# %% [markdown]
# # Compression logs order-40 MC 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/40-order_markov_chain_1000000.txt output/40_mc_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/40_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/40-order_markov_chain_1000000.txt output/decom_mc_1m
# ```
#
# The file "Simulated-data/30-order_markov_chain_1000000.txt" is the same as "output/decom_mc_1m"

# %% [markdown]
# ### Compression Log
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash compress.sh Simulated-data/40-order_markov_chain_1000000.txt output/40_mc_1m.dzip com MODEL_PATH
# Seq Length 1999999
# Using cuda
# Vocab Size 3
# CudNN version 8902
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.5352685451507568 secs
# 3.604308605194092 secs/976 Average loss: 1.7712
# ====> Epoch: 1 Average loss: 0.5125211500: 0.5237
# Loss went from 100000000.0000 to 0.5125
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23987722396850586 secs
# 3.5236432552337646 secs976 Average loss: 0.5087
# ====> Epoch: 2 Average loss: 0.5002292896: 0.5003
# Loss went from 0.5125 to 0.5002
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23186564445495605 secs
# 3.619208335876465 secs/976 Average loss: 0.4878
# ====> Epoch: 3 Average loss: 0.5001879871: 0.5006
# Loss went from 0.5002 to 0.5002
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23300600051879883 secs
# 3.481624126434326 secs/976 Average loss: 0.4902
# ====> Epoch: 4 Average loss: 0.5001299515: 0.4997
# Loss went from 0.5002 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.24842214584350586 secs
# 3.623899221420288 secs/976 Average loss: 0.4880
# ====> Epoch: 5 Average loss: 0.5001075053: 0.4994
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.25128650665283203 secs
# 3.7334251403808594 secs976 Average loss: 0.4959
# ====> Epoch: 6 Average loss: 0.5000942750: 0.5002
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.24991917610168457 secs
# 3.506369113922119 secs/976 Average loss: 0.4832
# ====> Epoch: 7 Average loss: 0.5000769973: 0.5005
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2593979835510254 secs
# 3.6119396686553955 secs976 Average loss: 0.5033
# ====> Epoch: 8 Average loss: 0.5000572656: 0.5002
# Loss went from 0.5001 to 0.5001
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# 0.5018870830535889 secs
# Iter 100 Loss 0.5581 Moving Loss 0.5581 Train Loss 0.9147
# 0.22435355186462402 secs
# Iter 200 Loss 0.5308 Moving Loss 0.5035 Train Loss 0.5628
# 0.22578096389770508 secs
# Iter 300 Loss 0.5256 Moving Loss 0.5153 Train Loss 0.5546
# 0.2294771671295166 secs
# Iter 400 Loss 0.5193 Moving Loss 0.5006 Train Loss 0.5254
# 0.22319626808166504 secs
# Iter 500 Loss 0.5162 Moving Loss 0.5036 Train Loss 0.5115
# 0.22297072410583496 secs
# Iter 600 Loss 0.5142 Moving Loss 0.5042 Train Loss 0.5277
# 0.22366905212402344 secs
# Iter 700 Loss 0.5122 Moving Loss 0.5005 Train Loss 0.5051
# 0.22238421440124512 secs
# Iter 800 Loss 0.5108 Moving Loss 0.5004 Train Loss 0.5064
# 0.22258472442626953 secs
# Iter 900 Loss 0.5099 Moving Loss 0.5032 Train Loss 0.5178
# 0.22241926193237305 secs
# Iter 1000 Loss 0.5093 Moving Loss 0.5036 Train Loss 0.5155
# 0.25100064277648926 secs
# Iter 1100 Loss 0.5085 Moving Loss 0.5006 Train Loss 0.5062
# 0.2282276153564453 secs
# Iter 1200 Loss 0.5079 Moving Loss 0.5010 Train Loss 0.5038
# 0.2299039363861084 secs
# Iter 1300 Loss 0.5073 Moving Loss 0.4999 Train Loss 0.5064
# 0.2235407829284668 secs
# Iter 1400 Loss 0.5068 Moving Loss 0.5007 Train Loss 0.5024
# 0.22465038299560547 secs
# Iter 1500 Loss 0.5066 Moving Loss 0.5032 Train Loss 0.5117
# 0.22541451454162598 secs
# Iter 1600 Loss 0.5062 Moving Loss 0.5015 Train Loss 0.5091
# 0.23418712615966797 secs
# Iter 1700 Loss 0.5059 Moving Loss 0.5007 Train Loss 0.5032
# 0.23147177696228027 secs
# Iter 1800 Loss 0.5055 Moving Loss 0.4992 Train Loss 0.5024
# 0.23833394050598145 secs
# Iter 1900 Loss 0.5055 Moving Loss 0.5038 Train Loss 0.5130
# 0.23548555374145508 secs
# Iter 2000 Loss 0.5052 Moving Loss 0.5003 Train Loss 0.5033
# 0.22487974166870117 secs
# Iter 2100 Loss 0.5050 Moving Loss 0.5008 Train Loss 0.5060
# 0.22301435470581055 secs
# Iter 2200 Loss 0.5049 Moving Loss 0.5021 Train Loss 0.5082
# 0.22315502166748047 secs
# Iter 2300 Loss 0.5046 Moving Loss 0.5000 Train Loss 0.5019
# 0.22408008575439453 secs
# Iter 2400 Loss 0.5044 Moving Loss 0.4997 Train Loss 0.5004
# 0.22356390953063965 secs
# Iter 2500 Loss 0.5043 Moving Loss 0.5010 Train Loss 0.5060
# 0.22249388694763184 secs
# Iter 2600 Loss 0.5041 Moving Loss 0.5002 Train Loss 0.5015
# 0.2235395908355713 secs
# Iter 2700 Loss 0.5040 Moving Loss 0.5004 Train Loss 0.5028
# 0.22351527214050293 secs
# Iter 2800 Loss 0.5039 Moving Loss 0.5019 Train Loss 0.5037
# 0.22487735748291016 secs
# Iter 2900 Loss 0.5038 Moving Loss 0.5002 Train Loss 0.5045
# 0.223191499710083 secs
# Iter 3000 Loss 0.5037 Moving Loss 0.5008 Train Loss 0.5013
# 0.22265124320983887 secs
# Iter 3100 Loss 0.5036 Moving Loss 0.5003 Train Loss 0.5036
# 0.2233905792236328 secs
# Iter 3200 Loss 0.5035 Moving Loss 0.5007 Train Loss 0.5008
# 0.22477340698242188 secs
# Iter 3300 Loss 0.5034 Moving Loss 0.5006 Train Loss 0.5038
# 0.22540712356567383 secs
# Iter 3400 Loss 0.5034 Moving Loss 0.5015 Train Loss 0.5054
# 0.2252061367034912 secs
# Iter 3500 Loss 0.5033 Moving Loss 0.5012 Train Loss 0.5047
# 0.22322559356689453 secs
# Iter 3600 Loss 0.5032 Moving Loss 0.5005 Train Loss 0.5015
# 0.22343730926513672 secs
# Iter 3700 Loss 0.5031 Moving Loss 0.5001 Train Loss 0.5013
# 0.22470474243164062 secs
# Iter 3800 Loss 0.5031 Moving Loss 0.5014 Train Loss 0.5009
# 0.22320032119750977 secs
# Iter 3900 Loss 0.5030 Moving Loss 0.5001 Train Loss 0.5065
# 0.23346209526062012 secs
# Iter 4000 Loss 0.5029 Moving Loss 0.5004 Train Loss 0.5014
# 0.23953890800476074 secs
# Iter 4100 Loss 0.5029 Moving Loss 0.5008 Train Loss 0.5034
# 0.23012781143188477 secs
# Iter 4200 Loss 0.5028 Moving Loss 0.4998 Train Loss 0.5007
# 0.22840118408203125 secs
# Iter 4300 Loss 0.5028 Moving Loss 0.5006 Train Loss 0.5021
# 0.22537565231323242 secs
# Iter 4400 Loss 0.5027 Moving Loss 0.5002 Train Loss 0.5014
# 0.2223830223083496 secs
# Iter 4500 Loss 0.5027 Moving Loss 0.5006 Train Loss 0.5012
# 0.22347378730773926 secs
# Iter 4600 Loss 0.5026 Moving Loss 0.5004 Train Loss 0.5020
# 0.22265243530273438 secs
# Iter 4700 Loss 0.5026 Moving Loss 0.5008 Train Loss 0.5049
# 0.22343111038208008 secs
# Iter 4800 Loss 0.5025 Moving Loss 0.5009 Train Loss 0.5015
# 0.22178030014038086 secs
# Iter 4900 Loss 0.5025 Moving Loss 0.5008 Train Loss 0.5035
# 0.2217540740966797 secs
# Iter 5000 Loss 0.5025 Moving Loss 0.5001 Train Loss 0.5011
# 0.22388434410095215 secs
# Iter 5100 Loss 0.5024 Moving Loss 0.5004 Train Loss 0.5021
# 0.22228479385375977 secs
# Iter 5200 Loss 0.5024 Moving Loss 0.5002 Train Loss 0.5014
# 0.22288775444030762 secs
# Iter 5300 Loss 0.5023 Moving Loss 0.5007 Train Loss 0.5028
# 0.2220606803894043 secs
# Iter 5400 Loss 0.5023 Moving Loss 0.5019 Train Loss 0.5060
# 0.22503948211669922 secs
# Iter 5500 Loss 0.5023 Moving Loss 0.5002 Train Loss 0.5025
# 0.22678256034851074 secs
# Iter 5600 Loss 0.5023 Moving Loss 0.5003 Train Loss 0.5007
# 0.22298264503479004 secs
# Iter 5700 Loss 0.5022 Moving Loss 0.4997 Train Loss 0.5013
# 0.22260618209838867 secs
# Iter 5800 Loss 0.5022 Moving Loss 0.5015 Train Loss 0.5027
# 0.22219204902648926 secs
# Iter 5900 Loss 0.5022 Moving Loss 0.5000 Train Loss 0.5031
# 0.22540760040283203 secs
# Iter 6000 Loss 0.5021 Moving Loss 0.4998 Train Loss 0.4998
# 0.22153091430664062 secs
# Iter 6100 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5003
# 0.23151636123657227 secs
# Iter 6200 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5014
# 0.24569272994995117 secs
# Iter 6300 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5006
# 0.2239699363708496 secs
# Iter 6400 Loss 0.5020 Moving Loss 0.5012 Train Loss 0.5045
# 0.22472715377807617 secs
# Iter 6500 Loss 0.5020 Moving Loss 0.4999 Train Loss 0.5004
# 0.22902274131774902 secs
# Iter 6600 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5011
# 0.22279143333435059 secs
# Iter 6700 Loss 0.5019 Moving Loss 0.5013 Train Loss 0.5042
# 0.22268080711364746 secs
# Iter 6800 Loss 0.5020 Moving Loss 0.5034 Train Loss 0.5083
# 0.22517752647399902 secs
# Iter 6900 Loss 0.5024 Moving Loss 0.5302 Train Loss 0.8086
# 0.22989416122436523 secs
# Iter 7000 Loss 0.5024 Moving Loss 0.5062 Train Loss 0.5435
# 0.22354459762573242 secs
# Iter 7100 Loss 0.5024 Moving Loss 0.5003 Train Loss 0.5016
# 0.22252178192138672 secs
# Iter 7200 Loss 0.5024 Moving Loss 0.5003 Train Loss 0.5013
# 0.22478604316711426 secs
# Iter 7300 Loss 0.5023 Moving Loss 0.5003 Train Loss 0.5010
# 0.22330546379089355 secs
# Iter 7400 Loss 0.5023 Moving Loss 0.5000 Train Loss 0.5007
# 0.22381901741027832 secs
# Iter 7500 Loss 0.5023 Moving Loss 0.5003 Train Loss 0.5008
# 0.22369623184204102 secs
# Iter 7600 Loss 0.5023 Moving Loss 0.5005 Train Loss 0.5015
# 0.22481369972229004 secs
# Iter 7700 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5008
# 0.22445130348205566 secs
# Iter 7800 Loss 0.5022 Moving Loss 0.4999 Train Loss 0.5018
# 0.2227306365966797 secs
# Iter 7900 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.4999
# 0.22192144393920898 secs
# Iter 8000 Loss 0.5021 Moving Loss 0.5004 Train Loss 0.5019
# 0.22322416305541992 secs
# Iter 8100 Loss 0.5021 Moving Loss 0.4993 Train Loss 0.5008
# 0.22612714767456055 secs
# Iter 8200 Loss 0.5021 Moving Loss 0.5008 Train Loss 0.5030
# 0.24098873138427734 secs
# Iter 8300 Loss 0.5021 Moving Loss 0.5005 Train Loss 0.5016
# 0.2576119899749756 secs
# Iter 8400 Loss 0.5021 Moving Loss 0.5007 Train Loss 0.5018
# 0.2887871265411377 secs
# Iter 8500 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5008
# 0.2687256336212158 secs
# Iter 8600 Loss 0.5020 Moving Loss 0.5002 Train Loss 0.5008
# 0.26503705978393555 secs
# Iter 8700 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5007
# 0.25756120681762695 secs
# Iter 8800 Loss 0.5020 Moving Loss 0.5005 Train Loss 0.5009
# 0.2579483985900879 secs
# Iter 8900 Loss 0.5020 Moving Loss 0.5003 Train Loss 0.5009
# 0.2618536949157715 secs
# Iter 9000 Loss 0.5019 Moving Loss 0.4995 Train Loss 0.4999
# 0.25948405265808105 secs
# Iter 9100 Loss 0.5019 Moving Loss 0.5002 Train Loss 0.5009
# 0.2576603889465332 secs
# Iter 9200 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5003
# 0.257692813873291 secs
# Iter 9300 Loss 0.5019 Moving Loss 0.4997 Train Loss 0.5002
# 0.25748300552368164 secs
# Iter 9400 Loss 0.5018 Moving Loss 0.5001 Train Loss 0.5008
# 0.2580406665802002 secs
# Iter 9500 Loss 0.5018 Moving Loss 0.4997 Train Loss 0.5002
# 0.25713229179382324 secs
# Iter 9600 Loss 0.5018 Moving Loss 0.5001 Train Loss 0.5016
# 0.26421308517456055 secs
# Iter 9700 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5007
# 0.2664213180541992 secs
# Iter 9800 Loss 0.5018 Moving Loss 0.5004 Train Loss 0.5013
# 0.2584226131439209 secs
# Iter 9900 Loss 0.5018 Moving Loss 0.4997 Train Loss 0.4999
# 0.2580723762512207 secs
# Iter 10000 Loss 0.5017 Moving Loss 0.5010 Train Loss 0.5022
# 0.2583892345428467 secs
# Iter 10100 Loss 0.5017 Moving Loss 0.5002 Train Loss 0.5012
# 0.2578160762786865 secs
# Iter 10200 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5005
# 0.25852203369140625 secs
# Iter 10300 Loss 0.5017 Moving Loss 0.4999 Train Loss 0.5004
# 0.2782571315765381 secs
# Iter 10400 Loss 0.5017 Moving Loss 0.5008 Train Loss 0.5022
# 0.26581597328186035 secs
# Iter 10500 Loss 0.5017 Moving Loss 0.5003 Train Loss 0.5010
# 0.2626476287841797 secs
# Iter 10600 Loss 0.5017 Moving Loss 0.5002 Train Loss 0.5009
# 0.2579159736633301 secs
# Iter 10700 Loss 0.5016 Moving Loss 0.5000 Train Loss 0.5007
# 0.2581357955932617 secs
# Iter 10800 Loss 0.5016 Moving Loss 0.4995 Train Loss 0.4995
# 0.25778889656066895 secs
# Iter 10900 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5009
# 0.25764012336730957 secs
# Iter 11000 Loss 0.5016 Moving Loss 0.4996 Train Loss 0.4998
# 0.2574434280395508 secs
# Iter 11100 Loss 0.5016 Moving Loss 0.5007 Train Loss 0.5014
# 0.2603616714477539 secs
# Iter 11200 Loss 0.5016 Moving Loss 0.5004 Train Loss 0.5012
# 0.2590460777282715 secs
# Iter 11300 Loss 0.5016 Moving Loss 0.5004 Train Loss 0.5013
# 0.25822997093200684 secs
# Iter 11400 Loss 0.5016 Moving Loss 0.5005 Train Loss 0.5019
# 0.2566707134246826 secs
# Iter 11500 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5011
# 0.25937867164611816 secs
# Iter 11600 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.5007
# 0.25998854637145996 secs
# Iter 11700 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5013
# 0.2581007480621338 secs
# Iter 11800 Loss 0.5015 Moving Loss 0.4998 Train Loss 0.5001
# 0.25774097442626953 secs
# Iter 11900 Loss 0.5015 Moving Loss 0.5005 Train Loss 0.5013
# 0.2597947120666504 secs
# Iter 12000 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5007
# 0.25817418098449707 secs
# Iter 12100 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.5005
# 0.2572617530822754 secs
# Iter 12200 Loss 0.5015 Moving Loss 0.4999 Train Loss 0.5004
# 0.2706301212310791 secs
# Iter 12300 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5004
# 0.2820851802825928 secs
# Iter 12400 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5010
# 0.26903367042541504 secs
# Iter 12500 Loss 0.5014 Moving Loss 0.4996 Train Loss 0.5001
# 0.2605247497558594 secs
# Iter 12600 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5008
# 0.25606441497802734 secs
# Iter 12700 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5003
# 0.2576923370361328 secs
# Iter 12800 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5009
# 0.26272010803222656 secs
# Iter 12900 Loss 0.5014 Moving Loss 0.5003 Train Loss 0.5006
# 0.26114916801452637 secs
# Iter 13000 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5009
# 0.2595953941345215 secs
# Iter 13100 Loss 0.5014 Moving Loss 0.5004 Train Loss 0.5011
# 0.2580893039703369 secs
# Iter 13200 Loss 0.5014 Moving Loss 0.5007 Train Loss 0.5016
# 0.25734376907348633 secs
# Iter 13300 Loss 0.5014 Moving Loss 0.5006 Train Loss 0.5025
# 0.2562417984008789 secs
# Iter 13400 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5005
# 0.25808215141296387 secs
# Iter 13500 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5002
# 0.26054811477661133 secs
# Iter 13600 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5006
# 0.2656095027923584 secs
# Iter 13700 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5003
# 0.2578587532043457 secs
# Iter 13800 Loss 0.5013 Moving Loss 0.5006 Train Loss 0.5023
# 0.25874853134155273 secs
# Iter 13900 Loss 0.5013 Moving Loss 0.5016 Train Loss 0.5048
# 0.25654149055480957 secs
# Iter 14000 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5034
# 0.2572181224822998 secs
# Iter 14100 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5009
# 0.2699599266052246 secs
# Iter 14200 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5011
# 0.2575666904449463 secs
# Iter 14300 Loss 0.5013 Moving Loss 0.4996 Train Loss 0.5006
# 0.2641317844390869 secs
# Iter 14400 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5003
# 0.2762458324432373 secs
# Iter 14500 Loss 0.5013 Moving Loss 0.4998 Train Loss 0.5001
# 0.256178617477417 secs
# Iter 14600 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5001
# 0.257204532623291 secs
# Iter 14700 Loss 0.5013 Moving Loss 0.5007 Train Loss 0.5032
# 0.25582051277160645 secs
# Iter 14800 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5014
# 0.2583730220794678 secs
# Iter 14900 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5015
# 0.25667643547058105 secs
# Iter 15000 Loss 0.5012 Moving Loss 0.5010 Train Loss 0.5041
# 0.2573730945587158 secs
# Iter 15100 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5004
# 0.25612545013427734 secs
# Iter 15200 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5010
# 0.2755110263824463 secs
# Iter 15300 Loss 0.5012 Moving Loss 0.5005 Train Loss 0.5016
# 0.2654249668121338 secs
# Iter 15400 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5009
# 0.26212430000305176 secs
# Iter 15500 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5006
# 0.25760817527770996 secs
# Iter 15600 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5007
# 0.256610631942749 secs
# Iter 15700 Loss 0.5012 Moving Loss 0.5003 Train Loss 0.5006
# 0.25633978843688965 secs
# Iter 15800 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.26093101501464844 secs
# Iter 15900 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5001
# 0.25605034828186035 secs
# Iter 16000 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5000
# 0.268505334854126 secs
# Iter 16100 Loss 0.5012 Moving Loss 0.5003 Train Loss 0.5010
# 0.2612948417663574 secs
# Iter 16200 Loss 0.5012 Moving Loss 0.4999 Train Loss 0.5006
# 0.2720520496368408 secs
# Iter 16300 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5003
# 0.26644015312194824 secs
# Iter 16400 Loss 0.5012 Moving Loss 0.5004 Train Loss 0.5010
# 0.25724005699157715 secs
# Iter 16500 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5021
# 0.2567582130432129 secs
# Iter 16600 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5004
# 0.2578470706939697 secs
# Iter 16700 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5004
# 0.26007771492004395 secs
# Iter 16800 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.4996
# 0.2668187618255615 secs
# Iter 16900 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5014
# 0.2566952705383301 secs
# Iter 17000 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5012
# 0.25902271270751953 secs
# Iter 17100 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5007
# 0.2561037540435791 secs
# Iter 17200 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5013
# 0.25581979751586914 secs
# Iter 17300 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.26778316497802734 secs
# Iter 17400 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5006
# 0.2627413272857666 secs
# Iter 17500 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5019
# 0.2567594051361084 secs
# Iter 17600 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5006
# 0.2562575340270996 secs
# Iter 17700 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.25917887687683105 secs
# Iter 17800 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5008
# 0.25692105293273926 secs
# Iter 17900 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5006
# 0.2567555904388428 secs
# Iter 18000 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.2669639587402344 secs
# Iter 18100 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5001
# 0.25792384147644043 secs
# Iter 18200 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5007
# 0.27010512351989746 secs
# Iter 18300 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.25638413429260254 secs
# Iter 18400 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.4999
# 0.25685644149780273 secs
# Iter 18500 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5007
# 0.25601959228515625 secs
# Iter 18600 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5005
# 0.2611820697784424 secs
# Iter 18700 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5004
# 0.2563059329986572 secs
# Iter 18800 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5006
# 0.2656865119934082 secs
# Iter 18900 Loss 0.5010 Moving Loss 0.5004 Train Loss 0.5008
# 0.255415678024292 secs
# Iter 19000 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5007
# 0.25549840927124023 secs
# Iter 19100 Loss 0.5010 Moving Loss 0.5007 Train Loss 0.5017
# 0.2553384304046631 secs
# Iter 19200 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5005
# 0.26243162155151367 secs
# Iter 19300 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5008
# 0.2645995616912842 secs
# Iter 19400 Loss 0.5010 Moving Loss 0.4995 Train Loss 0.4996
# 0.25734829902648926 secs
# Iter 19500 Loss 0.5010 Moving Loss 0.5005 Train Loss 0.5012
# 0.25698304176330566 secs
# Iter 19600 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5008
# 0.257568359375 secs
# Iter 19700 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5005
# 0.2573695182800293 secs
# Iter 19800 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5003
# 0.2559494972229004 secs
# Iter 19900 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5000
# 0.2781188488006592 secs
# Iter 20000 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.2750515937805176 secs
# Iter 20100 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.4999
# 0.26334643363952637 secs
# Iter 20200 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5003
# 0.26569533348083496 secs
# Iter 20300 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5002
# 0.25592565536499023 secs
# Iter 20400 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5003
# 0.25709962844848633 secs
# Iter 20500 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5002
# 0.25760674476623535 secs
# Iter 20600 Loss 0.5009 Moving Loss 0.4995 Train Loss 0.5000
# 0.256974458694458 secs
# Iter 20700 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5001
# 0.25600624084472656 secs
# Iter 20800 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5006
# 0.257580041885376 secs
# Iter 20900 Loss 0.5009 Moving Loss 0.4999 Train Loss 0.5001
# 0.25739502906799316 secs
# Iter 21000 Loss 0.5009 Moving Loss 0.5003 Train Loss 0.5007
# 0.2557399272918701 secs
# Iter 21100 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5003
# 0.25850582122802734 secs
# Iter 21200 Loss 0.5009 Moving Loss 0.4998 Train Loss 0.5003
# 0.2599825859069824 secs
# Iter 21300 Loss 0.5009 Moving Loss 0.5006 Train Loss 0.5011
# 0.2560439109802246 secs
# Iter 21400 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5005
# 0.25629353523254395 secs
# Iter 21500 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5003
# 0.25781679153442383 secs
# Iter 21600 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5002
# 0.2551231384277344 secs
# Iter 21700 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5004
# 0.2567415237426758 secs
# Iter 21800 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5007
# 0.2695159912109375 secs
# Iter 21900 Loss 0.5009 Moving Loss 0.5007 Train Loss 0.5005
# 0.26378679275512695 secs
# Iter 22000 Loss 0.5009 Moving Loss 0.5003 Train Loss 0.5021
# 0.25850820541381836 secs
# Iter 22100 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5005
# 0.2701096534729004 secs
# Iter 22200 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5003
# 0.2573282718658447 secs
# Iter 22300 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5007
# 0.25679850578308105 secs
# Iter 22400 Loss 0.5009 Moving Loss 0.5003 Train Loss 0.5004
# 0.25804638862609863 secs
# Iter 22500 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5006
# 0.25742483139038086 secs
# Iter 22600 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5004
# 0.2566804885864258 secs
# Iter 22700 Loss 0.5009 Moving Loss 0.5007 Train Loss 0.5019
# 0.25699877738952637 secs
# Iter 22800 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5004
# 0.2556121349334717 secs
# Iter 22900 Loss 0.5009 Moving Loss 0.4997 Train Loss 0.5000
# 0.25649547576904297 secs
# Iter 23000 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.4999
# 0.25604820251464844 secs
# Iter 23100 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5000
# 0.25795459747314453 secs
# Iter 23200 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5013
# 0.25696396827697754 secs
# Iter 23300 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5006
# 0.25568580627441406 secs
# Iter 23400 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5011
# 0.25577831268310547 secs
# Iter 23500 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.4997
# 0.2566039562225342 secs
# Iter 23600 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5016
# 0.2561612129211426 secs
# Iter 23700 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5004
# 0.2659635543823242 secs
# Iter 23800 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5001
# 0.2839827537536621 secs
# Iter 23900 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5006
# 0.2723808288574219 secs
# Iter 24000 Loss 0.5008 Moving Loss 0.5004 Train Loss 0.5008
# 0.2598271369934082 secs
# Iter 24100 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5006
# 0.26340198516845703 secs
# Iter 24200 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5003
# 0.25690174102783203 secs
# Iter 24300 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5004
# 0.2619025707244873 secs
# Iter 24400 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5004
# 0.2577245235443115 secs
# Iter 24500 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5005
# 0.25681257247924805 secs
# Iter 24600 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5009
# 0.25691819190979004 secs
# Iter 24700 Loss 0.5008 Moving Loss 0.4998 Train Loss 0.5000
# 0.2567269802093506 secs
# Iter 24800 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5003
# 0.2565274238586426 secs
# Iter 24900 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5006
# 0.2569258213043213 secs
# Iter 25000 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5006
# 0.26611804962158203 secs
# Iter 25100 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5002
# 0.26172900199890137 secs
# Iter 25200 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5002
# 0.2569088935852051 secs
# Iter 25300 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5003
# 0.2563004493713379 secs
# Iter 25400 Loss 0.5008 Moving Loss 0.5005 Train Loss 0.5011
# 0.25758981704711914 secs
# Iter 25500 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5000
# 0.2573397159576416 secs
# Iter 25600 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5005
# 0.2579481601715088 secs
# Iter 25700 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5009
# 0.2451610565185547 secs
# Iter 25800 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5003
# 0.22868132591247559 secs
# Iter 25900 Loss 0.5008 Moving Loss 0.5044 Train Loss 0.5074
# 0.22025322914123535 secs
# Iter 26000 Loss 0.5008 Moving Loss 0.5038 Train Loss 0.5387
# 0.22274351119995117 secs
# Iter 26100 Loss 0.5008 Moving Loss 0.5005 Train Loss 0.5006
# 0.22843503952026367 secs
# Iter 26200 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5011
# 0.2219710350036621 secs
# Iter 26300 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5005
# 0.2208871841430664 secs
# Iter 26400 Loss 0.5008 Moving Loss 0.4998 Train Loss 0.5005
# 0.22141408920288086 secs
# Iter 26500 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5003
# 0.2211599349975586 secs
# Iter 26600 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5009
# 0.2200767993927002 secs
# Iter 26700 Loss 0.5008 Moving Loss 0.4997 Train Loss 0.4998
# 0.22138452529907227 secs
# Iter 26800 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5004
# 0.22054505348205566 secs
# Iter 26900 Loss 0.5008 Moving Loss 0.5008 Train Loss 0.5022
# 0.22014689445495605 secs
# Iter 27000 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5021
# 0.220062255859375 secs
# Iter 27100 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5002
# 0.22417449951171875 secs
# Iter 27200 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5006
# 0.22158217430114746 secs
# Iter 27300 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5007
# 0.22073674201965332 secs
# Iter 27400 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5006
# 0.2201526165008545 secs
# Iter 27500 Loss 0.5008 Moving Loss 0.5004 Train Loss 0.5007
# 0.22045326232910156 secs
# Iter 27600 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5003
# 0.22443652153015137 secs
# Iter 27700 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.4998
# 0.22164440155029297 secs
# Iter 27800 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5011
# 0.22151446342468262 secs
# Iter 27900 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5004
# 0.23397326469421387 secs
# Iter 28000 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5005
# 0.235856294631958 secs
# Iter 28100 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5004
# 0.23458290100097656 secs
# Iter 28200 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5003
# 0.24527263641357422 secs
# Iter 28300 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5007
# 0.22014451026916504 secs
# Iter 28400 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5008
# 0.23157286643981934 secs
# Iter 28500 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5002
# 0.22157835960388184 secs
# Iter 28600 Loss 0.5007 Moving Loss 0.4998 Train Loss 0.4999
# 0.22195935249328613 secs
# Iter 28700 Loss 0.5007 Moving Loss 0.4997 Train Loss 0.4997
# 0.2204899787902832 secs
# Iter 28800 Loss 0.5007 Moving Loss 0.5004 Train Loss 0.5011
# 0.22028160095214844 secs
# Iter 28900 Loss 0.5007 Moving Loss 0.5004 Train Loss 0.5010
# 0.22136473655700684 secs
# Iter 29000 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5004
# 0.22077083587646484 secs
# Iter 29100 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5004
# 0.2203967571258545 secs
# Iter 29200 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5001
# 0.2202012538909912 secs
# Iter 29300 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5004
# 0.22098731994628906 secs
# Iter 29400 Loss 0.5007 Moving Loss 0.5004 Train Loss 0.5009
# 0.22304034233093262 secs
# Iter 29500 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5002
# 0.22092151641845703 secs
# Iter 29600 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5002
# 0.22015953063964844 secs
# Iter 29700 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5003
# 0.2208085060119629 secs
# Iter 29800 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5001
# 0.22157573699951172 secs
# Iter 29900 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5004
# 0.22045040130615234 secs
# Iter 30000 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5000
# 0.22141146659851074 secs
# Iter 30100 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5004
# 0.23312830924987793 secs
# Iter 30200 Loss 0.5007 Moving Loss 0.5003 Train Loss 0.5012
# 0.23524117469787598 secs
# Iter 30300 Loss 0.5007 Moving Loss 0.5004 Train Loss 0.5008
# 0.2290642261505127 secs
# Iter 30400 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.4999
# 0.22358298301696777 secs
# Iter 30500 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5005
# 0.22068262100219727 secs
# Iter 30600 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5006
# 0.22111749649047852 secs
# Iter 30700 Loss 0.5007 Moving Loss 0.4998 Train Loss 0.5002
# 0.23237848281860352 secs
# Iter 30800 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5005
# 0.22716331481933594 secs
# Iter 30900 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5003
# 0.22247624397277832 secs
# Iter 31000 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5002
# 0.22086882591247559 secs
# Iter 31100 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5000
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash decompress.sh output/40_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5581 Moving Loss 0.5581
# 0.5394585132598877 secs
# Iter 200 Loss 0.5308 Moving Loss 0.5035
# 0.2418978214263916 secs
# Iter 300 Loss 0.5256 Moving Loss 0.5153
# 0.24241948127746582 secs
# Iter 400 Loss 0.5193 Moving Loss 0.5006
# 0.23759746551513672 secs
# Iter 500 Loss 0.5162 Moving Loss 0.5036
# 0.23834967613220215 secs
# Iter 600 Loss 0.5142 Moving Loss 0.5042
# 0.23851227760314941 secs
# Iter 700 Loss 0.5122 Moving Loss 0.5005
# 0.27149367332458496 secs
# Iter 800 Loss 0.5108 Moving Loss 0.5004
# 0.26563453674316406 secs
# Iter 900 Loss 0.5099 Moving Loss 0.5032
# 0.26036810874938965 secs
# Iter 1000 Loss 0.5093 Moving Loss 0.5036
# 0.2370595932006836 secs
# Iter 1100 Loss 0.5085 Moving Loss 0.5006
# 0.23925995826721191 secs
# Iter 1200 Loss 0.5079 Moving Loss 0.5010
# 0.23848176002502441 secs
# Iter 1300 Loss 0.5073 Moving Loss 0.4999
# 0.2375035285949707 secs
# Iter 1400 Loss 0.5068 Moving Loss 0.5007
# 0.24799776077270508 secs
# Iter 1500 Loss 0.5066 Moving Loss 0.5032
# 0.23919677734375 secs
# Iter 1600 Loss 0.5062 Moving Loss 0.5015
# 0.23601078987121582 secs
# Iter 1700 Loss 0.5059 Moving Loss 0.5007
# 0.23647189140319824 secs
# Iter 1800 Loss 0.5055 Moving Loss 0.4992
# 0.23913884162902832 secs
# Iter 1900 Loss 0.5055 Moving Loss 0.5038
# 0.23726344108581543 secs
# Iter 2000 Loss 0.5052 Moving Loss 0.5003
# 0.2378685474395752 secs
# Iter 2100 Loss 0.5050 Moving Loss 0.5008
# 0.24937820434570312 secs
# Iter 2200 Loss 0.5049 Moving Loss 0.5021
# 0.2448287010192871 secs
# Iter 2300 Loss 0.5046 Moving Loss 0.5000
# 0.2366786003112793 secs
# Iter 2400 Loss 0.5044 Moving Loss 0.4997
# 0.23637843132019043 secs
# Iter 2500 Loss 0.5043 Moving Loss 0.5010
# 0.23523974418640137 secs
# Iter 2600 Loss 0.5041 Moving Loss 0.5002
# 0.23725080490112305 secs
# Iter 2700 Loss 0.5040 Moving Loss 0.5004
# 0.2374401092529297 secs
# Iter 2800 Loss 0.5039 Moving Loss 0.5019
# 0.23628950119018555 secs
# Iter 2900 Loss 0.5038 Moving Loss 0.5002
# 0.23753666877746582 secs
# Iter 3000 Loss 0.5037 Moving Loss 0.5008
# 0.24471330642700195 secs
# Iter 3100 Loss 0.5036 Moving Loss 0.5003
# 0.23623371124267578 secs
# Iter 3200 Loss 0.5035 Moving Loss 0.5007
# 0.23588252067565918 secs
# Iter 3300 Loss 0.5034 Moving Loss 0.5006
# 0.2360222339630127 secs
# Iter 3400 Loss 0.5034 Moving Loss 0.5015
# 0.23708415031433105 secs
# Iter 3500 Loss 0.5033 Moving Loss 0.5012
# 0.2398698329925537 secs
# Iter 3600 Loss 0.5032 Moving Loss 0.5005
# 0.23611879348754883 secs
# Iter 3700 Loss 0.5031 Moving Loss 0.5001
# 0.23490405082702637 secs
# Iter 3800 Loss 0.5031 Moving Loss 0.5014
# 0.2370131015777588 secs
# Iter 3900 Loss 0.5030 Moving Loss 0.5001
# 0.23704242706298828 secs
# Iter 4000 Loss 0.5029 Moving Loss 0.5004
# 0.23589134216308594 secs
# Iter 4100 Loss 0.5029 Moving Loss 0.5008
# 0.23705697059631348 secs
# Iter 4200 Loss 0.5028 Moving Loss 0.4998
# 0.252150297164917 secs
# Iter 4300 Loss 0.5028 Moving Loss 0.5006
# 0.24865245819091797 secs
# Iter 4400 Loss 0.5027 Moving Loss 0.5002
# 0.23889946937561035 secs
# Iter 4500 Loss 0.5027 Moving Loss 0.5006
# 0.23660635948181152 secs
# Iter 4600 Loss 0.5026 Moving Loss 0.5004
# 0.23461318016052246 secs
# Iter 4700 Loss 0.5026 Moving Loss 0.5008
# 0.2354893684387207 secs
# Iter 4800 Loss 0.5025 Moving Loss 0.5009
# 0.24058771133422852 secs
# Iter 4900 Loss 0.5025 Moving Loss 0.5008
# 0.23640108108520508 secs
# Iter 5000 Loss 0.5025 Moving Loss 0.5001
# 0.23619508743286133 secs
# Iter 5100 Loss 0.5024 Moving Loss 0.5004
# 0.23571062088012695 secs
# Iter 5200 Loss 0.5024 Moving Loss 0.5002
# 0.24738121032714844 secs
# Iter 5300 Loss 0.5023 Moving Loss 0.5007
# 0.23594260215759277 secs
# Iter 5400 Loss 0.5023 Moving Loss 0.5019
# 0.23468708992004395 secs
# Iter 5500 Loss 0.5023 Moving Loss 0.5002
# 0.23699235916137695 secs
# Iter 5600 Loss 0.5023 Moving Loss 0.5003
# 0.23815393447875977 secs
# Iter 5700 Loss 0.5022 Moving Loss 0.4997
# 0.23675894737243652 secs
# Iter 5800 Loss 0.5022 Moving Loss 0.5015
# 0.2347710132598877 secs
# Iter 5900 Loss 0.5022 Moving Loss 0.5000
# 0.23678231239318848 secs
# Iter 6000 Loss 0.5021 Moving Loss 0.4998
# 0.23662328720092773 secs
# Iter 6100 Loss 0.5021 Moving Loss 0.5000
# 0.23623061180114746 secs
# Iter 6200 Loss 0.5021 Moving Loss 0.5000
# 0.23575043678283691 secs
# Iter 6300 Loss 0.5020 Moving Loss 0.5000
# 0.2497880458831787 secs
# Iter 6400 Loss 0.5020 Moving Loss 0.5012
# 0.24943161010742188 secs
# Iter 6500 Loss 0.5020 Moving Loss 0.4999
# 0.24416685104370117 secs
# Iter 6600 Loss 0.5019 Moving Loss 0.5000
# 0.23633527755737305 secs
# Iter 6700 Loss 0.5019 Moving Loss 0.5013
# 0.2349400520324707 secs
# Iter 6800 Loss 0.5020 Moving Loss 0.5034
# 0.2361304759979248 secs
# Iter 6900 Loss 0.5024 Moving Loss 0.5302
# 0.23787689208984375 secs
# Iter 7000 Loss 0.5024 Moving Loss 0.5062
# 0.23612141609191895 secs
# Iter 7100 Loss 0.5024 Moving Loss 0.5003
# 0.23828482627868652 secs
# Iter 7200 Loss 0.5024 Moving Loss 0.5003
# 0.23656892776489258 secs
# Iter 7300 Loss 0.5023 Moving Loss 0.5003
# 0.24549555778503418 secs
# Iter 7400 Loss 0.5023 Moving Loss 0.5000
# 0.23536014556884766 secs
# Iter 7500 Loss 0.5023 Moving Loss 0.5003
# 0.23535585403442383 secs
# Iter 7600 Loss 0.5023 Moving Loss 0.5005
# 0.2370755672454834 secs
# Iter 7700 Loss 0.5022 Moving Loss 0.5002
# 0.23841118812561035 secs
# Iter 7800 Loss 0.5022 Moving Loss 0.4999
# 0.2380375862121582 secs
# Iter 7900 Loss 0.5022 Moving Loss 0.5002
# 0.23613810539245605 secs
# Iter 8000 Loss 0.5021 Moving Loss 0.5004
# 0.23553991317749023 secs
# Iter 8100 Loss 0.5021 Moving Loss 0.4993
# 0.2377634048461914 secs
# Iter 8200 Loss 0.5021 Moving Loss 0.5008
# 0.23691105842590332 secs
# Iter 8300 Loss 0.5021 Moving Loss 0.5005
# 0.23453474044799805 secs
# Iter 8400 Loss 0.5021 Moving Loss 0.5007
# 0.2502930164337158 secs
# Iter 8500 Loss 0.5020 Moving Loss 0.5001
# 0.24051856994628906 secs
# Iter 8600 Loss 0.5020 Moving Loss 0.5002
# 0.24143099784851074 secs
# Iter 8700 Loss 0.5020 Moving Loss 0.5000
# 0.23602962493896484 secs
# Iter 8800 Loss 0.5020 Moving Loss 0.5005
# 0.2348625659942627 secs
# Iter 8900 Loss 0.5020 Moving Loss 0.5003
# 0.23584723472595215 secs
# Iter 9000 Loss 0.5019 Moving Loss 0.4995
# 0.24012207984924316 secs
# Iter 9100 Loss 0.5019 Moving Loss 0.5002
# 0.23605990409851074 secs
# Iter 9200 Loss 0.5019 Moving Loss 0.5000
# 0.23527956008911133 secs
# Iter 9300 Loss 0.5019 Moving Loss 0.4997
# 0.23518776893615723 secs
# Iter 9400 Loss 0.5018 Moving Loss 0.5001
# 0.23624038696289062 secs
# Iter 9500 Loss 0.5018 Moving Loss 0.4997
# 0.2472395896911621 secs
# Iter 9600 Loss 0.5018 Moving Loss 0.5001
# 0.23542547225952148 secs
# Iter 9700 Loss 0.5018 Moving Loss 0.5002
# 0.24102091789245605 secs
# Iter 9800 Loss 0.5018 Moving Loss 0.5004
# 0.24489879608154297 secs
# Iter 9900 Loss 0.5018 Moving Loss 0.4997
# 0.23654723167419434 secs
# Iter 10000 Loss 0.5017 Moving Loss 0.5010
# 0.2349841594696045 secs
# Iter 10100 Loss 0.5017 Moving Loss 0.5002
# 0.23534059524536133 secs
# Iter 10200 Loss 0.5017 Moving Loss 0.5000
# 0.23815560340881348 secs
# Iter 10300 Loss 0.5017 Moving Loss 0.4999
# 0.23718976974487305 secs
# Iter 10400 Loss 0.5017 Moving Loss 0.5008
# 0.23840665817260742 secs
# Iter 10500 Loss 0.5017 Moving Loss 0.5003
# 0.2579958438873291 secs
# Iter 10600 Loss 0.5017 Moving Loss 0.5002
# 0.24988102912902832 secs
# Iter 10700 Loss 0.5016 Moving Loss 0.5000
# 0.2363755702972412 secs
# Iter 10800 Loss 0.5016 Moving Loss 0.4995
# 0.23607659339904785 secs
# Iter 10900 Loss 0.5016 Moving Loss 0.5002
# 0.23533964157104492 secs
# Iter 11000 Loss 0.5016 Moving Loss 0.4996
# 0.23760318756103516 secs
# Iter 11100 Loss 0.5016 Moving Loss 0.5007
# 0.24721550941467285 secs
# Iter 11200 Loss 0.5016 Moving Loss 0.5004
# 0.23623299598693848 secs
# Iter 11300 Loss 0.5016 Moving Loss 0.5004
# 0.23649311065673828 secs
# Iter 11400 Loss 0.5016 Moving Loss 0.5005
# 0.2364661693572998 secs
# Iter 11500 Loss 0.5015 Moving Loss 0.5002
# 0.23592424392700195 secs
# Iter 11600 Loss 0.5015 Moving Loss 0.5000
# 0.24654245376586914 secs
# Iter 11700 Loss 0.5015 Moving Loss 0.5004
# 0.23465633392333984 secs
# Iter 11800 Loss 0.5015 Moving Loss 0.4998
# 0.23929858207702637 secs
# Iter 11900 Loss 0.5015 Moving Loss 0.5005
# 0.24041318893432617 secs
# Iter 12000 Loss 0.5015 Moving Loss 0.5002
# 0.2355794906616211 secs
# Iter 12100 Loss 0.5015 Moving Loss 0.5000
# 0.2353818416595459 secs
# Iter 12200 Loss 0.5015 Moving Loss 0.4999
# 0.23665308952331543 secs
# Iter 12300 Loss 0.5015 Moving Loss 0.5001
# 0.23527193069458008 secs
# Iter 12400 Loss 0.5014 Moving Loss 0.5002
# 0.23635530471801758 secs
# Iter 12500 Loss 0.5014 Moving Loss 0.4996
# 0.24557042121887207 secs
# Iter 12600 Loss 0.5014 Moving Loss 0.5000
# 0.24288344383239746 secs
# Iter 12700 Loss 0.5014 Moving Loss 0.5002
# 0.24146294593811035 secs
# Iter 12800 Loss 0.5014 Moving Loss 0.5001
# 0.23680496215820312 secs
# Iter 12900 Loss 0.5014 Moving Loss 0.5003
# 0.23619842529296875 secs
# Iter 13000 Loss 0.5014 Moving Loss 0.5002
# 0.23440337181091309 secs
# Iter 13100 Loss 0.5014 Moving Loss 0.5004
# 0.23549509048461914 secs
# Iter 13200 Loss 0.5014 Moving Loss 0.5007
# 0.23883342742919922 secs
# Iter 13300 Loss 0.5014 Moving Loss 0.5006
# 0.23695969581604004 secs
# Iter 13400 Loss 0.5014 Moving Loss 0.5001
# 0.23665976524353027 secs
# Iter 13500 Loss 0.5013 Moving Loss 0.5000
# 0.23570990562438965 secs
# Iter 13600 Loss 0.5013 Moving Loss 0.5003
# 0.23670291900634766 secs
# Iter 13700 Loss 0.5013 Moving Loss 0.5000
# 0.23485279083251953 secs
# Iter 13800 Loss 0.5013 Moving Loss 0.5006
# 0.24747753143310547 secs
# Iter 13900 Loss 0.5013 Moving Loss 0.5016
# 0.23987627029418945 secs
# Iter 14000 Loss 0.5013 Moving Loss 0.5002
# 0.23927807807922363 secs
# Iter 14100 Loss 0.5013 Moving Loss 0.5003
# 0.23566222190856934 secs
# Iter 14200 Loss 0.5013 Moving Loss 0.5005
# 0.23593997955322266 secs
# Iter 14300 Loss 0.5013 Moving Loss 0.4996
# 0.23629546165466309 secs
# Iter 14400 Loss 0.5013 Moving Loss 0.5001
# 0.24524450302124023 secs
# Iter 14500 Loss 0.5013 Moving Loss 0.4998
# 0.23864054679870605 secs
# Iter 14600 Loss 0.5013 Moving Loss 0.5005
# 0.24524998664855957 secs
# Iter 14700 Loss 0.5013 Moving Loss 0.5007
# 0.24679160118103027 secs
# Iter 14800 Loss 0.5013 Moving Loss 0.5005
# 0.2498784065246582 secs
# Iter 14900 Loss 0.5012 Moving Loss 0.5001
# 0.24712634086608887 secs
# Iter 15000 Loss 0.5012 Moving Loss 0.5010
# 0.2364656925201416 secs
# Iter 15100 Loss 0.5012 Moving Loss 0.5002
# 0.23487138748168945 secs
# Iter 15200 Loss 0.5012 Moving Loss 0.5001
# 0.23678135871887207 secs
# Iter 15300 Loss 0.5012 Moving Loss 0.5005
# 0.23972630500793457 secs
# Iter 15400 Loss 0.5012 Moving Loss 0.5001
# 0.23764801025390625 secs
# Iter 15500 Loss 0.5012 Moving Loss 0.5002
# 0.2360062599182129 secs
# Iter 15600 Loss 0.5012 Moving Loss 0.5002
# 0.23628449440002441 secs
# Iter 15700 Loss 0.5012 Moving Loss 0.5003
# 0.23685789108276367 secs
# Iter 15800 Loss 0.5012 Moving Loss 0.5001
# 0.23664093017578125 secs
# Iter 15900 Loss 0.5012 Moving Loss 0.5000
# 0.24479126930236816 secs
# Iter 16000 Loss 0.5012 Moving Loss 0.5001
# 0.2369537353515625 secs
# Iter 16100 Loss 0.5012 Moving Loss 0.5003
# 0.23658084869384766 secs
# Iter 16200 Loss 0.5012 Moving Loss 0.4999
# 0.2351551055908203 secs
# Iter 16300 Loss 0.5012 Moving Loss 0.5001
# 0.23581647872924805 secs
# Iter 16400 Loss 0.5012 Moving Loss 0.5004
# 0.24210667610168457 secs
# Iter 16500 Loss 0.5011 Moving Loss 0.5004
# 0.24219226837158203 secs
# Iter 16600 Loss 0.5011 Moving Loss 0.5003
# 0.23717045783996582 secs
# Iter 16700 Loss 0.5011 Moving Loss 0.5000
# 0.24848365783691406 secs
# Iter 16800 Loss 0.5011 Moving Loss 0.5001
# 0.26034069061279297 secs
# Iter 16900 Loss 0.5011 Moving Loss 0.5001
# 0.244964599609375 secs
# Iter 17000 Loss 0.5011 Moving Loss 0.5003
# 0.23671627044677734 secs
# Iter 17100 Loss 0.5011 Moving Loss 0.5003
# 0.23519086837768555 secs
# Iter 17200 Loss 0.5011 Moving Loss 0.5003
# 0.23543739318847656 secs
# Iter 17300 Loss 0.5011 Moving Loss 0.4999
# 0.2369675636291504 secs
# Iter 17400 Loss 0.5011 Moving Loss 0.5004
# 0.24585437774658203 secs
# Iter 17500 Loss 0.5011 Moving Loss 0.5005
# 0.23688697814941406 secs
# Iter 17600 Loss 0.5011 Moving Loss 0.5002
# 0.23611235618591309 secs
# Iter 17700 Loss 0.5011 Moving Loss 0.5001
# 0.23586678504943848 secs
# Iter 17800 Loss 0.5011 Moving Loss 0.5002
# 0.23772859573364258 secs
# Iter 17900 Loss 0.5011 Moving Loss 0.5001
# 0.23644423484802246 secs
# Iter 18000 Loss 0.5011 Moving Loss 0.5001
# 0.24823451042175293 secs
# Iter 18100 Loss 0.5011 Moving Loss 0.4999
# 0.24110150337219238 secs
# Iter 18200 Loss 0.5011 Moving Loss 0.5004
# 0.23870062828063965 secs
# Iter 18300 Loss 0.5011 Moving Loss 0.5000
# 0.25594258308410645 secs
# Iter 18400 Loss 0.5010 Moving Loss 0.4999
# 0.24392223358154297 secs
# Iter 18500 Loss 0.5010 Moving Loss 0.5002
# 0.2367725372314453 secs
# Iter 18600 Loss 0.5010 Moving Loss 0.5001
# 0.23444056510925293 secs
# Iter 18700 Loss 0.5010 Moving Loss 0.5001
# 0.23502898216247559 secs
# Iter 18800 Loss 0.5010 Moving Loss 0.5002
# 0.2544529438018799 secs
# Iter 18900 Loss 0.5010 Moving Loss 0.5004
# 0.2569289207458496 secs
# Iter 19000 Loss 0.5010 Moving Loss 0.5001
# 0.2614293098449707 secs
# Iter 19100 Loss 0.5010 Moving Loss 0.5007
# 0.2394857406616211 secs
# Iter 19200 Loss 0.5010 Moving Loss 0.5002
# 0.2354264259338379 secs
# Iter 19300 Loss 0.5010 Moving Loss 0.5002
# 0.23690462112426758 secs
# Iter 19400 Loss 0.5010 Moving Loss 0.4995
# 0.23881077766418457 secs
# Iter 19500 Loss 0.5010 Moving Loss 0.5005
# 0.2364959716796875 secs
# Iter 19600 Loss 0.5010 Moving Loss 0.5002
# 0.23518705368041992 secs
# Iter 19700 Loss 0.5010 Moving Loss 0.5001
# 0.23611021041870117 secs
# Iter 19800 Loss 0.5010 Moving Loss 0.4999
# 0.2355794906616211 secs
# Iter 19900 Loss 0.5010 Moving Loss 0.5000
# 0.23810458183288574 secs
# Iter 20000 Loss 0.5010 Moving Loss 0.5002
# 0.23740673065185547 secs
# Iter 20100 Loss 0.5010 Moving Loss 0.5000
# 0.23797821998596191 secs
# Iter 20200 Loss 0.5010 Moving Loss 0.4999
# 0.2462620735168457 secs
# Iter 20300 Loss 0.5010 Moving Loss 0.5000
# 0.2360391616821289 secs
# Iter 20400 Loss 0.5010 Moving Loss 0.5001
# 0.2362663745880127 secs
# Iter 20500 Loss 0.5010 Moving Loss 0.4999
# 0.2350165843963623 secs
# Iter 20600 Loss 0.5009 Moving Loss 0.4995
# 0.23662161827087402 secs
# Iter 20700 Loss 0.5009 Moving Loss 0.5000
# 0.23662948608398438 secs
# Iter 20800 Loss 0.5009 Moving Loss 0.5000
# 0.23555660247802734 secs
# Iter 20900 Loss 0.5009 Moving Loss 0.4999
# 0.2562863826751709 secs
# Iter 21000 Loss 0.5009 Moving Loss 0.5003
# 0.23873257637023926 secs
# Iter 21100 Loss 0.5009 Moving Loss 0.5000
# 0.23780345916748047 secs
# Iter 21200 Loss 0.5009 Moving Loss 0.4998
# 0.23558449745178223 secs
# Iter 21300 Loss 0.5009 Moving Loss 0.5006
# 0.23451924324035645 secs
# Iter 21400 Loss 0.5009 Moving Loss 0.5001
# 0.23551654815673828 secs
# Iter 21500 Loss 0.5009 Moving Loss 0.5001
# 0.239546537399292 secs
# Iter 21600 Loss 0.5009 Moving Loss 0.5000
# 0.23532891273498535 secs
# Iter 21700 Loss 0.5009 Moving Loss 0.5000
# 0.2350625991821289 secs
# Iter 21800 Loss 0.5009 Moving Loss 0.5002
# 0.23410367965698242 secs
# Iter 21900 Loss 0.5009 Moving Loss 0.5007
# 0.2349567413330078 secs
# Iter 22000 Loss 0.5009 Moving Loss 0.5003
# 0.23699641227722168 secs
# Iter 22100 Loss 0.5009 Moving Loss 0.5001
# 0.23497557640075684 secs
# Iter 22200 Loss 0.5009 Moving Loss 0.5000
# 0.23479366302490234 secs
# Iter 22300 Loss 0.5009 Moving Loss 0.5001
# 0.25156521797180176 secs
# Iter 22400 Loss 0.5009 Moving Loss 0.5003
# 0.2364823818206787 secs
# Iter 22500 Loss 0.5009 Moving Loss 0.5000
# 0.23727703094482422 secs
# Iter 22600 Loss 0.5009 Moving Loss 0.5001
# 0.23679852485656738 secs
# Iter 22700 Loss 0.5009 Moving Loss 0.5007
# 0.2375960350036621 secs
# Iter 22800 Loss 0.5009 Moving Loss 0.5001
# 0.23636841773986816 secs
# Iter 22900 Loss 0.5009 Moving Loss 0.4997
# 0.23554706573486328 secs
# Iter 23000 Loss 0.5009 Moving Loss 0.5000
# 0.24700093269348145 secs
# Iter 23100 Loss 0.5009 Moving Loss 0.5002
# 0.23707008361816406 secs
# Iter 23200 Loss 0.5009 Moving Loss 0.5001
# 0.2362208366394043 secs
# Iter 23300 Loss 0.5009 Moving Loss 0.5002
# 0.2357010841369629 secs
# Iter 23400 Loss 0.5008 Moving Loss 0.5002
# 0.2355198860168457 secs
# Iter 23500 Loss 0.5008 Moving Loss 0.5001
# 0.23522019386291504 secs
# Iter 23600 Loss 0.5008 Moving Loss 0.5002
# 0.2396092414855957 secs
# Iter 23700 Loss 0.5008 Moving Loss 0.5000
# 0.24466991424560547 secs
# Iter 23800 Loss 0.5008 Moving Loss 0.4999
# 0.23543262481689453 secs
# Iter 23900 Loss 0.5008 Moving Loss 0.5002
# 0.23495864868164062 secs
# Iter 24000 Loss 0.5008 Moving Loss 0.5004
# 0.23565435409545898 secs
# Iter 24100 Loss 0.5008 Moving Loss 0.5002
# 0.2365412712097168 secs
# Iter 24200 Loss 0.5008 Moving Loss 0.5000
# 0.2356107234954834 secs
# Iter 24300 Loss 0.5008 Moving Loss 0.4999
# 0.234999418258667 secs
# Iter 24400 Loss 0.5008 Moving Loss 0.5002
# 0.2533576488494873 secs
# Iter 24500 Loss 0.5008 Moving Loss 0.5002
# 0.24287867546081543 secs
# Iter 24600 Loss 0.5008 Moving Loss 0.5000
# 0.23568344116210938 secs
# Iter 24700 Loss 0.5008 Moving Loss 0.4998
# 0.23533034324645996 secs
# Iter 24800 Loss 0.5008 Moving Loss 0.5001
# 0.23672747611999512 secs
# Iter 24900 Loss 0.5008 Moving Loss 0.5002
# 0.23507928848266602 secs
# Iter 25000 Loss 0.5008 Moving Loss 0.5001
# 0.235184907913208 secs
# Iter 25100 Loss 0.5008 Moving Loss 0.5000
# 0.24622869491577148 secs
# Iter 25200 Loss 0.5008 Moving Loss 0.5000
# 0.23703360557556152 secs
# Iter 25300 Loss 0.5008 Moving Loss 0.4999
# 0.23559999465942383 secs
# Iter 25400 Loss 0.5008 Moving Loss 0.5005
# 0.23544931411743164 secs
# Iter 25500 Loss 0.5008 Moving Loss 0.4999
# 0.23369717597961426 secs
# Iter 25600 Loss 0.5008 Moving Loss 0.5000
# 0.2343909740447998 secs
# Iter 25700 Loss 0.5008 Moving Loss 0.5001
# 0.23615431785583496 secs
# Iter 25800 Loss 0.5008 Moving Loss 0.4999
# 0.23766565322875977 secs
# Iter 25900 Loss 0.5008 Moving Loss 0.5044
# 0.2355501651763916 secs
# Iter 26000 Loss 0.5008 Moving Loss 0.5038
# 0.2349252700805664 secs
# Iter 26100 Loss 0.5008 Moving Loss 0.5005
# 0.2366018295288086 secs
# Iter 26200 Loss 0.5008 Moving Loss 0.4999
# 0.2360076904296875 secs
# Iter 26300 Loss 0.5008 Moving Loss 0.5001
# 0.23582005500793457 secs
# Iter 26400 Loss 0.5008 Moving Loss 0.4998
# 0.2357943058013916 secs
# Iter 26500 Loss 0.5008 Moving Loss 0.5002
# 0.23787474632263184 secs
# Iter 26600 Loss 0.5008 Moving Loss 0.5002
# 0.24559354782104492 secs
# Iter 26700 Loss 0.5008 Moving Loss 0.4997
# 0.23538899421691895 secs
# Iter 26800 Loss 0.5008 Moving Loss 0.5000
# 0.23619413375854492 secs
# Iter 26900 Loss 0.5008 Moving Loss 0.5008
# 0.2389209270477295 secs
# Iter 27000 Loss 0.5008 Moving Loss 0.5001
# 0.23462915420532227 secs
# Iter 27100 Loss 0.5008 Moving Loss 0.5000
# 0.2359333038330078 secs
# Iter 27200 Loss 0.5008 Moving Loss 0.5002
# 0.2456977367401123 secs
# Iter 27300 Loss 0.5008 Moving Loss 0.5003
# 0.24204778671264648 secs
# Iter 27400 Loss 0.5008 Moving Loss 0.5000
# 0.24244308471679688 secs
# Iter 27500 Loss 0.5008 Moving Loss 0.5004
# 0.23612284660339355 secs
# Iter 27600 Loss 0.5008 Moving Loss 0.5001
# 0.2348647117614746 secs
# Iter 27700 Loss 0.5008 Moving Loss 0.5000
# 0.23483896255493164 secs
# Iter 27800 Loss 0.5008 Moving Loss 0.5002
# 0.23678922653198242 secs
# Iter 27900 Loss 0.5008 Moving Loss 0.5001
# 0.24934172630310059 secs
# Iter 28000 Loss 0.5008 Moving Loss 0.5002
# 0.23559904098510742 secs
# Iter 28100 Loss 0.5008 Moving Loss 0.5001
# 0.2344648838043213 secs
# Iter 28200 Loss 0.5008 Moving Loss 0.5000
# 0.23552751541137695 secs
# Iter 28300 Loss 0.5007 Moving Loss 0.5000
# 0.2360210418701172 secs
# Iter 28400 Loss 0.5007 Moving Loss 0.5002
# 0.23463106155395508 secs
# Iter 28500 Loss 0.5007 Moving Loss 0.4999
# 0.23442339897155762 secs
# Iter 28600 Loss 0.5007 Moving Loss 0.4998
# 0.24686360359191895 secs
# Iter 28700 Loss 0.5007 Moving Loss 0.4997
# 0.23717546463012695 secs
# Iter 28800 Loss 0.5007 Moving Loss 0.5004
# 0.2432563304901123 secs
# Iter 28900 Loss 0.5007 Moving Loss 0.5004
# 0.23476886749267578 secs
# Iter 29000 Loss 0.5007 Moving Loss 0.5001
# 0.2379152774810791 secs
# Iter 29100 Loss 0.5007 Moving Loss 0.5001
# 0.23511934280395508 secs
# Iter 29200 Loss 0.5007 Moving Loss 0.5001
# 0.23543095588684082 secs
# Iter 29300 Loss 0.5007 Moving Loss 0.5000
# 0.27434539794921875 secs
# Iter 29400 Loss 0.5007 Moving Loss 0.5004
# 0.2979588508605957 secs
# Iter 29500 Loss 0.5007 Moving Loss 0.5000
# 0.27176332473754883 secs
# Iter 29600 Loss 0.5007 Moving Loss 0.5000
# 0.2710599899291992 secs
# Iter 29700 Loss 0.5007 Moving Loss 0.5000
# 0.2698333263397217 secs
# Iter 29800 Loss 0.5007 Moving Loss 0.5002
# 0.27136754989624023 secs
# Iter 29900 Loss 0.5007 Moving Loss 0.5001
# 0.2781648635864258 secs
# Iter 30000 Loss 0.5007 Moving Loss 0.5000
# 0.27063846588134766 secs
# Iter 30100 Loss 0.5007 Moving Loss 0.5001
# 0.2723991870880127 secs
# Iter 30200 Loss 0.5007 Moving Loss 0.5003
# 0.2748274803161621 secs
# Iter 30300 Loss 0.5007 Moving Loss 0.5004
# 0.27217960357666016 secs
# Iter 30400 Loss 0.5007 Moving Loss 0.4999
# 0.2728080749511719 secs
# Iter 30500 Loss 0.5007 Moving Loss 0.5000
# 0.2882554531097412 secs
# Iter 30600 Loss 0.5007 Moving Loss 0.5002
# 0.2734100818634033 secs
# Iter 30700 Loss 0.5007 Moving Loss 0.4998
# 0.2837705612182617 secs
# Iter 30800 Loss 0.5007 Moving Loss 0.5002
# 0.27223968505859375 secs
# Iter 30900 Loss 0.5007 Moving Loss 0.5000
# 0.271411657333374 secs
# Iter 31000 Loss 0.5007 Moving Loss 0.5000
# 0.2737135887145996 secs
# Iter 31100 Loss 0.5007 Moving Loss 0.4999
# 0.2794535160064697 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/40-order_markov_chain_1000000.txt" is the same as "output/decom_mc_1m"
# ```
