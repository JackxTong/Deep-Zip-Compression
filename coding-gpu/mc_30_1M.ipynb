# %% [markdown]
# # Compression logs order-30 MC 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/30-order_markov_chain_1000000.txt output/30_mc_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/30_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/30-order_markov_chain_1000000.txt output/decom_mc_1m
# ```
#
# The file "Simulated-data/30-order_markov_chain_1000000.txt" is the same as "output/decom_mc_1m"

# %% [markdown]
# ### Compression Log
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash compress.sh Simulated-data/30-order_markov_chain_1000000.txt output/30_mc_1m.dzip com MODEL_PATH
# Seq Length 1999999
# Using cuda
# Vocab Size 3
# CudNN version 8902
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.5403146743774414 secs
# 3.609405994415283 secs/976 Average loss: 1.7884
# ====> Epoch: 1 Average loss: 0.5121813223: 0.5229
# Loss went from 100000000.0000 to 0.5122
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.25494980812072754 secs
# 3.3617048263549805 secs976 Average loss: 0.5085
# ====> Epoch: 2 Average loss: 0.5002775093: 0.5003
# Loss went from 0.5122 to 0.5003
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23830175399780273 secs
# 3.4540340900421143 secs976 Average loss: 0.4879
# ====> Epoch: 3 Average loss: 0.5001895537: 0.5006
# Loss went from 0.5003 to 0.5002
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2691519260406494 secs
# 3.450892925262451 secs/976 Average loss: 0.4907
# ====> Epoch: 4 Average loss: 0.5001281858: 0.4997
# Loss went from 0.5002 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.28321075439453125 secs
# 3.5480074882507324 secs976 Average loss: 0.4879
# ====> Epoch: 5 Average loss: 0.5001116166: 0.4995
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2723546028137207 secs
# 3.6643803119659424 secs976 Average loss: 0.4957
# ====> Epoch: 6 Average loss: 0.5000912223: 0.5001
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.26728200912475586 secs
# 3.4262919425964355 secs976 Average loss: 0.4834
# ====> Epoch: 7 Average loss: 0.5000769919: 0.5005
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23267436027526855 secs
# 3.4201295375823975 secs976 Average loss: 0.5034
# ====> Epoch: 8 Average loss: 0.5000654850: 0.5001
# Loss went from 0.5001 to 0.5001
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# 0.49313926696777344 secs
# Iter 100 Loss 0.5564 Moving Loss 0.5564 Train Loss 0.9106
# 0.2212202548980713 secs
# Iter 200 Loss 0.5305 Moving Loss 0.5046 Train Loss 0.5606
# 0.2208878993988037 secs
# Iter 300 Loss 0.5218 Moving Loss 0.5042 Train Loss 0.5374
# 0.22598052024841309 secs
# Iter 400 Loss 0.5185 Moving Loss 0.5086 Train Loss 0.5342
# 0.22737455368041992 secs
# Iter 500 Loss 0.5150 Moving Loss 0.5011 Train Loss 0.5160
# 0.2319660186767578 secs
# Iter 600 Loss 0.5136 Moving Loss 0.5069 Train Loss 0.5317
# 0.22411322593688965 secs
# Iter 700 Loss 0.5122 Moving Loss 0.5039 Train Loss 0.5134
# 0.22066378593444824 secs
# Iter 800 Loss 0.5108 Moving Loss 0.5008 Train Loss 0.5087
# 0.22157812118530273 secs
# Iter 900 Loss 0.5098 Moving Loss 0.5015 Train Loss 0.5070
# 0.22048282623291016 secs
# Iter 1000 Loss 0.5091 Moving Loss 0.5034 Train Loss 0.5100
# 0.22471022605895996 secs
# Iter 1100 Loss 0.5086 Moving Loss 0.5027 Train Loss 0.5194
# 0.23302197456359863 secs
# Iter 1200 Loss 0.5079 Moving Loss 0.5011 Train Loss 0.5050
# 0.22479486465454102 secs
# Iter 1300 Loss 0.5074 Moving Loss 0.5009 Train Loss 0.5070
# 0.22604680061340332 secs
# Iter 1400 Loss 0.5070 Moving Loss 0.5023 Train Loss 0.5100
# 0.2199687957763672 secs
# Iter 1500 Loss 0.5066 Moving Loss 0.5006 Train Loss 0.5025
# 0.22240400314331055 secs
# Iter 1600 Loss 0.5062 Moving Loss 0.5000 Train Loss 0.5029
# 0.21981334686279297 secs
# Iter 1700 Loss 0.5061 Moving Loss 0.5045 Train Loss 0.5170
# 0.22115516662597656 secs
# Iter 1800 Loss 0.5059 Moving Loss 0.5029 Train Loss 0.5111
# 0.22053098678588867 secs
# Iter 1900 Loss 0.5057 Moving Loss 0.5010 Train Loss 0.5035
# 0.22039461135864258 secs
# Iter 2000 Loss 0.5054 Moving Loss 0.5009 Train Loss 0.5036
# 0.2205219268798828 secs
# Iter 2100 Loss 0.5052 Moving Loss 0.5001 Train Loss 0.5034
# 0.22205662727355957 secs
# Iter 2200 Loss 0.5050 Moving Loss 0.5020 Train Loss 0.5063
# 0.21966767311096191 secs
# Iter 2300 Loss 0.5048 Moving Loss 0.4999 Train Loss 0.5012
# 0.21982455253601074 secs
# Iter 2400 Loss 0.5046 Moving Loss 0.5004 Train Loss 0.5024
# 0.22057151794433594 secs
# Iter 2500 Loss 0.5045 Moving Loss 0.5012 Train Loss 0.5049
# 0.2201371192932129 secs
# Iter 2600 Loss 0.5043 Moving Loss 0.5005 Train Loss 0.5027
# 0.2322709560394287 secs
# Iter 2700 Loss 0.5042 Moving Loss 0.5005 Train Loss 0.5033
# 0.2272932529449463 secs
# Iter 2800 Loss 0.5041 Moving Loss 0.5011 Train Loss 0.5020
# 0.22342371940612793 secs
# Iter 2900 Loss 0.5040 Moving Loss 0.5013 Train Loss 0.5062
# 0.2211446762084961 secs
# Iter 3000 Loss 0.5038 Moving Loss 0.5000 Train Loss 0.5032
# 0.2216029167175293 secs
# Iter 3100 Loss 0.5037 Moving Loss 0.4997 Train Loss 0.5005
# 0.21979904174804688 secs
# Iter 3200 Loss 0.5036 Moving Loss 0.5001 Train Loss 0.5009
# 0.21986722946166992 secs
# Iter 3300 Loss 0.5035 Moving Loss 0.5008 Train Loss 0.5030
# 0.22979187965393066 secs
# Iter 3400 Loss 0.5034 Moving Loss 0.5004 Train Loss 0.5027
# 0.22889328002929688 secs
# Iter 3500 Loss 0.5033 Moving Loss 0.5004 Train Loss 0.5027
# 0.22749829292297363 secs
# Iter 3600 Loss 0.5032 Moving Loss 0.5001 Train Loss 0.5008
# 0.22620201110839844 secs
# Iter 3700 Loss 0.5033 Moving Loss 0.5043 Train Loss 0.5167
# 0.22116756439208984 secs
# Iter 3800 Loss 0.5032 Moving Loss 0.5007 Train Loss 0.5030
# 0.2196028232574463 secs
# Iter 3900 Loss 0.5032 Moving Loss 0.5037 Train Loss 0.5137
# 0.22022008895874023 secs
# Iter 4000 Loss 0.5031 Moving Loss 0.5003 Train Loss 0.5027
# 0.22001361846923828 secs
# Iter 4100 Loss 0.5031 Moving Loss 0.5016 Train Loss 0.5046
# 0.21932578086853027 secs
# Iter 4200 Loss 0.5030 Moving Loss 0.5008 Train Loss 0.5014
# 0.22017884254455566 secs
# Iter 4300 Loss 0.5030 Moving Loss 0.5012 Train Loss 0.5048
# 0.21998047828674316 secs
# Iter 4400 Loss 0.5029 Moving Loss 0.5005 Train Loss 0.5026
# 0.2197401523590088 secs
# Iter 4500 Loss 0.5029 Moving Loss 0.5014 Train Loss 0.5020
# 0.22052550315856934 secs
# Iter 4600 Loss 0.5029 Moving Loss 0.5006 Train Loss 0.5042
# 0.22013521194458008 secs
# Iter 4700 Loss 0.5028 Moving Loss 0.5001 Train Loss 0.5015
# 0.22002100944519043 secs
# Iter 4800 Loss 0.5028 Moving Loss 0.5019 Train Loss 0.5040
# 0.23012781143188477 secs
# Iter 4900 Loss 0.5030 Moving Loss 0.5136 Train Loss 0.5883
# 0.22605085372924805 secs
# Iter 5000 Loss 0.5030 Moving Loss 0.5048 Train Loss 0.5308
# 0.22953009605407715 secs
# Iter 5100 Loss 0.5030 Moving Loss 0.5014 Train Loss 0.5041
# 0.224015474319458 secs
# Iter 5200 Loss 0.5030 Moving Loss 0.5010 Train Loss 0.5045
# 0.22054624557495117 secs
# Iter 5300 Loss 0.5029 Moving Loss 0.5002 Train Loss 0.5012
# 0.2217090129852295 secs
# Iter 5400 Loss 0.5029 Moving Loss 0.5012 Train Loss 0.5020
# 0.22070074081420898 secs
# Iter 5500 Loss 0.5028 Moving Loss 0.5007 Train Loss 0.5048
# 0.22027897834777832 secs
# Iter 5600 Loss 0.5029 Moving Loss 0.5059 Train Loss 0.5192
# 0.23867559432983398 secs
# Iter 5700 Loss 0.5029 Moving Loss 0.5007 Train Loss 0.5045
# 0.2268514633178711 secs
# Iter 5800 Loss 0.5028 Moving Loss 0.5003 Train Loss 0.5019
# 0.22227764129638672 secs
# Iter 5900 Loss 0.5028 Moving Loss 0.5007 Train Loss 0.5022
# 0.22249698638916016 secs
# Iter 6000 Loss 0.5027 Moving Loss 0.5000 Train Loss 0.5006
# 0.2217388153076172 secs
# Iter 6100 Loss 0.5027 Moving Loss 0.4999 Train Loss 0.5002
# 0.2203066349029541 secs
# Iter 6200 Loss 0.5027 Moving Loss 0.5006 Train Loss 0.5019
# 0.22002005577087402 secs
# Iter 6300 Loss 0.5026 Moving Loss 0.5005 Train Loss 0.5016
# 0.22057890892028809 secs
# Iter 6400 Loss 0.5026 Moving Loss 0.5000 Train Loss 0.5008
# 0.22095656394958496 secs
# Iter 6500 Loss 0.5026 Moving Loss 0.5006 Train Loss 0.5031
# 0.22100591659545898 secs
# Iter 6600 Loss 0.5025 Moving Loss 0.5001 Train Loss 0.5008
# 0.2237851619720459 secs
# Iter 6700 Loss 0.5025 Moving Loss 0.5001 Train Loss 0.5005
# 0.23322343826293945 secs
# Iter 6800 Loss 0.5025 Moving Loss 0.5004 Train Loss 0.5018
# 0.23299193382263184 secs
# Iter 6900 Loss 0.5024 Moving Loss 0.5001 Train Loss 0.5006
# 0.22739291191101074 secs
# Iter 7000 Loss 0.5024 Moving Loss 0.5001 Train Loss 0.5009
# 0.22443628311157227 secs
# Iter 7100 Loss 0.5023 Moving Loss 0.4999 Train Loss 0.5001
# 0.2240755558013916 secs
# Iter 7200 Loss 0.5023 Moving Loss 0.5008 Train Loss 0.5009
# 0.23659348487854004 secs
# Iter 7300 Loss 0.5023 Moving Loss 0.5000 Train Loss 0.5021
# 0.24330353736877441 secs
# Iter 7400 Loss 0.5023 Moving Loss 0.5006 Train Loss 0.5017
# 0.22040224075317383 secs
# Iter 7500 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5005
# 0.2219078540802002 secs
# Iter 7600 Loss 0.5022 Moving Loss 0.5012 Train Loss 0.5020
# 0.21958374977111816 secs
# Iter 7700 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5024
# 0.22172236442565918 secs
# Iter 7800 Loss 0.5022 Moving Loss 0.5000 Train Loss 0.5004
# 0.23754405975341797 secs
# Iter 7900 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5003
# 0.24345159530639648 secs
# Iter 8000 Loss 0.5021 Moving Loss 0.5006 Train Loss 0.5021
# 0.2314751148223877 secs
# Iter 8100 Loss 0.5021 Moving Loss 0.5007 Train Loss 0.5016
# 0.22273588180541992 secs
# Iter 8200 Loss 0.5021 Moving Loss 0.5003 Train Loss 0.5014
# 0.22115778923034668 secs
# Iter 8300 Loss 0.5021 Moving Loss 0.5001 Train Loss 0.5002
# 0.22010135650634766 secs
# Iter 8400 Loss 0.5021 Moving Loss 0.5008 Train Loss 0.5013
# 0.22018146514892578 secs
# Iter 8500 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5014
# 0.22126054763793945 secs
# Iter 8600 Loss 0.5020 Moving Loss 0.5006 Train Loss 0.5018
# 0.22040462493896484 secs
# Iter 8700 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5003
# 0.22000575065612793 secs
# Iter 8800 Loss 0.5020 Moving Loss 0.5005 Train Loss 0.5014
# 0.22009515762329102 secs
# Iter 8900 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5006
# 0.21967053413391113 secs
# Iter 9000 Loss 0.5019 Moving Loss 0.4996 Train Loss 0.5003
# 0.2197251319885254 secs
# Iter 9100 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5004
# 0.2204453945159912 secs
# Iter 9200 Loss 0.5019 Moving Loss 0.5006 Train Loss 0.5016
# 0.22195076942443848 secs
# Iter 9300 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5007
# 0.23621249198913574 secs
# Iter 9400 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5007
# 0.22129368782043457 secs
# Iter 9500 Loss 0.5018 Moving Loss 0.5008 Train Loss 0.5015
# 0.22022104263305664 secs
# Iter 9600 Loss 0.5018 Moving Loss 0.4999 Train Loss 0.5011
# 0.23094463348388672 secs
# Iter 9700 Loss 0.5018 Moving Loss 0.5009 Train Loss 0.5023
# 0.22395825386047363 secs
# Iter 9800 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5010
# 0.221663236618042 secs
# Iter 9900 Loss 0.5018 Moving Loss 0.5004 Train Loss 0.5006
# 0.22144460678100586 secs
# Iter 10000 Loss 0.5018 Moving Loss 0.5003 Train Loss 0.5015
# 0.23189115524291992 secs
# Iter 10100 Loss 0.5018 Moving Loss 0.5007 Train Loss 0.5020
# 0.21995782852172852 secs
# Iter 10200 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5012
# 0.21770119667053223 secs
# Iter 10300 Loss 0.5017 Moving Loss 0.5003 Train Loss 0.5010
# 0.21846580505371094 secs
# Iter 10400 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5005
# 0.22066020965576172 secs
# Iter 10500 Loss 0.5017 Moving Loss 0.5014 Train Loss 0.5034
# 0.21761393547058105 secs
# Iter 10600 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5021
# 0.21822571754455566 secs
# Iter 10700 Loss 0.5017 Moving Loss 0.5002 Train Loss 0.5007
# 0.2176346778869629 secs
# Iter 10800 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5003
# 0.21770668029785156 secs
# Iter 10900 Loss 0.5016 Moving Loss 0.4999 Train Loss 0.5005
# 0.21773409843444824 secs
# Iter 11000 Loss 0.5016 Moving Loss 0.4997 Train Loss 0.4996
# 0.217911958694458 secs
# Iter 11100 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5003
# 0.21782469749450684 secs
# Iter 11200 Loss 0.5016 Moving Loss 0.5004 Train Loss 0.5019
# 0.21911835670471191 secs
# Iter 11300 Loss 0.5016 Moving Loss 0.4998 Train Loss 0.5006
# 0.217634916305542 secs
# Iter 11400 Loss 0.5016 Moving Loss 0.5004 Train Loss 0.5014
# 0.2199716567993164 secs
# Iter 11500 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5008
# 0.21981596946716309 secs
# Iter 11600 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5007
# 0.2256302833557129 secs
# Iter 11700 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5010
# 0.21825766563415527 secs
# Iter 11800 Loss 0.5015 Moving Loss 0.5008 Train Loss 0.5024
# 0.2182457447052002 secs
# Iter 11900 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.5003
# 0.22761011123657227 secs
# Iter 12000 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5001
# 0.21842479705810547 secs
# Iter 12100 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5014
# 0.21810436248779297 secs
# Iter 12200 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5004
# 0.21763920783996582 secs
# Iter 12300 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5009
# 0.23659706115722656 secs
# Iter 12400 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5012
# 0.2236328125 secs
# Iter 12500 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5008
# 0.22438383102416992 secs
# Iter 12600 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.4999
# 0.22161269187927246 secs
# Iter 12700 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5018
# 0.21854329109191895 secs
# Iter 12800 Loss 0.5014 Moving Loss 0.5003 Train Loss 0.5003
# 0.21785664558410645 secs
# Iter 12900 Loss 0.5014 Moving Loss 0.5004 Train Loss 0.5019
# 0.21770358085632324 secs
# Iter 13000 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5007
# 0.21784520149230957 secs
# Iter 13100 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.5002
# 0.21776199340820312 secs
# Iter 13200 Loss 0.5014 Moving Loss 0.5004 Train Loss 0.5016
# 0.21780610084533691 secs
# Iter 13300 Loss 0.5014 Moving Loss 0.5004 Train Loss 0.5002
# 0.21772980690002441 secs
# Iter 13400 Loss 0.5014 Moving Loss 0.4993 Train Loss 0.5005
# 0.21775436401367188 secs
# Iter 13500 Loss 0.5014 Moving Loss 0.4998 Train Loss 0.5009
# 0.217850923538208 secs
# Iter 13600 Loss 0.5014 Moving Loss 0.5008 Train Loss 0.5016
# 0.2182633876800537 secs
# Iter 13700 Loss 0.5013 Moving Loss 0.4999 Train Loss 0.5001
# 0.21798968315124512 secs
# Iter 13800 Loss 0.5013 Moving Loss 0.4999 Train Loss 0.5002
# 0.22513151168823242 secs
# Iter 13900 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5004
# 0.22237205505371094 secs
# Iter 14000 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5008
# 0.2175610065460205 secs
# Iter 14100 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5006
# 0.21786928176879883 secs
# Iter 14200 Loss 0.5013 Moving Loss 0.5006 Train Loss 0.5013
# 0.22474050521850586 secs
# Iter 14300 Loss 0.5013 Moving Loss 0.5007 Train Loss 0.5036
# 0.22087359428405762 secs
# Iter 14400 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5007
# 0.21763849258422852 secs
# Iter 14500 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5009
# 0.21786808967590332 secs
# Iter 14600 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5009
# 0.24161148071289062 secs
# Iter 14700 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5000
# 0.23763251304626465 secs
# Iter 14800 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5007
# 0.22762632369995117 secs
# Iter 14900 Loss 0.5013 Moving Loss 0.5012 Train Loss 0.5028
# 0.22095179557800293 secs
# Iter 15000 Loss 0.5012 Moving Loss 0.4993 Train Loss 0.5004
# 0.21744370460510254 secs
# Iter 15100 Loss 0.5012 Moving Loss 0.5009 Train Loss 0.5018
# 0.21825909614562988 secs
# Iter 15200 Loss 0.5012 Moving Loss 0.4996 Train Loss 0.5000
# 0.2183539867401123 secs
# Iter 15300 Loss 0.5012 Moving Loss 0.4997 Train Loss 0.4997
# 0.21790432929992676 secs
# Iter 15400 Loss 0.5012 Moving Loss 0.4998 Train Loss 0.5001
# 0.21759438514709473 secs
# Iter 15500 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5000
# 0.21753764152526855 secs
# Iter 15600 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5010
# 0.21767449378967285 secs
# Iter 15700 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5006
# 0.21889805793762207 secs
# Iter 15800 Loss 0.5012 Moving Loss 0.4998 Train Loss 0.4998
# 0.21742510795593262 secs
# Iter 15900 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5005
# 0.21729183197021484 secs
# Iter 16000 Loss 0.5012 Moving Loss 0.5005 Train Loss 0.5010
# 0.22092366218566895 secs
# Iter 16100 Loss 0.5012 Moving Loss 0.5004 Train Loss 0.5010
# 0.2301955223083496 secs
# Iter 16200 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5008
# 0.22152376174926758 secs
# Iter 16300 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.21732378005981445 secs
# Iter 16400 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5006
# 0.21743011474609375 secs
# Iter 16500 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5008
# 0.21823430061340332 secs
# Iter 16600 Loss 0.5012 Moving Loss 0.5045 Train Loss 0.5121
# 0.22688055038452148 secs
# Iter 16700 Loss 0.5012 Moving Loss 0.5091 Train Loss 0.5628
# 0.2172527313232422 secs
# Iter 16800 Loss 0.5012 Moving Loss 0.5005 Train Loss 0.5031
# 0.23022890090942383 secs
# Iter 16900 Loss 0.5012 Moving Loss 0.5011 Train Loss 0.5042
# 0.22368383407592773 secs
# Iter 17000 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5013
# 0.22252154350280762 secs
# Iter 17100 Loss 0.5012 Moving Loss 0.5003 Train Loss 0.5011
# 0.21800756454467773 secs
# Iter 17200 Loss 0.5012 Moving Loss 0.4999 Train Loss 0.5007
# 0.22186064720153809 secs
# Iter 17300 Loss 0.5012 Moving Loss 0.4998 Train Loss 0.5003
# 0.21827268600463867 secs
# Iter 17400 Loss 0.5012 Moving Loss 0.4999 Train Loss 0.5007
# 0.21819663047790527 secs
# Iter 17500 Loss 0.5012 Moving Loss 0.5004 Train Loss 0.5010
# 0.2179880142211914 secs
# Iter 17600 Loss 0.5012 Moving Loss 0.5005 Train Loss 0.5013
# 0.21759819984436035 secs
# Iter 17700 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5003
# 0.21987605094909668 secs
# Iter 17800 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.217940092086792 secs
# Iter 17900 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5007
# 0.21789240837097168 secs
# Iter 18000 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5023
# 0.21790552139282227 secs
# Iter 18100 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.2178783416748047 secs
# Iter 18200 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5015
# 0.21815967559814453 secs
# Iter 18300 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.22396254539489746 secs
# Iter 18400 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5008
# 0.22439002990722656 secs
# Iter 18500 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.21834015846252441 secs
# Iter 18600 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.21822547912597656 secs
# Iter 18700 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5001
# 0.21844935417175293 secs
# Iter 18800 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5005
# 0.2188408374786377 secs
# Iter 18900 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5004
# 0.22803688049316406 secs
# Iter 19000 Loss 0.5011 Moving Loss 0.4998 Train Loss 0.5000
# 0.21859145164489746 secs
# Iter 19100 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5007
# 0.23686742782592773 secs
# Iter 19200 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.22569584846496582 secs
# Iter 19300 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.22003602981567383 secs
# Iter 19400 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.4999
# 0.21820735931396484 secs
# Iter 19500 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5002
# 0.22013044357299805 secs
# Iter 19600 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5008
# 0.2178027629852295 secs
# Iter 19700 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5002
# 0.217390775680542 secs
# Iter 19800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5003
# 0.21796536445617676 secs
# Iter 19900 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5006
# 0.21859073638916016 secs
# Iter 20000 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5008
# 0.21795034408569336 secs
# Iter 20100 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5003
# 0.21808171272277832 secs
# Iter 20200 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5005
# 0.21859145164489746 secs
# Iter 20300 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5007
# 0.2178802490234375 secs
# Iter 20400 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5005
# 0.21834325790405273 secs
# Iter 20500 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5005
# 0.2189474105834961 secs
# Iter 20600 Loss 0.5010 Moving Loss 0.4998 Train Loss 0.4998
# 0.22484993934631348 secs
# Iter 20700 Loss 0.5010 Moving Loss 0.4998 Train Loss 0.4996
# 0.22832822799682617 secs
# Iter 20800 Loss 0.5010 Moving Loss 0.4997 Train Loss 0.5000
# 0.22225546836853027 secs
# Iter 20900 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5005
# 0.23183155059814453 secs
# Iter 21000 Loss 0.5010 Moving Loss 0.5031 Train Loss 0.5107
# 0.21907615661621094 secs
# Iter 21100 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5009
# 0.21798443794250488 secs
# Iter 21200 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5003
# 0.22863388061523438 secs
# Iter 21300 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5005
# 0.229156494140625 secs
# Iter 21400 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5002
# 0.2220780849456787 secs
# Iter 21500 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5007
# 0.22297215461730957 secs
# Iter 21600 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.22151494026184082 secs
# Iter 21700 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5006
# 0.22990942001342773 secs
# Iter 21800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5002
# 0.2200620174407959 secs
# Iter 21900 Loss 0.5010 Moving Loss 0.5007 Train Loss 0.5013
# 0.21824193000793457 secs
# Iter 22000 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5011
# 0.21820497512817383 secs
# Iter 22100 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5001
# 0.21780085563659668 secs
# Iter 22200 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5004
# 0.2231297492980957 secs
# Iter 22300 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5002
# 0.21834588050842285 secs
# Iter 22400 Loss 0.5009 Moving Loss 0.5004 Train Loss 0.5009
# 0.21812057495117188 secs
# Iter 22500 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5010
# 0.21831154823303223 secs
# Iter 22600 Loss 0.5009 Moving Loss 0.5004 Train Loss 0.5010
# 0.2191319465637207 secs
# Iter 22700 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5008
# 0.22628068923950195 secs
# Iter 22800 Loss 0.5009 Moving Loss 0.5004 Train Loss 0.5009
# 0.21948528289794922 secs
# Iter 22900 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5004
# 0.21923017501831055 secs
# Iter 23000 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5001
# 0.21810245513916016 secs
# Iter 23100 Loss 0.5009 Moving Loss 0.5007 Train Loss 0.5017
# 0.22004079818725586 secs
# Iter 23200 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5000
# 0.2192842960357666 secs
# Iter 23300 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5006
# 0.22010135650634766 secs
# Iter 23400 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5004
# 0.21863937377929688 secs
# Iter 23500 Loss 0.5009 Moving Loss 0.4998 Train Loss 0.5001
# 0.23092055320739746 secs
# Iter 23600 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5007
# 0.24080562591552734 secs
# Iter 23700 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5006
# 0.24681949615478516 secs
# Iter 23800 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5005
# 0.23029422760009766 secs
# Iter 23900 Loss 0.5009 Moving Loss 0.5005 Train Loss 0.5014
# 0.21871089935302734 secs
# Iter 24000 Loss 0.5009 Moving Loss 0.4999 Train Loss 0.5002
# 0.22178244590759277 secs
# Iter 24100 Loss 0.5009 Moving Loss 0.5001 Train Loss 0.5002
# 0.2189803123474121 secs
# Iter 24200 Loss 0.5009 Moving Loss 0.5003 Train Loss 0.5002
# 0.21903395652770996 secs
# Iter 24300 Loss 0.5009 Moving Loss 0.4999 Train Loss 0.5011
# 0.21862149238586426 secs
# Iter 24400 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5000
# 0.21990036964416504 secs
# Iter 24500 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5009
# 0.2186422348022461 secs
# Iter 24600 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5001
# 0.21896576881408691 secs
# Iter 24700 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5005
# 0.21865034103393555 secs
# Iter 24800 Loss 0.5009 Moving Loss 0.5003 Train Loss 0.5007
# 0.22108840942382812 secs
# Iter 24900 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5009
# 0.21855974197387695 secs
# Iter 25000 Loss 0.5009 Moving Loss 0.5000 Train Loss 0.5002
# 0.21925044059753418 secs
# Iter 25100 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5006
# 0.2212381362915039 secs
# Iter 25200 Loss 0.5009 Moving Loss 0.5002 Train Loss 0.5007
# 0.22861886024475098 secs
# Iter 25300 Loss 0.5009 Moving Loss 0.4998 Train Loss 0.5001
# 0.21948862075805664 secs
# Iter 25400 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5002
# 0.21866655349731445 secs
# Iter 25500 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5001
# 0.218963623046875 secs
# Iter 25600 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5004
# 0.21865391731262207 secs
# Iter 25700 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5005
# 0.2188570499420166 secs
# Iter 25800 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5005
# 0.23782753944396973 secs
# Iter 25900 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5003
# 0.22803258895874023 secs
# Iter 26000 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5004
# 0.22554588317871094 secs
# Iter 26100 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5004
# 0.2252657413482666 secs
# Iter 26200 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5013
# 0.22307586669921875 secs
# Iter 26300 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5003
# 0.21890473365783691 secs
# Iter 26400 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5005
# 0.218841552734375 secs
# Iter 26500 Loss 0.5008 Moving Loss 0.4997 Train Loss 0.4997
# 0.21903276443481445 secs
# Iter 26600 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5004
# 0.21878647804260254 secs
# Iter 26700 Loss 0.5008 Moving Loss 0.4997 Train Loss 0.5006
# 0.21958231925964355 secs
# Iter 26800 Loss 0.5008 Moving Loss 0.5008 Train Loss 0.5015
# 0.2188549041748047 secs
# Iter 26900 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5007
# 0.21846604347229004 secs
# Iter 27000 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5004
# 0.21858954429626465 secs
# Iter 27100 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5007
# 0.21881937980651855 secs
# Iter 27200 Loss 0.5008 Moving Loss 0.4997 Train Loss 0.4998
# 0.21849656105041504 secs
# Iter 27300 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5009
# 0.22240090370178223 secs
# Iter 27400 Loss 0.5008 Moving Loss 0.5005 Train Loss 0.5009
# 0.22118639945983887 secs
# Iter 27500 Loss 0.5008 Moving Loss 0.4998 Train Loss 0.5004
# 0.21972918510437012 secs
# Iter 27600 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5006
# 0.21874308586120605 secs
# Iter 27700 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5001
# 0.21820688247680664 secs
# Iter 27800 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5001
# 0.218644380569458 secs
# Iter 27900 Loss 0.5008 Moving Loss 0.5004 Train Loss 0.5011
# 0.21835541725158691 secs
# Iter 28000 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5006
# 0.219329833984375 secs
# Iter 28100 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5005
# 0.23763585090637207 secs
# Iter 28200 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5005
# 0.22411394119262695 secs
# Iter 28300 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5002
# 0.22141003608703613 secs
# Iter 28400 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5003
# 0.21888995170593262 secs
# Iter 28500 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5000
# 0.22190499305725098 secs
# Iter 28600 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5003
# 0.2188434600830078 secs
# Iter 28700 Loss 0.5008 Moving Loss 0.5002 Train Loss 0.5005
# 0.2192518711090088 secs
# Iter 28800 Loss 0.5008 Moving Loss 0.4999 Train Loss 0.5001
# 0.21857881546020508 secs
# Iter 28900 Loss 0.5008 Moving Loss 0.5000 Train Loss 0.5001
# 0.21921634674072266 secs
# Iter 29000 Loss 0.5008 Moving Loss 0.5003 Train Loss 0.5008
# 0.22067928314208984 secs
# Iter 29100 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5004
# 0.21880865097045898 secs
# Iter 29200 Loss 0.5008 Moving Loss 0.5001 Train Loss 0.5000
# 0.21913719177246094 secs
# Iter 29300 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5013
# 0.21838617324829102 secs
# Iter 29400 Loss 0.5007 Moving Loss 0.5004 Train Loss 0.5010
# 0.21992969512939453 secs
# Iter 29500 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5001
# 0.2183990478515625 secs
# Iter 29600 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5006
# 0.2216944694519043 secs
# Iter 29700 Loss 0.5007 Moving Loss 0.5002 Train Loss 0.5007
# 0.22475743293762207 secs
# Iter 29800 Loss 0.5007 Moving Loss 0.4998 Train Loss 0.5000
# 0.2195889949798584 secs
# Iter 29900 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5004
# 0.21884822845458984 secs
# Iter 30000 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5001
# 0.21871089935302734 secs
# Iter 30100 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5003
# 0.2196204662322998 secs
# Iter 30200 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5000
# 0.21843433380126953 secs
# Iter 30300 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5002
# 0.21866679191589355 secs
# Iter 30400 Loss 0.5007 Moving Loss 0.4997 Train Loss 0.5002
# 0.24211692810058594 secs
# Iter 30500 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5001
# 0.22577571868896484 secs
# Iter 30600 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5000
# 0.22461485862731934 secs
# Iter 30700 Loss 0.5007 Moving Loss 0.5003 Train Loss 0.5009
# 0.2229447364807129 secs
# Iter 30800 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5006
# 0.22144031524658203 secs
# Iter 30900 Loss 0.5007 Moving Loss 0.4999 Train Loss 0.5002
# 0.2197408676147461 secs
# Iter 31000 Loss 0.5007 Moving Loss 0.5000 Train Loss 0.5002
# 0.2197887897491455 secs
# Iter 31100 Loss 0.5007 Moving Loss 0.5001 Train Loss 0.5003
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash decompress.sh output/30_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5564 Moving Loss 0.5564
# 0.5307531356811523 secs
# Iter 200 Loss 0.5305 Moving Loss 0.5046
# 0.2377007007598877 secs
# Iter 300 Loss 0.5218 Moving Loss 0.5042
# 0.24600958824157715 secs
# Iter 400 Loss 0.5185 Moving Loss 0.5086
# 0.23850655555725098 secs
# Iter 500 Loss 0.5150 Moving Loss 0.5011
# 0.27901744842529297 secs
# Iter 600 Loss 0.5136 Moving Loss 0.5069
# 0.2403867244720459 secs
# Iter 700 Loss 0.5122 Moving Loss 0.5039
# 0.23735570907592773 secs
# Iter 800 Loss 0.5108 Moving Loss 0.5008
# 0.23911595344543457 secs
# Iter 900 Loss 0.5098 Moving Loss 0.5015
# 0.23644280433654785 secs
# Iter 1000 Loss 0.5091 Moving Loss 0.5034
# 0.2368001937866211 secs
# Iter 1100 Loss 0.5086 Moving Loss 0.5027
# 0.23601913452148438 secs
# Iter 1200 Loss 0.5079 Moving Loss 0.5011
# 0.24138474464416504 secs
# Iter 1300 Loss 0.5074 Moving Loss 0.5009
# 0.23867559432983398 secs
# Iter 1400 Loss 0.5070 Moving Loss 0.5023
# 0.23685169219970703 secs
# Iter 1500 Loss 0.5066 Moving Loss 0.5006
# 0.2385847568511963 secs
# Iter 1600 Loss 0.5062 Moving Loss 0.5000
# 0.236724853515625 secs
# Iter 1700 Loss 0.5061 Moving Loss 0.5045
# 0.23644018173217773 secs
# Iter 1800 Loss 0.5059 Moving Loss 0.5029
# 0.2416374683380127 secs
# Iter 1900 Loss 0.5057 Moving Loss 0.5010
# 0.2519257068634033 secs
# Iter 2000 Loss 0.5054 Moving Loss 0.5009
# 0.23694872856140137 secs
# Iter 2100 Loss 0.5052 Moving Loss 0.5001
# 0.23585724830627441 secs
# Iter 2200 Loss 0.5050 Moving Loss 0.5020
# 0.23840713500976562 secs
# Iter 2300 Loss 0.5048 Moving Loss 0.4999
# 0.23742198944091797 secs
# Iter 2400 Loss 0.5046 Moving Loss 0.5004
# 0.2385575771331787 secs
# Iter 2500 Loss 0.5045 Moving Loss 0.5012
# 0.2487330436706543 secs
# Iter 2600 Loss 0.5043 Moving Loss 0.5005
# 0.2580568790435791 secs
# Iter 2700 Loss 0.5042 Moving Loss 0.5005
# 0.2557241916656494 secs
# Iter 2800 Loss 0.5041 Moving Loss 0.5011
# 0.23987507820129395 secs
# Iter 2900 Loss 0.5040 Moving Loss 0.5013
# 0.2366175651550293 secs
# Iter 3000 Loss 0.5038 Moving Loss 0.5000
# 0.23729991912841797 secs
# Iter 3100 Loss 0.5037 Moving Loss 0.4997
# 0.23619794845581055 secs
# Iter 3200 Loss 0.5036 Moving Loss 0.5001
# 0.23604774475097656 secs
# Iter 3300 Loss 0.5035 Moving Loss 0.5008
# 0.23984718322753906 secs
# Iter 3400 Loss 0.5034 Moving Loss 0.5004
# 0.23694610595703125 secs
# Iter 3500 Loss 0.5033 Moving Loss 0.5004
# 0.23602533340454102 secs
# Iter 3600 Loss 0.5032 Moving Loss 0.5001
# 0.23555755615234375 secs
# Iter 3700 Loss 0.5033 Moving Loss 0.5043
# 0.23799371719360352 secs
# Iter 3800 Loss 0.5032 Moving Loss 0.5007
# 0.23867273330688477 secs
# Iter 3900 Loss 0.5032 Moving Loss 0.5037
# 0.2448558807373047 secs
# Iter 4000 Loss 0.5031 Moving Loss 0.5003
# 0.24261260032653809 secs
# Iter 4100 Loss 0.5031 Moving Loss 0.5016
# 0.2378218173980713 secs
# Iter 4200 Loss 0.5030 Moving Loss 0.5008
# 0.23660850524902344 secs
# Iter 4300 Loss 0.5030 Moving Loss 0.5012
# 0.24045562744140625 secs
# Iter 4400 Loss 0.5029 Moving Loss 0.5005
# 0.23599958419799805 secs
# Iter 4500 Loss 0.5029 Moving Loss 0.5014
# 0.2414252758026123 secs
# Iter 4600 Loss 0.5029 Moving Loss 0.5006
# 0.24824953079223633 secs
# Iter 4700 Loss 0.5028 Moving Loss 0.5001
# 0.25065112113952637 secs
# Iter 4800 Loss 0.5028 Moving Loss 0.5019
# 0.23774981498718262 secs
# Iter 4900 Loss 0.5030 Moving Loss 0.5136
# 0.23900675773620605 secs
# Iter 5000 Loss 0.5030 Moving Loss 0.5048
# 0.23537492752075195 secs
# Iter 5100 Loss 0.5030 Moving Loss 0.5014
# 0.235823392868042 secs
# Iter 5200 Loss 0.5030 Moving Loss 0.5010
# 0.23507142066955566 secs
# Iter 5300 Loss 0.5029 Moving Loss 0.5002
# 0.23767447471618652 secs
# Iter 5400 Loss 0.5029 Moving Loss 0.5012
# 0.2360844612121582 secs
# Iter 5500 Loss 0.5028 Moving Loss 0.5007
# 0.23683595657348633 secs
# Iter 5600 Loss 0.5029 Moving Loss 0.5059
# 0.23664426803588867 secs
# Iter 5700 Loss 0.5029 Moving Loss 0.5007
# 0.23506402969360352 secs
# Iter 5800 Loss 0.5028 Moving Loss 0.5003
# 0.2367086410522461 secs
# Iter 5900 Loss 0.5028 Moving Loss 0.5007
# 0.23755788803100586 secs
# Iter 6000 Loss 0.5027 Moving Loss 0.5000
# 0.24606728553771973 secs
# Iter 6100 Loss 0.5027 Moving Loss 0.4999
# 0.24944448471069336 secs
# Iter 6200 Loss 0.5027 Moving Loss 0.5006
# 0.23684477806091309 secs
# Iter 6300 Loss 0.5026 Moving Loss 0.5005
# 0.23599886894226074 secs
# Iter 6400 Loss 0.5026 Moving Loss 0.5000
# 0.23942875862121582 secs
# Iter 6500 Loss 0.5026 Moving Loss 0.5006
# 0.23605132102966309 secs
# Iter 6600 Loss 0.5025 Moving Loss 0.5001
# 0.23652172088623047 secs
# Iter 6700 Loss 0.5025 Moving Loss 0.5001
# 0.252765417098999 secs
# Iter 6800 Loss 0.5025 Moving Loss 0.5004
# 0.2546966075897217 secs
# Iter 6900 Loss 0.5024 Moving Loss 0.5001
# 0.24830174446105957 secs
# Iter 7000 Loss 0.5024 Moving Loss 0.5001
# 0.23672175407409668 secs
# Iter 7100 Loss 0.5023 Moving Loss 0.4999
# 0.23645281791687012 secs
# Iter 7200 Loss 0.5023 Moving Loss 0.5008
# 0.23563265800476074 secs
# Iter 7300 Loss 0.5023 Moving Loss 0.5000
# 0.23550844192504883 secs
# Iter 7400 Loss 0.5023 Moving Loss 0.5006
# 0.23636841773986816 secs
# Iter 7500 Loss 0.5022 Moving Loss 0.5002
# 0.2353825569152832 secs
# Iter 7600 Loss 0.5022 Moving Loss 0.5012
# 0.23520421981811523 secs
# Iter 7700 Loss 0.5022 Moving Loss 0.5002
# 0.23504877090454102 secs
# Iter 7800 Loss 0.5022 Moving Loss 0.5000
# 0.2365415096282959 secs
# Iter 7900 Loss 0.5021 Moving Loss 0.5002
# 0.23558902740478516 secs
# Iter 8000 Loss 0.5021 Moving Loss 0.5006
# 0.23542571067810059 secs
# Iter 8100 Loss 0.5021 Moving Loss 0.5007
# 0.2454056739807129 secs
# Iter 8200 Loss 0.5021 Moving Loss 0.5003
# 0.2406148910522461 secs
# Iter 8300 Loss 0.5021 Moving Loss 0.5001
# 0.23620319366455078 secs
# Iter 8400 Loss 0.5021 Moving Loss 0.5008
# 0.23647379875183105 secs
# Iter 8500 Loss 0.5020 Moving Loss 0.5000
# 0.23707914352416992 secs
# Iter 8600 Loss 0.5020 Moving Loss 0.5006
# 0.23734426498413086 secs
# Iter 8700 Loss 0.5020 Moving Loss 0.5000
# 0.2389969825744629 secs
# Iter 8800 Loss 0.5020 Moving Loss 0.5005
# 0.24792742729187012 secs
# Iter 8900 Loss 0.5019 Moving Loss 0.5001
# 0.24190330505371094 secs
# Iter 9000 Loss 0.5019 Moving Loss 0.4996
# 0.2495880126953125 secs
# Iter 9100 Loss 0.5019 Moving Loss 0.5000
# 0.2387402057647705 secs
# Iter 9200 Loss 0.5019 Moving Loss 0.5006
# 0.23560261726379395 secs
# Iter 9300 Loss 0.5019 Moving Loss 0.5001
# 0.23593616485595703 secs
# Iter 9400 Loss 0.5019 Moving Loss 0.5001
# 0.23702383041381836 secs
# Iter 9500 Loss 0.5018 Moving Loss 0.5008
# 0.2367405891418457 secs
# Iter 9600 Loss 0.5018 Moving Loss 0.4999
# 0.23585748672485352 secs
# Iter 9700 Loss 0.5018 Moving Loss 0.5009
# 0.23684215545654297 secs
# Iter 9800 Loss 0.5018 Moving Loss 0.5002
# 0.2358720302581787 secs
# Iter 9900 Loss 0.5018 Moving Loss 0.5004
# 0.23651981353759766 secs
# Iter 10000 Loss 0.5018 Moving Loss 0.5003
# 0.2359156608581543 secs
# Iter 10100 Loss 0.5018 Moving Loss 0.5007
# 0.23598575592041016 secs
# Iter 10200 Loss 0.5017 Moving Loss 0.5001
# 0.25025177001953125 secs
# Iter 10300 Loss 0.5017 Moving Loss 0.5003
# 0.2480776309967041 secs
# Iter 10400 Loss 0.5017 Moving Loss 0.5001
# 0.2500464916229248 secs
# Iter 10500 Loss 0.5017 Moving Loss 0.5014
# 0.23925042152404785 secs
# Iter 10600 Loss 0.5017 Moving Loss 0.5000
# 0.23850703239440918 secs
# Iter 10700 Loss 0.5017 Moving Loss 0.5002
# 0.2377779483795166 secs
# Iter 10800 Loss 0.5017 Moving Loss 0.5000
# 0.23721957206726074 secs
# Iter 10900 Loss 0.5016 Moving Loss 0.4999
# 0.2512850761413574 secs
# Iter 11000 Loss 0.5016 Moving Loss 0.4997
# 0.2405388355255127 secs
# Iter 11100 Loss 0.5016 Moving Loss 0.5003
# 0.25035619735717773 secs
# Iter 11200 Loss 0.5016 Moving Loss 0.5004
# 0.2395799160003662 secs
# Iter 11300 Loss 0.5016 Moving Loss 0.4998
# 0.2478499412536621 secs
# Iter 11400 Loss 0.5016 Moving Loss 0.5004
# 0.2364482879638672 secs
# Iter 11500 Loss 0.5016 Moving Loss 0.5002
# 0.23539495468139648 secs
# Iter 11600 Loss 0.5016 Moving Loss 0.5003
# 0.23662590980529785 secs
# Iter 11700 Loss 0.5015 Moving Loss 0.5004
# 0.24254488945007324 secs
# Iter 11800 Loss 0.5015 Moving Loss 0.5008
# 0.23532342910766602 secs
# Iter 11900 Loss 0.5015 Moving Loss 0.5000
# 0.23548412322998047 secs
# Iter 12000 Loss 0.5015 Moving Loss 0.5002
# 0.2358226776123047 secs
# Iter 12100 Loss 0.5015 Moving Loss 0.5002
# 0.24389934539794922 secs
# Iter 12200 Loss 0.5015 Moving Loss 0.5001
# 0.23837041854858398 secs
# Iter 12300 Loss 0.5015 Moving Loss 0.5002
# 0.24403691291809082 secs
# Iter 12400 Loss 0.5015 Moving Loss 0.5004
# 0.23667025566101074 secs
# Iter 12500 Loss 0.5015 Moving Loss 0.5004
# 0.23726201057434082 secs
# Iter 12600 Loss 0.5015 Moving Loss 0.5001
# 0.23494672775268555 secs
# Iter 12700 Loss 0.5014 Moving Loss 0.5002
# 0.2368302345275879 secs
# Iter 12800 Loss 0.5014 Moving Loss 0.5003
# 0.23748064041137695 secs
# Iter 12900 Loss 0.5014 Moving Loss 0.5004
# 0.23633432388305664 secs
# Iter 13000 Loss 0.5014 Moving Loss 0.5001
# 0.25891733169555664 secs
# Iter 13100 Loss 0.5014 Moving Loss 0.4999
# 0.2486724853515625 secs
# Iter 13200 Loss 0.5014 Moving Loss 0.5004
# 0.23732829093933105 secs
# Iter 13300 Loss 0.5014 Moving Loss 0.5004
# 0.2459096908569336 secs
# Iter 13400 Loss 0.5014 Moving Loss 0.4993
# 0.23532724380493164 secs
# Iter 13500 Loss 0.5014 Moving Loss 0.4998
# 0.2352290153503418 secs
# Iter 13600 Loss 0.5014 Moving Loss 0.5008
# 0.23473787307739258 secs
# Iter 13700 Loss 0.5013 Moving Loss 0.4999
# 0.23619890213012695 secs
# Iter 13800 Loss 0.5013 Moving Loss 0.4999
# 0.23553681373596191 secs
# Iter 13900 Loss 0.5013 Moving Loss 0.5001
# 0.23614764213562012 secs
# Iter 14000 Loss 0.5013 Moving Loss 0.5001
# 0.23694467544555664 secs
# Iter 14100 Loss 0.5013 Moving Loss 0.5001
# 0.23587632179260254 secs
# Iter 14200 Loss 0.5013 Moving Loss 0.5006
# 0.23614287376403809 secs
# Iter 14300 Loss 0.5013 Moving Loss 0.5007
# 0.23903799057006836 secs
# Iter 14400 Loss 0.5013 Moving Loss 0.5002
# 0.2503030300140381 secs
# Iter 14500 Loss 0.5013 Moving Loss 0.5002
# 0.2367382049560547 secs
# Iter 14600 Loss 0.5013 Moving Loss 0.5003
# 0.2348494529724121 secs
# Iter 14700 Loss 0.5013 Moving Loss 0.5000
# 0.23509979248046875 secs
# Iter 14800 Loss 0.5013 Moving Loss 0.5001
# 0.23553133010864258 secs
# Iter 14900 Loss 0.5013 Moving Loss 0.5012
# 0.23683619499206543 secs
# Iter 15000 Loss 0.5012 Moving Loss 0.4993
# 0.23814058303833008 secs
# Iter 15100 Loss 0.5012 Moving Loss 0.5009
# 0.2570037841796875 secs
# Iter 15200 Loss 0.5012 Moving Loss 0.4996
# 0.25373101234436035 secs
# Iter 15300 Loss 0.5012 Moving Loss 0.4997
# 0.25020861625671387 secs
# Iter 15400 Loss 0.5012 Moving Loss 0.4998
# 0.24557924270629883 secs
# Iter 15500 Loss 0.5012 Moving Loss 0.5001
# 0.23502874374389648 secs
# Iter 15600 Loss 0.5012 Moving Loss 0.5001
# 0.235154390335083 secs
# Iter 15700 Loss 0.5012 Moving Loss 0.5000
# 0.2350599765777588 secs
# Iter 15800 Loss 0.5012 Moving Loss 0.4998
# 0.23562908172607422 secs
# Iter 15900 Loss 0.5012 Moving Loss 0.5000
# 0.23485755920410156 secs
# Iter 16000 Loss 0.5012 Moving Loss 0.5005
# 0.23545050621032715 secs
# Iter 16100 Loss 0.5012 Moving Loss 0.5004
# 0.2348487377166748 secs
# Iter 16200 Loss 0.5012 Moving Loss 0.5001
# 0.23526978492736816 secs
# Iter 16300 Loss 0.5012 Moving Loss 0.5001
# 0.2349538803100586 secs
# Iter 16400 Loss 0.5011 Moving Loss 0.5002
# 0.23670125007629395 secs
# Iter 16500 Loss 0.5011 Moving Loss 0.5003
# 0.2370922565460205 secs
# Iter 16600 Loss 0.5012 Moving Loss 0.5045
# 0.2367875576019287 secs
# Iter 16700 Loss 0.5012 Moving Loss 0.5091
# 0.23546957969665527 secs
# Iter 16800 Loss 0.5012 Moving Loss 0.5005
# 0.23516130447387695 secs
# Iter 16900 Loss 0.5012 Moving Loss 0.5011
# 0.23880934715270996 secs
# Iter 17000 Loss 0.5012 Moving Loss 0.5002
# 0.23717117309570312 secs
# Iter 17100 Loss 0.5012 Moving Loss 0.5003
# 0.2405233383178711 secs
# Iter 17200 Loss 0.5012 Moving Loss 0.4999
# 0.2419590950012207 secs
# Iter 17300 Loss 0.5012 Moving Loss 0.4998
# 0.2359449863433838 secs
# Iter 17400 Loss 0.5012 Moving Loss 0.4999
# 0.23585915565490723 secs
# Iter 17500 Loss 0.5012 Moving Loss 0.5004
# 0.23609519004821777 secs
# Iter 17600 Loss 0.5012 Moving Loss 0.5005
# 0.24423980712890625 secs
# Iter 17700 Loss 0.5012 Moving Loss 0.5000
# 0.23564553260803223 secs
# Iter 17800 Loss 0.5012 Moving Loss 0.5001
# 0.2353816032409668 secs
# Iter 17900 Loss 0.5011 Moving Loss 0.5004
# 0.23602509498596191 secs
# Iter 18000 Loss 0.5011 Moving Loss 0.5005
# 0.2362368106842041 secs
# Iter 18100 Loss 0.5011 Moving Loss 0.4999
# 0.23545074462890625 secs
# Iter 18200 Loss 0.5011 Moving Loss 0.5005
# 0.23522663116455078 secs
# Iter 18300 Loss 0.5011 Moving Loss 0.5000
# 0.23571300506591797 secs
# Iter 18400 Loss 0.5011 Moving Loss 0.5002
# 0.23635363578796387 secs
# Iter 18500 Loss 0.5011 Moving Loss 0.4999
# 0.24012994766235352 secs
# Iter 18600 Loss 0.5011 Moving Loss 0.5001
# 0.24552655220031738 secs
# Iter 18700 Loss 0.5011 Moving Loss 0.5000
# 0.23732995986938477 secs
# Iter 18800 Loss 0.5011 Moving Loss 0.5002
# 0.2355506420135498 secs
# Iter 18900 Loss 0.5011 Moving Loss 0.5001
# 0.23513317108154297 secs
# Iter 19000 Loss 0.5011 Moving Loss 0.4998
# 0.24385595321655273 secs
# Iter 19100 Loss 0.5011 Moving Loss 0.5001
# 0.2359635829925537 secs
# Iter 19200 Loss 0.5011 Moving Loss 0.5000
# 0.2392864227294922 secs
# Iter 19300 Loss 0.5011 Moving Loss 0.4999
# 0.2683699131011963 secs
# Iter 19400 Loss 0.5011 Moving Loss 0.5000
# 0.25159239768981934 secs
# Iter 19500 Loss 0.5011 Moving Loss 0.4999
# 0.23764753341674805 secs
# Iter 19600 Loss 0.5011 Moving Loss 0.5003
# 0.23622703552246094 secs
# Iter 19700 Loss 0.5011 Moving Loss 0.5000
# 0.245682954788208 secs
# Iter 19800 Loss 0.5010 Moving Loss 0.5000
# 0.23526787757873535 secs
# Iter 19900 Loss 0.5010 Moving Loss 0.5000
# 0.23507905006408691 secs
# Iter 20000 Loss 0.5010 Moving Loss 0.5002
# 0.235870361328125 secs
# Iter 20100 Loss 0.5010 Moving Loss 0.4999
# 0.235062837600708 secs
# Iter 20200 Loss 0.5010 Moving Loss 0.5003
# 0.23513150215148926 secs
# Iter 20300 Loss 0.5010 Moving Loss 0.4999
# 0.2348628044128418 secs
# Iter 20400 Loss 0.5010 Moving Loss 0.5001
# 0.23672175407409668 secs
# Iter 20500 Loss 0.5010 Moving Loss 0.5002
# 0.23561573028564453 secs
# Iter 20600 Loss 0.5010 Moving Loss 0.4998
# 0.23636603355407715 secs
# Iter 20700 Loss 0.5010 Moving Loss 0.4998
# 0.23948073387145996 secs
# Iter 20800 Loss 0.5010 Moving Loss 0.4997
# 0.2363877296447754 secs
# Iter 20900 Loss 0.5010 Moving Loss 0.5002
# 0.23622751235961914 secs
# Iter 21000 Loss 0.5010 Moving Loss 0.5031
# 0.23546314239501953 secs
# Iter 21100 Loss 0.5010 Moving Loss 0.5001
# 0.23618650436401367 secs
# Iter 21200 Loss 0.5010 Moving Loss 0.5000
# 0.23634672164916992 secs
# Iter 21300 Loss 0.5010 Moving Loss 0.5002
# 0.24569082260131836 secs
# Iter 21400 Loss 0.5010 Moving Loss 0.4999
# 0.24235296249389648 secs
# Iter 21500 Loss 0.5010 Moving Loss 0.5001
# 0.23965144157409668 secs
# Iter 21600 Loss 0.5010 Moving Loss 0.5002
# 0.23544096946716309 secs
# Iter 21700 Loss 0.5010 Moving Loss 0.4999
# 0.23616766929626465 secs
# Iter 21800 Loss 0.5010 Moving Loss 0.5000
# 0.23548531532287598 secs
# Iter 21900 Loss 0.5010 Moving Loss 0.5007
# 0.24482440948486328 secs
# Iter 22000 Loss 0.5010 Moving Loss 0.5001
# 0.23522305488586426 secs
# Iter 22100 Loss 0.5010 Moving Loss 0.5000
# 0.23592591285705566 secs
# Iter 22200 Loss 0.5010 Moving Loss 0.5000
# 0.2356865406036377 secs
# Iter 22300 Loss 0.5009 Moving Loss 0.5001
# 0.23537755012512207 secs
# Iter 22400 Loss 0.5009 Moving Loss 0.5004
# 0.2351856231689453 secs
# Iter 22500 Loss 0.5009 Moving Loss 0.5002
# 0.23682403564453125 secs
# Iter 22600 Loss 0.5009 Moving Loss 0.5004
# 0.23551082611083984 secs
# Iter 22700 Loss 0.5009 Moving Loss 0.5001
# 0.23682570457458496 secs
# Iter 22800 Loss 0.5009 Moving Loss 0.5004
# 0.24801206588745117 secs
# Iter 22900 Loss 0.5009 Moving Loss 0.5001
# 0.23937368392944336 secs
# Iter 23000 Loss 0.5009 Moving Loss 0.5000
# 0.2358236312866211 secs
# Iter 23100 Loss 0.5009 Moving Loss 0.5007
# 0.23621773719787598 secs
# Iter 23200 Loss 0.5009 Moving Loss 0.5000
# 0.23620939254760742 secs
# Iter 23300 Loss 0.5009 Moving Loss 0.5001
# 0.23817920684814453 secs
# Iter 23400 Loss 0.5009 Moving Loss 0.5000
# 0.24470257759094238 secs
# Iter 23500 Loss 0.5009 Moving Loss 0.4998
# 0.24181413650512695 secs
# Iter 23600 Loss 0.5009 Moving Loss 0.5002
# 0.23897933959960938 secs
# Iter 23700 Loss 0.5009 Moving Loss 0.5002
# 0.23627877235412598 secs
# Iter 23800 Loss 0.5009 Moving Loss 0.5000
# 0.2358253002166748 secs
# Iter 23900 Loss 0.5009 Moving Loss 0.5005
# 0.23558759689331055 secs
# Iter 24000 Loss 0.5009 Moving Loss 0.4999
# 0.24535727500915527 secs
# Iter 24100 Loss 0.5009 Moving Loss 0.5001
# 0.23492670059204102 secs
# Iter 24200 Loss 0.5009 Moving Loss 0.5003
# 0.23620939254760742 secs
# Iter 24300 Loss 0.5009 Moving Loss 0.4999
# 0.23636198043823242 secs
# Iter 24400 Loss 0.5009 Moving Loss 0.5000
# 0.23589777946472168 secs
# Iter 24500 Loss 0.5009 Moving Loss 0.5002
# 0.23548436164855957 secs
# Iter 24600 Loss 0.5009 Moving Loss 0.5000
# 0.23606038093566895 secs
# Iter 24700 Loss 0.5009 Moving Loss 0.5002
# 0.23551177978515625 secs
# Iter 24800 Loss 0.5009 Moving Loss 0.5003
# 0.23992419242858887 secs
# Iter 24900 Loss 0.5009 Moving Loss 0.5002
# 0.24181413650512695 secs
# Iter 25000 Loss 0.5009 Moving Loss 0.5000
# 0.23616719245910645 secs
# Iter 25100 Loss 0.5009 Moving Loss 0.5002
# 0.23589420318603516 secs
# Iter 25200 Loss 0.5009 Moving Loss 0.5002
# 0.2357313632965088 secs
# Iter 25300 Loss 0.5009 Moving Loss 0.4998
# 0.23703575134277344 secs
# Iter 25400 Loss 0.5008 Moving Loss 0.5001
# 0.2380666732788086 secs
# Iter 25500 Loss 0.5008 Moving Loss 0.5000
# 0.24291419982910156 secs
# Iter 25600 Loss 0.5008 Moving Loss 0.5001
# 0.25511837005615234 secs
# Iter 25700 Loss 0.5008 Moving Loss 0.5002
# 0.2526588439941406 secs
# Iter 25800 Loss 0.5008 Moving Loss 0.5002
# 0.24383187294006348 secs
# Iter 25900 Loss 0.5008 Moving Loss 0.5001
# 0.2358405590057373 secs
# Iter 26000 Loss 0.5008 Moving Loss 0.5002
# 0.23543500900268555 secs
# Iter 26100 Loss 0.5008 Moving Loss 0.5002
# 0.24164438247680664 secs
# Iter 26200 Loss 0.5008 Moving Loss 0.5003
# 0.23851776123046875 secs
# Iter 26300 Loss 0.5008 Moving Loss 0.5002
# 0.23592901229858398 secs
# Iter 26400 Loss 0.5008 Moving Loss 0.4999
# 0.2355179786682129 secs
# Iter 26500 Loss 0.5008 Moving Loss 0.4997
# 0.2354283332824707 secs
# Iter 26600 Loss 0.5008 Moving Loss 0.5000
# 0.23522639274597168 secs
# Iter 26700 Loss 0.5008 Moving Loss 0.4997
# 0.23569130897521973 secs
# Iter 26800 Loss 0.5008 Moving Loss 0.5008
# 0.23545336723327637 secs
# Iter 26900 Loss 0.5008 Moving Loss 0.5002
# 0.23941993713378906 secs
# Iter 27000 Loss 0.5008 Moving Loss 0.5001
# 0.24904322624206543 secs
# Iter 27100 Loss 0.5008 Moving Loss 0.5003
# 0.23631644248962402 secs
# Iter 27200 Loss 0.5008 Moving Loss 0.4997
# 0.23618221282958984 secs
# Iter 27300 Loss 0.5008 Moving Loss 0.5000
# 0.23718023300170898 secs
# Iter 27400 Loss 0.5008 Moving Loss 0.5005
# 0.23520350456237793 secs
# Iter 27500 Loss 0.5008 Moving Loss 0.4998
# 0.23806548118591309 secs
# Iter 27600 Loss 0.5008 Moving Loss 0.5002
# 0.24687981605529785 secs
# Iter 27700 Loss 0.5008 Moving Loss 0.4999
# 0.25335121154785156 secs
# Iter 27800 Loss 0.5008 Moving Loss 0.5000
# 0.2435007095336914 secs
# Iter 27900 Loss 0.5008 Moving Loss 0.5004
# 0.24506711959838867 secs
# Iter 28000 Loss 0.5008 Moving Loss 0.5003
# 0.23850679397583008 secs
# Iter 28100 Loss 0.5008 Moving Loss 0.5003
# 0.23632049560546875 secs
# Iter 28200 Loss 0.5008 Moving Loss 0.4999
# 0.23644542694091797 secs
# Iter 28300 Loss 0.5008 Moving Loss 0.5002
# 0.24866962432861328 secs
# Iter 28400 Loss 0.5008 Moving Loss 0.4999
# 0.23639249801635742 secs
# Iter 28500 Loss 0.5008 Moving Loss 0.5000
# 0.23707938194274902 secs
# Iter 28600 Loss 0.5008 Moving Loss 0.5000
# 0.23625850677490234 secs
# Iter 28700 Loss 0.5008 Moving Loss 0.5002
# 0.23579740524291992 secs
# Iter 28800 Loss 0.5008 Moving Loss 0.4999
# 0.2366654872894287 secs
# Iter 28900 Loss 0.5008 Moving Loss 0.5000
# 0.23626351356506348 secs
# Iter 29000 Loss 0.5008 Moving Loss 0.5003
# 0.2445213794708252 secs
# Iter 29100 Loss 0.5008 Moving Loss 0.5001
# 0.24353313446044922 secs
# Iter 29200 Loss 0.5008 Moving Loss 0.5001
# 0.23688364028930664 secs
# Iter 29300 Loss 0.5007 Moving Loss 0.5001
# 0.2367241382598877 secs
# Iter 29400 Loss 0.5007 Moving Loss 0.5004
# 0.23785066604614258 secs
# Iter 29500 Loss 0.5007 Moving Loss 0.5001
# 0.23643851280212402 secs
# Iter 29600 Loss 0.5007 Moving Loss 0.5002
# 0.24058198928833008 secs
# Iter 29700 Loss 0.5007 Moving Loss 0.5002
# 0.24711275100708008 secs
# Iter 29800 Loss 0.5007 Moving Loss 0.4998
# 0.2417609691619873 secs
# Iter 29900 Loss 0.5007 Moving Loss 0.5001
# 0.23542261123657227 secs
# Iter 30000 Loss 0.5007 Moving Loss 0.5001
# 0.2361607551574707 secs
# Iter 30100 Loss 0.5007 Moving Loss 0.5001
# 0.23646283149719238 secs
# Iter 30200 Loss 0.5007 Moving Loss 0.4999
# 0.23677396774291992 secs
# Iter 30300 Loss 0.5007 Moving Loss 0.5000
# 0.23563456535339355 secs
# Iter 30400 Loss 0.5007 Moving Loss 0.4997
# 0.2466883659362793 secs
# Iter 30500 Loss 0.5007 Moving Loss 0.4999
# 0.23624968528747559 secs
# Iter 30600 Loss 0.5007 Moving Loss 0.4999
# 0.23624420166015625 secs
# Iter 30700 Loss 0.5007 Moving Loss 0.5003
# 0.2656583786010742 secs
# Iter 30800 Loss 0.5007 Moving Loss 0.5001
# 0.2375187873840332 secs
# Iter 30900 Loss 0.5007 Moving Loss 0.4999
# 0.2367076873779297 secs
# Iter 31000 Loss 0.5007 Moving Loss 0.5000
# 0.2361593246459961 secs
# Iter 31100 Loss 0.5007 Moving Loss 0.5001
# 0.24677658081054688 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/20-order_markov_chain_1000000.txt" is the same as "output/decom_mc_1m"
# ```
