# %% [markdown]
# # Compression logs order-40 HMM
#
# Compression
# ```bash
# bash compress.sh Simulated-data-main/40-order_hidden_markov_chain.txt output/40_hmm.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/40_hmm.dzip output/decom_hmm40 com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data-main/40-order_hidden_markov_chain.txt output/decom_hmm40
# ```

# %% [markdown]
# # Compression Logs
#
# ```bash
# Seq Length 199999
# Using cuda
# Vocab Size 3
# CudNN version 90100
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.3311152458190918 secs
# ====> Epoch: 1 Average loss: 0.6189324257.8169
# Loss went from 100000000.0000 to 0.6189
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.0920403003692627 secs
# ====> Epoch: 2 Average loss: 0.5033147323.5069
# Loss went from 0.6189 to 0.5033
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09103679656982422 secs
# ====> Epoch: 3 Average loss: 0.5022553184.4966
# Loss went from 0.5033 to 0.5023
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08771753311157227 secs
# ====> Epoch: 4 Average loss: 0.5004885903.4968
# Loss went from 0.5023 to 0.5005
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08461642265319824 secs
# ====> Epoch: 5 Average loss: 0.5008727834.4912
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08261680603027344 secs
# ====> Epoch: 6 Average loss: 0.5007549647.4953
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08709836006164551 secs
# ====> Epoch: 7 Average loss: 0.5005085032.4862
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08613085746765137 secs
# ====> Epoch: 8 Average loss: 0.5002788348.4869
# Loss went from 0.5005 to 0.5003
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# 0.44533777236938477 secs
# Iter 100 Loss 0.5667 Moving Loss 0.5667 Train Loss 0.9701
# 0.17018604278564453 secs
# Iter 200 Loss 0.5411 Moving Loss 0.5154 Train Loss 0.5697
# 0.1703777313232422 secs
# Iter 300 Loss 0.5284 Moving Loss 0.5032 Train Loss 0.5404
# 0.16916322708129883 secs
# Iter 400 Loss 0.5246 Moving Loss 0.5132 Train Loss 0.5325
# 0.16981029510498047 secs
# Iter 500 Loss 0.5204 Moving Loss 0.5036 Train Loss 0.5434
# 0.16936469078063965 secs
# Iter 600 Loss 0.5185 Moving Loss 0.5090 Train Loss 0.5265
# 0.16823077201843262 secs
# Iter 700 Loss 0.5160 Moving Loss 0.5009 Train Loss 0.5135
# 0.16960358619689941 secs
# Iter 800 Loss 0.5143 Moving Loss 0.5022 Train Loss 0.5099
# 0.17083358764648438 secs
# Iter 900 Loss 0.5131 Moving Loss 0.5038 Train Loss 0.5162
# 0.16911721229553223 secs
# Iter 1000 Loss 0.5118 Moving Loss 0.4998 Train Loss 0.5031
# 0.1684122085571289 secs
# Iter 1100 Loss 0.5112 Moving Loss 0.5050 Train Loss 0.5134
# 0.1683971881866455 secs
# Iter 1200 Loss 0.5105 Moving Loss 0.5028 Train Loss 0.5187
# 0.1685962677001953 secs
# Iter 1300 Loss 0.5097 Moving Loss 0.5003 Train Loss 0.5033
# 0.16849780082702637 secs
# Iter 1400 Loss 0.5091 Moving Loss 0.5009 Train Loss 0.5021
# 0.16905570030212402 secs
# Iter 1500 Loss 0.5087 Moving Loss 0.5041 Train Loss 0.5174
# 0.16864824295043945 secs
# Iter 1600 Loss 0.5083 Moving Loss 0.5012 Train Loss 0.5047
# 0.16843748092651367 secs
# Iter 1700 Loss 0.5078 Moving Loss 0.5009 Train Loss 0.5039
# 0.16829919815063477 secs
# Iter 1800 Loss 0.5075 Moving Loss 0.5011 Train Loss 0.5051
# 0.16835570335388184 secs
# Iter 1900 Loss 0.5071 Moving Loss 0.5004 Train Loss 0.5029
# 0.16851449012756348 secs
# Iter 2000 Loss 0.5068 Moving Loss 0.5009 Train Loss 0.5042
# 0.17136383056640625 secs
# Iter 2100 Loss 0.5065 Moving Loss 0.5013 Train Loss 0.5051
# 0.1779170036315918 secs
# Iter 2200 Loss 0.5063 Moving Loss 0.5025 Train Loss 0.5050
# 0.16865301132202148 secs
# Iter 2300 Loss 0.5061 Moving Loss 0.5005 Train Loss 0.5084
# 0.16881680488586426 secs
# Iter 2400 Loss 0.5059 Moving Loss 0.5020 Train Loss 0.5047
# 0.1692500114440918 secs
# Iter 2500 Loss 0.5057 Moving Loss 0.5001 Train Loss 0.5048
# 0.16843962669372559 secs
# Iter 2600 Loss 0.5056 Moving Loss 0.5029 Train Loss 0.5049
# 0.17788410186767578 secs
# Iter 2700 Loss 0.5054 Moving Loss 0.5019 Train Loss 0.5107
# 0.1806185245513916 secs
# Iter 2800 Loss 0.5053 Moving Loss 0.5027 Train Loss 0.5087
# 0.16957354545593262 secs
# Iter 2900 Loss 0.5052 Moving Loss 0.5008 Train Loss 0.5050
# 0.16919374465942383 secs
# Iter 3000 Loss 0.5050 Moving Loss 0.5010 Train Loss 0.5008
# Done
# ```

# %% [markdown]
# # Decompression Logs
#
# ```bash
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# Iter 100 Loss 0.5667 Moving Loss 0.5667
# 0.4128453731536865 secs
# Iter 200 Loss 0.5411 Moving Loss 0.5154
# 0.1760094165802002 secs
# Iter 300 Loss 0.5284 Moving Loss 0.5032
# 0.17568421363830566 secs
# Iter 400 Loss 0.5246 Moving Loss 0.5132
# 0.1840522289276123 secs
# Iter 500 Loss 0.5204 Moving Loss 0.5036
# 0.17547178268432617 secs
# Iter 600 Loss 0.5185 Moving Loss 0.5090
# 0.17466378211975098 secs
# Iter 700 Loss 0.5160 Moving Loss 0.5009
# 0.17481493949890137 secs
# Iter 800 Loss 0.5143 Moving Loss 0.5022
# 0.17512273788452148 secs
# Iter 900 Loss 0.5131 Moving Loss 0.5038
# 0.17515778541564941 secs
# Iter 1000 Loss 0.5118 Moving Loss 0.4998
# 0.174729585647583 secs
# Iter 1100 Loss 0.5112 Moving Loss 0.5050
# 0.18621110916137695 secs
# Iter 1200 Loss 0.5105 Moving Loss 0.5028
# 0.17462944984436035 secs
# Iter 1300 Loss 0.5097 Moving Loss 0.5003
# 0.1753847599029541 secs
# Iter 1400 Loss 0.5091 Moving Loss 0.5009
# 0.17883825302124023 secs
# Iter 1500 Loss 0.5087 Moving Loss 0.5041
# 0.17488551139831543 secs
# Iter 1600 Loss 0.5083 Moving Loss 0.5012
# 0.1751234531402588 secs
# Iter 1700 Loss 0.5078 Moving Loss 0.5009
# 0.17460203170776367 secs
# Iter 1800 Loss 0.5075 Moving Loss 0.5011
# 0.17397809028625488 secs
# Iter 1900 Loss 0.5071 Moving Loss 0.5004
# 0.17695975303649902 secs
# Iter 2000 Loss 0.5068 Moving Loss 0.5009
# 0.1772165298461914 secs
# Iter 2100 Loss 0.5065 Moving Loss 0.5013
# 0.17517828941345215 secs
# Iter 2200 Loss 0.5063 Moving Loss 0.5025
# 0.17477631568908691 secs
# Iter 2300 Loss 0.5061 Moving Loss 0.5005
# 0.17506933212280273 secs
# Iter 2400 Loss 0.5059 Moving Loss 0.5020
# 0.17507529258728027 secs
# Iter 2500 Loss 0.5057 Moving Loss 0.5001
# 0.17518997192382812 secs
# Iter 2600 Loss 0.5056 Moving Loss 0.5029
# 0.17592287063598633 secs
# Iter 2700 Loss 0.5054 Moving Loss 0.5019
# 0.17494893074035645 secs
# Iter 2800 Loss 0.5053 Moving Loss 0.5027
# 0.17482423782348633 secs
# Iter 2900 Loss 0.5052 Moving Loss 0.5008
# 0.17525053024291992 secs
# Iter 3000 Loss 0.5050 Moving Loss 0.5010
# 0.17509746551513672 secs
# Done
# ```

# %% [markdown]
# # Comparison Logs
#
# The file "Simulated-data-main/40-order_hidden_markov_chain.txt" is the same as "output/decom_hmm40"
