# %% [markdown]
# # Compression logs order-30 HMM 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/30-order_hidden_markov_chain_1000000.txt output/30_hmm_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/30_hmm_1m.dzip output/decom_hmm_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/30-order_hidden_markov_chain_1000000.txt output/decom_hmm_1m
# ```
#
# The file "Simulated-data/30-order_hidden_markov_chain_1000000.txt" is the same as "output/decom_hmm_1m"

# %% [markdown]
# ### Compression Log
#
# ```bash
# [jx1421@ee-tarrasque Deep-Zip-Compression]$ cd coding-gpu/
# [jx1421@ee-tarrasque coding-gpu]$ bash compress.sh Simulated-data/30-order_hidden_markov_chain_1000000.txt output/30_hmm_1m.dzip com MODEL_PATH
# Seq Length 1999999
# Using cuda
# Vocab Size 3
# CudNN version 8902
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.5497393608093262 secs
# 3.746614933013916 secs/976 Average loss: 1.8015
# ====> Epoch: 1 Average loss: 0.5123813201: 0.5235
# Loss went from 100000000.0000 to 0.5124
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2636985778808594 secs
# 3.6345388889312744 secs976 Average loss: 0.5071
# ====> Epoch: 2 Average loss: 0.5003359647: 0.5005
# Loss went from 0.5124 to 0.5003
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.22911953926086426 secs
# 3.7116057872772217 secs976 Average loss: 0.4881
# ====> Epoch: 3 Average loss: 0.5001390538: 0.5006
# Loss went from 0.5003 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23587679862976074 secs
# 3.566641330718994 secs/976 Average loss: 0.4905
# ====> Epoch: 4 Average loss: 0.5001550229: 0.4997
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.22875475883483887 secs
# 3.6346781253814697 secs976 Average loss: 0.4878
# ====> Epoch: 5 Average loss: 0.5001013597: 0.4994
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2664225101470947 secs
# 3.4862194061279297 secs976 Average loss: 0.4953
# ====> Epoch: 6 Average loss: 0.5001041954: 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.26215243339538574 secs
# 3.7694668769836426 secs976 Average loss: 0.4859
# ====> Epoch: 7 Average loss: 0.5000914688: 0.5005
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2822442054748535 secs
# 3.76181960105896 secs1/976 Average loss: 0.5049
# ====> Epoch: 8 Average loss: 0.5000680956: 0.5002
# Loss went from 0.5001 to 0.5001
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# 0.5387370586395264 secs
# Iter 100 Loss 0.5665 Moving Loss 0.5665 Train Loss 0.9227
# 0.2205653190612793 secs
# Iter 200 Loss 0.5338 Moving Loss 0.5011 Train Loss 0.5724
# 0.24832582473754883 secs
# Iter 300 Loss 0.5265 Moving Loss 0.5119 Train Loss 0.5342
# 0.22352981567382812 secs
# Iter 400 Loss 0.5208 Moving Loss 0.5037 Train Loss 0.5475
# 0.22351717948913574 secs
# Iter 500 Loss 0.5168 Moving Loss 0.5006 Train Loss 0.5064
# 0.2554340362548828 secs
# Iter 600 Loss 0.5139 Moving Loss 0.4996 Train Loss 0.5077
# 0.2227778434753418 secs
# Iter 700 Loss 0.5135 Moving Loss 0.5107 Train Loss 0.5352
# 0.2187976837158203 secs
# Iter 800 Loss 0.5116 Moving Loss 0.4989 Train Loss 0.5126
# 0.23745036125183105 secs
# Iter 900 Loss 0.5103 Moving Loss 0.5000 Train Loss 0.5026
# 0.22031545639038086 secs
# Iter 1000 Loss 0.5094 Moving Loss 0.5013 Train Loss 0.5159
# 0.24109721183776855 secs
# Iter 1100 Loss 0.5091 Moving Loss 0.5053 Train Loss 0.5067
# 0.22068071365356445 secs
# Iter 1200 Loss 0.5087 Moving Loss 0.5049 Train Loss 0.5366
# 0.23373174667358398 secs
# Iter 1300 Loss 0.5081 Moving Loss 0.5010 Train Loss 0.5086
# 0.2565619945526123 secs
# Iter 1400 Loss 0.5078 Moving Loss 0.5031 Train Loss 0.5114
# 0.2469780445098877 secs
# Iter 1500 Loss 0.5071 Moving Loss 0.4970 Train Loss 0.5010
# 0.22572922706604004 secs
# Iter 1600 Loss 0.5086 Moving Loss 0.5321 Train Loss 0.6020
# 0.2376101016998291 secs
# Iter 1700 Loss 0.5081 Moving Loss 0.5000 Train Loss 0.5223
# 0.21791434288024902 secs
# Iter 1800 Loss 0.5076 Moving Loss 0.4997 Train Loss 0.5029
# 0.22968602180480957 secs
# Iter 1900 Loss 0.5072 Moving Loss 0.4994 Train Loss 0.5025
# 0.2257392406463623 secs
# Iter 2000 Loss 0.5070 Moving Loss 0.5021 Train Loss 0.5034
# 0.21696710586547852 secs
# Iter 2100 Loss 0.5066 Moving Loss 0.4998 Train Loss 0.5116
# 0.23621582984924316 secs
# Iter 2200 Loss 0.5062 Moving Loss 0.4985 Train Loss 0.4989
# 0.21836614608764648 secs
# Iter 2300 Loss 0.5061 Moving Loss 0.5019 Train Loss 0.4958
# 0.23981118202209473 secs
# Iter 2400 Loss 0.5059 Moving Loss 0.5031 Train Loss 0.5389
# 0.24007654190063477 secs
# Iter 2500 Loss 0.5057 Moving Loss 0.5001 Train Loss 0.5036
# 0.22835898399353027 secs
# Iter 2600 Loss 0.5054 Moving Loss 0.4978 Train Loss 0.4978
# 0.22333860397338867 secs
# Iter 2700 Loss 0.5052 Moving Loss 0.4995 Train Loss 0.5049
# 0.2382962703704834 secs
# Iter 2800 Loss 0.5049 Moving Loss 0.4975 Train Loss 0.5000
# 0.21792888641357422 secs
# Iter 2900 Loss 0.5048 Moving Loss 0.5030 Train Loss 0.5017
# 0.22362661361694336 secs
# Iter 3000 Loss 0.5054 Moving Loss 0.5211 Train Loss 0.5965
# 0.22497129440307617 secs
# Iter 3100 Loss 0.5052 Moving Loss 0.4990 Train Loss 0.4999
# 0.2174985408782959 secs
# Iter 3200 Loss 0.5050 Moving Loss 0.4999 Train Loss 0.5021
# 0.2451474666595459 secs
# Iter 3300 Loss 0.5048 Moving Loss 0.4975 Train Loss 0.4960
# 0.2426135540008545 secs
# Iter 3400 Loss 0.5047 Moving Loss 0.5026 Train Loss 0.5049
# 0.2301626205444336 secs
# Iter 3500 Loss 0.5046 Moving Loss 0.5000 Train Loss 0.5212
# 0.25064873695373535 secs
# Iter 3600 Loss 0.5044 Moving Loss 0.4974 Train Loss 0.4976
# 0.21964311599731445 secs
# Iter 3700 Loss 0.5041 Moving Loss 0.4955 Train Loss 0.4941
# 0.22868585586547852 secs
# Iter 3800 Loss 0.5039 Moving Loss 0.4941 Train Loss 0.4899
# 0.24279499053955078 secs
# Iter 3900 Loss 0.5036 Moving Loss 0.4942 Train Loss 0.4915
# 0.22045135498046875 secs
# Iter 4000 Loss 0.5041 Moving Loss 0.5244 Train Loss 0.6070
# 0.23344850540161133 secs
# Iter 4100 Loss 0.5040 Moving Loss 0.4997 Train Loss 0.5070
# 0.2194514274597168 secs
# Iter 4200 Loss 0.5039 Moving Loss 0.4962 Train Loss 0.4936
# 0.21793031692504883 secs
# Iter 4300 Loss 0.5037 Moving Loss 0.4959 Train Loss 0.4906
# 0.24463176727294922 secs
# Iter 4400 Loss 0.5035 Moving Loss 0.4962 Train Loss 0.5036
# 0.21815228462219238 secs
# Iter 4500 Loss 0.5034 Moving Loss 0.4986 Train Loss 0.5060
# 0.22289109230041504 secs
# Iter 4600 Loss 0.5032 Moving Loss 0.4931 Train Loss 0.4887
# 0.23744964599609375 secs
# Iter 4700 Loss 0.5030 Moving Loss 0.4947 Train Loss 0.5009
# 0.21877527236938477 secs
# Iter 4800 Loss 0.5029 Moving Loss 0.4998 Train Loss 0.4916
# 0.2296280860900879 secs
# Iter 4900 Loss 0.5027 Moving Loss 0.4918 Train Loss 0.5065
# 0.25824761390686035 secs
# Iter 5000 Loss 0.5025 Moving Loss 0.4915 Train Loss 0.4938
# 0.21932482719421387 secs
# Iter 5100 Loss 0.5021 Moving Loss 0.4851 Train Loss 0.4774
# 0.23613810539245605 secs
# Iter 5200 Loss 0.5019 Moving Loss 0.4900 Train Loss 0.4876
# 0.22112607955932617 secs
# Iter 5300 Loss 0.5013 Moving Loss 0.4690 Train Loss 0.4594
# 0.21879982948303223 secs
# Iter 5400 Loss 0.5029 Moving Loss 0.5866 Train Loss 0.6215
# 0.24395036697387695 secs
# Iter 5500 Loss 0.5028 Moving Loss 0.4981 Train Loss 0.6749
# 0.24033665657043457 secs
# Iter 5600 Loss 0.5024 Moving Loss 0.4797 Train Loss 0.4799
# 0.24648261070251465 secs
# Iter 5700 Loss 0.5018 Moving Loss 0.4724 Train Loss 0.4615
# 0.23154282569885254 secs
# Iter 5800 Loss 0.5012 Moving Loss 0.4632 Train Loss 0.4417
# 0.2199263572692871 secs
# Iter 5900 Loss 0.5002 Moving Loss 0.4446 Train Loss 0.4306
# 0.24141955375671387 secs
# Iter 6000 Loss 0.4992 Moving Loss 0.4369 Train Loss 0.4180
# 0.23262429237365723 secs
# Iter 6100 Loss 0.4982 Moving Loss 0.4422 Train Loss 0.4346
# 0.21981525421142578 secs
# Iter 6200 Loss 0.4972 Moving Loss 0.4333 Train Loss 0.4219
# 0.23427963256835938 secs
# Iter 6300 Loss 0.4959 Moving Loss 0.4150 Train Loss 0.4077
# 0.21913576126098633 secs
# Iter 6400 Loss 0.4947 Moving Loss 0.4187 Train Loss 0.4092
# 0.22021031379699707 secs
# Iter 6500 Loss 0.4935 Moving Loss 0.4185 Train Loss 0.3950
# 0.23346400260925293 secs
# Iter 6600 Loss 0.4924 Moving Loss 0.4212 Train Loss 0.4152
# 0.21721386909484863 secs
# Iter 6700 Loss 0.4912 Moving Loss 0.4148 Train Loss 0.4056
# 0.2447071075439453 secs
# Iter 6800 Loss 0.4903 Moving Loss 0.4258 Train Loss 0.4191
# 0.2538917064666748 secs
# Iter 6900 Loss 0.4892 Moving Loss 0.4164 Train Loss 0.4022
# 0.22112154960632324 secs
# Iter 7000 Loss 0.4882 Moving Loss 0.4185 Train Loss 0.4121
# 0.24033093452453613 secs
# Iter 7100 Loss 0.4871 Moving Loss 0.4128 Train Loss 0.4005
# 0.2185525894165039 secs
# Iter 7200 Loss 0.4862 Moving Loss 0.4192 Train Loss 0.4136
# 0.21698617935180664 secs
# Iter 7300 Loss 0.4852 Moving Loss 0.4168 Train Loss 0.4107
# 0.22985196113586426 secs
# Iter 7400 Loss 0.4843 Moving Loss 0.4169 Train Loss 0.4103
# 0.2190992832183838 secs
# Iter 7500 Loss 0.4835 Moving Loss 0.4203 Train Loss 0.4175
# 0.23341727256774902 secs
# Iter 7600 Loss 0.4826 Moving Loss 0.4205 Train Loss 0.4080
# 0.24680829048156738 secs
# Iter 7700 Loss 0.4817 Moving Loss 0.4145 Train Loss 0.4120
# 0.23095154762268066 secs
# Iter 7800 Loss 0.4808 Moving Loss 0.4055 Train Loss 0.3899
# 0.22850894927978516 secs
# Iter 7900 Loss 0.4800 Moving Loss 0.4200 Train Loss 0.4191
# 0.21932387351989746 secs
# Iter 8000 Loss 0.4792 Moving Loss 0.4156 Train Loss 0.4124
# 0.22061705589294434 secs
# Iter 8100 Loss 0.4784 Moving Loss 0.4150 Train Loss 0.4104
# 0.23955655097961426 secs
# Iter 8200 Loss 0.4777 Moving Loss 0.4188 Train Loss 0.4125
# 0.2199554443359375 secs
# Iter 8300 Loss 0.4770 Moving Loss 0.4196 Train Loss 0.4098
# 0.21894049644470215 secs
# Iter 8400 Loss 0.4762 Moving Loss 0.4134 Train Loss 0.4100
# 0.22835564613342285 secs
# Iter 8500 Loss 0.4755 Moving Loss 0.4111 Train Loss 0.4014
# 0.21840167045593262 secs
# Iter 8600 Loss 0.4748 Moving Loss 0.4190 Train Loss 0.4168
# 0.22069311141967773 secs
# Iter 8700 Loss 0.4741 Moving Loss 0.4150 Train Loss 0.4032
# 0.24123239517211914 secs
# Iter 8800 Loss 0.4735 Moving Loss 0.4237 Train Loss 0.4129
# 0.22337031364440918 secs
# Iter 8900 Loss 0.4729 Moving Loss 0.4140 Train Loss 0.4174
# 0.22345280647277832 secs
# Iter 9000 Loss 0.4722 Moving Loss 0.4174 Train Loss 0.3977
# 0.21783065795898438 secs
# Iter 9100 Loss 0.4717 Moving Loss 0.4250 Train Loss 0.4272
# 0.23242855072021484 secs
# Iter 9200 Loss 0.4711 Moving Loss 0.4143 Train Loss 0.4004
# 0.23505616188049316 secs
# Iter 9300 Loss 0.4706 Moving Loss 0.4196 Train Loss 0.4206
# 0.2290019989013672 secs
# Iter 9400 Loss 0.4700 Moving Loss 0.4182 Train Loss 0.4174
# 0.21895408630371094 secs
# Iter 9500 Loss 0.4694 Moving Loss 0.4143 Train Loss 0.4034
# 0.22526860237121582 secs
# Iter 9600 Loss 0.4687 Moving Loss 0.4034 Train Loss 0.3915
# 0.22112083435058594 secs
# Iter 9700 Loss 0.4680 Moving Loss 0.4023 Train Loss 0.3954
# 0.219635009765625 secs
# Iter 9800 Loss 0.4674 Moving Loss 0.4072 Train Loss 0.3964
# 0.24797368049621582 secs
# Iter 9900 Loss 0.4669 Moving Loss 0.4123 Train Loss 0.4107
# 0.23519372940063477 secs
# Iter 10000 Loss 0.4663 Moving Loss 0.4138 Train Loss 0.4043
# 0.23869943618774414 secs
# Iter 10100 Loss 0.4658 Moving Loss 0.4133 Train Loss 0.4091
# 0.22288298606872559 secs
# Iter 10200 Loss 0.4653 Moving Loss 0.4181 Train Loss 0.4140
# 0.230515718460083 secs
# Iter 10300 Loss 0.4648 Moving Loss 0.4084 Train Loss 0.3954
# 0.22990775108337402 secs
# Iter 10400 Loss 0.4643 Moving Loss 0.4121 Train Loss 0.4120
# 0.23610424995422363 secs
# Iter 10500 Loss 0.4637 Moving Loss 0.4067 Train Loss 0.3951
# 0.2199690341949463 secs
# Iter 10600 Loss 0.4633 Moving Loss 0.4145 Train Loss 0.4128
# 0.23458623886108398 secs
# Iter 10700 Loss 0.4628 Moving Loss 0.4163 Train Loss 0.4074
# 0.21878790855407715 secs
# Iter 10800 Loss 0.4623 Moving Loss 0.4109 Train Loss 0.4067
# 0.21967744827270508 secs
# Iter 10900 Loss 0.4618 Moving Loss 0.4005 Train Loss 0.3866
# 0.24217820167541504 secs
# Iter 11000 Loss 0.4614 Moving Loss 0.4149 Train Loss 0.4192
# 0.21929192543029785 secs
# Iter 11100 Loss 0.4610 Moving Loss 0.4178 Train Loss 0.4043
# 0.2263486385345459 secs
# Iter 11200 Loss 0.4606 Moving Loss 0.4180 Train Loss 0.4139
# 0.22917962074279785 secs
# Iter 11300 Loss 0.4602 Moving Loss 0.4180 Train Loss 0.4161
# 0.23782634735107422 secs
# Iter 11400 Loss 0.4598 Moving Loss 0.4117 Train Loss 0.4051
# 0.23927855491638184 secs
# Iter 11500 Loss 0.4594 Moving Loss 0.4114 Train Loss 0.3941
# 0.23671984672546387 secs
# Iter 11600 Loss 0.4590 Moving Loss 0.4206 Train Loss 0.4255
# 0.22140121459960938 secs
# Iter 11700 Loss 0.4586 Moving Loss 0.4081 Train Loss 0.3981
# 0.22991943359375 secs
# Iter 11800 Loss 0.4582 Moving Loss 0.4123 Train Loss 0.4053
# 0.21923136711120605 secs
# Iter 11900 Loss 0.4578 Moving Loss 0.4155 Train Loss 0.4141
# 0.21961379051208496 secs
# Iter 12000 Loss 0.4574 Moving Loss 0.4066 Train Loss 0.3915
# 0.2447803020477295 secs
# Iter 12100 Loss 0.4570 Moving Loss 0.4101 Train Loss 0.4055
# 0.24475407600402832 secs
# Iter 12200 Loss 0.4567 Moving Loss 0.4168 Train Loss 0.4117
# 0.25383520126342773 secs
# Iter 12300 Loss 0.4563 Moving Loss 0.4153 Train Loss 0.4074
# 0.2309706211090088 secs
# Iter 12400 Loss 0.4560 Moving Loss 0.4189 Train Loss 0.4143
# 0.2195289134979248 secs
# Iter 12500 Loss 0.4556 Moving Loss 0.4052 Train Loss 0.4021
# 0.23758912086486816 secs
# Iter 12600 Loss 0.4552 Moving Loss 0.4030 Train Loss 0.3938
# 0.2236647605895996 secs
# Iter 12700 Loss 0.4548 Moving Loss 0.4079 Train Loss 0.4046
# 0.22616147994995117 secs
# Iter 12800 Loss 0.4545 Moving Loss 0.4091 Train Loss 0.4076
# 0.23185205459594727 secs
# Iter 12900 Loss 0.4542 Moving Loss 0.4105 Train Loss 0.3998
# 0.21855759620666504 secs
# Iter 13000 Loss 0.4538 Moving Loss 0.4090 Train Loss 0.4051
# 0.22025084495544434 secs
# Iter 13100 Loss 0.4534 Moving Loss 0.4016 Train Loss 0.3939
# 0.24236130714416504 secs
# Iter 13200 Loss 0.4530 Moving Loss 0.3971 Train Loss 0.3882
# 0.2219400405883789 secs
# Iter 13300 Loss 0.4526 Moving Loss 0.4072 Train Loss 0.4010
# 0.238572359085083 secs
# Iter 13400 Loss 0.4523 Moving Loss 0.4085 Train Loss 0.4058
# 0.2169971466064453 secs
# Iter 13500 Loss 0.4520 Moving Loss 0.4061 Train Loss 0.3970
# 0.22968602180480957 secs
# Iter 13600 Loss 0.4516 Moving Loss 0.4032 Train Loss 0.3926
# 0.23505783081054688 secs
# Iter 13700 Loss 0.4513 Moving Loss 0.4155 Train Loss 0.4162
# 0.22169876098632812 secs
# Iter 13800 Loss 0.4510 Moving Loss 0.4044 Train Loss 0.4018
# 0.22322463989257812 secs
# Iter 13900 Loss 0.4506 Moving Loss 0.4015 Train Loss 0.3953
# 0.22547078132629395 secs
# Iter 14000 Loss 0.4503 Moving Loss 0.3982 Train Loss 0.3832
# 0.22003507614135742 secs
# Iter 14100 Loss 0.4500 Moving Loss 0.4166 Train Loss 0.4225
# 0.22072744369506836 secs
# Iter 14200 Loss 0.4497 Moving Loss 0.4057 Train Loss 0.3945
# 0.25299715995788574 secs
# Iter 14300 Loss 0.4493 Moving Loss 0.3964 Train Loss 0.3903
# 0.22836661338806152 secs
# Iter 14400 Loss 0.4490 Moving Loss 0.3939 Train Loss 0.3866
# 0.2320854663848877 secs
# Iter 14500 Loss 0.4488 Moving Loss 0.4250 Train Loss 0.4401
# 0.21822166442871094 secs
# Iter 14600 Loss 0.4485 Moving Loss 0.4043 Train Loss 0.3941
# 0.22144722938537598 secs
# Iter 14700 Loss 0.4482 Moving Loss 0.4078 Train Loss 0.4013
# 0.22908639907836914 secs
# Iter 14800 Loss 0.4480 Moving Loss 0.4139 Train Loss 0.4150
# 0.22956180572509766 secs
# Iter 14900 Loss 0.4476 Moving Loss 0.3961 Train Loss 0.3816
# 0.22832298278808594 secs
# Iter 15000 Loss 0.4473 Moving Loss 0.4033 Train Loss 0.4017
# 0.22143006324768066 secs
# Iter 15100 Loss 0.4471 Moving Loss 0.4134 Train Loss 0.4060
# 0.21867585182189941 secs
# Iter 15200 Loss 0.4469 Moving Loss 0.4205 Train Loss 0.4146
# 0.2194664478302002 secs
# Iter 15300 Loss 0.4467 Moving Loss 0.4154 Train Loss 0.4189
# 0.23944664001464844 secs
# Iter 15400 Loss 0.4465 Moving Loss 0.4111 Train Loss 0.4074
# 0.22533965110778809 secs
# Iter 15500 Loss 0.4463 Moving Loss 0.4149 Train Loss 0.4132
# 0.24507761001586914 secs
# Iter 15600 Loss 0.4460 Moving Loss 0.4025 Train Loss 0.3921
# 0.22932147979736328 secs
# Iter 15700 Loss 0.4457 Moving Loss 0.4024 Train Loss 0.4034
# 0.2191481590270996 secs
# Iter 15800 Loss 0.4454 Moving Loss 0.3894 Train Loss 0.3736
# 0.23809337615966797 secs
# Iter 15900 Loss 0.4451 Moving Loss 0.4010 Train Loss 0.3926
# 0.24121952056884766 secs
# Iter 16000 Loss 0.4449 Moving Loss 0.4201 Train Loss 0.4217
# 0.24197125434875488 secs
# Iter 16100 Loss 0.4447 Moving Loss 0.4130 Train Loss 0.4108
# 0.2206730842590332 secs
# Iter 16200 Loss 0.4445 Moving Loss 0.4073 Train Loss 0.3973
# 0.2181529998779297 secs
# Iter 16300 Loss 0.4442 Moving Loss 0.3998 Train Loss 0.4014
# 0.21977996826171875 secs
# Iter 16400 Loss 0.4440 Moving Loss 0.4082 Train Loss 0.3954
# 0.2516789436340332 secs
# Iter 16500 Loss 0.4438 Moving Loss 0.4124 Train Loss 0.4168
# 0.2528998851776123 secs
# Iter 16600 Loss 0.4436 Moving Loss 0.4038 Train Loss 0.3949
# 0.2232673168182373 secs
# Iter 16700 Loss 0.4434 Moving Loss 0.4082 Train Loss 0.4015
# 0.21958589553833008 secs
# Iter 16800 Loss 0.4431 Moving Loss 0.3890 Train Loss 0.3871
# 0.2346501350402832 secs
# Iter 16900 Loss 0.4428 Moving Loss 0.3994 Train Loss 0.3913
# 0.2397327423095703 secs
# Iter 17000 Loss 0.4425 Moving Loss 0.3913 Train Loss 0.3877
# 0.23604893684387207 secs
# Iter 17100 Loss 0.4423 Moving Loss 0.4054 Train Loss 0.4027
# 0.22877192497253418 secs
# Iter 17200 Loss 0.4421 Moving Loss 0.4135 Train Loss 0.4042
# 0.21734213829040527 secs
# Iter 17300 Loss 0.4420 Moving Loss 0.4165 Train Loss 0.4204
# 0.21856951713562012 secs
# Iter 17400 Loss 0.4418 Moving Loss 0.4183 Train Loss 0.4124
# 0.2182605266571045 secs
# Iter 17500 Loss 0.4416 Moving Loss 0.3980 Train Loss 0.3969
# 0.23425960540771484 secs
# Iter 17600 Loss 0.4413 Moving Loss 0.3953 Train Loss 0.3873
# 0.22411227226257324 secs
# Iter 17700 Loss 0.4410 Moving Loss 0.3870 Train Loss 0.3812
# 0.22305607795715332 secs
# Iter 17800 Loss 0.4408 Moving Loss 0.4003 Train Loss 0.3922
# 0.22248339653015137 secs
# Iter 17900 Loss 0.4405 Moving Loss 0.3954 Train Loss 0.3954
# 0.21892452239990234 secs
# Iter 18000 Loss 0.4403 Moving Loss 0.4037 Train Loss 0.3958
# 0.2395782470703125 secs
# Iter 18100 Loss 0.4401 Moving Loss 0.3922 Train Loss 0.3927
# 0.24598431587219238 secs
# Iter 18200 Loss 0.4398 Moving Loss 0.3999 Train Loss 0.3995
# 0.23411297798156738 secs
# Iter 18300 Loss 0.4396 Moving Loss 0.3949 Train Loss 0.3921
# 0.21967411041259766 secs
# Iter 18400 Loss 0.4394 Moving Loss 0.4012 Train Loss 0.3972
# 0.2181856632232666 secs
# Iter 18500 Loss 0.4391 Moving Loss 0.3931 Train Loss 0.3836
# 0.21811962127685547 secs
# Iter 18600 Loss 0.4388 Moving Loss 0.3862 Train Loss 0.3839
# 0.24522161483764648 secs
# Iter 18700 Loss 0.4386 Moving Loss 0.3953 Train Loss 0.3940
# 0.22588348388671875 secs
# Iter 18800 Loss 0.4384 Moving Loss 0.3935 Train Loss 0.3898
# 0.22565770149230957 secs
# Iter 18900 Loss 0.4381 Moving Loss 0.3904 Train Loss 0.3796
# 0.22079825401306152 secs
# Iter 19000 Loss 0.4379 Moving Loss 0.4048 Train Loss 0.3976
# 0.22017550468444824 secs
# Iter 19100 Loss 0.4378 Moving Loss 0.4065 Train Loss 0.4066
# 0.23360610008239746 secs
# Iter 19200 Loss 0.4376 Moving Loss 0.3994 Train Loss 0.3999
# 0.228285551071167 secs
# Iter 19300 Loss 0.4374 Moving Loss 0.3972 Train Loss 0.3900
# 0.23062682151794434 secs
# Iter 19400 Loss 0.4371 Moving Loss 0.3921 Train Loss 0.3919
# 0.21737980842590332 secs
# Iter 19500 Loss 0.4370 Moving Loss 0.4160 Train Loss 0.4178
# 0.21733403205871582 secs
# Iter 19600 Loss 0.4368 Moving Loss 0.3955 Train Loss 0.3895
# 0.21883249282836914 secs
# Iter 19700 Loss 0.4366 Moving Loss 0.3946 Train Loss 0.3935
# 0.24529123306274414 secs
# Iter 19800 Loss 0.4364 Moving Loss 0.3933 Train Loss 0.3886
# 0.23315787315368652 secs
# Iter 19900 Loss 0.4362 Moving Loss 0.4024 Train Loss 0.3952
# 0.221848726272583 secs
# Iter 20000 Loss 0.4360 Moving Loss 0.3916 Train Loss 0.3894
# 0.23824191093444824 secs
# Iter 20100 Loss 0.4358 Moving Loss 0.4070 Train Loss 0.3989
# 0.21883344650268555 secs
# Iter 20200 Loss 0.4357 Moving Loss 0.4005 Train Loss 0.4011
# 0.24666523933410645 secs
# Iter 20300 Loss 0.4355 Moving Loss 0.3979 Train Loss 0.3916
# 0.23254728317260742 secs
# Iter 20400 Loss 0.4353 Moving Loss 0.4008 Train Loss 0.3994
# 0.2360086441040039 secs
# Iter 20500 Loss 0.4352 Moving Loss 0.4077 Train Loss 0.4035
# 0.22075963020324707 secs
# Iter 20600 Loss 0.4350 Moving Loss 0.4030 Train Loss 0.3997
# 0.21755194664001465 secs
# Iter 20700 Loss 0.4349 Moving Loss 0.4033 Train Loss 0.4028
# 0.22765684127807617 secs
# Iter 20800 Loss 0.4347 Moving Loss 0.4049 Train Loss 0.3982
# 0.2566542625427246 secs
# Iter 20900 Loss 0.4346 Moving Loss 0.4131 Train Loss 0.4193
# 0.23374223709106445 secs
# Iter 21000 Loss 0.4344 Moving Loss 0.3986 Train Loss 0.3882
# 0.22067999839782715 secs
# Iter 21100 Loss 0.4343 Moving Loss 0.4005 Train Loss 0.3983
# 0.2183239459991455 secs
# Iter 21200 Loss 0.4341 Moving Loss 0.3924 Train Loss 0.3898
# 0.21900463104248047 secs
# Iter 21300 Loss 0.4339 Moving Loss 0.3996 Train Loss 0.3929
# 0.21800780296325684 secs
# Iter 21400 Loss 0.4338 Moving Loss 0.4021 Train Loss 0.4031
# 0.24098610877990723 secs
# Iter 21500 Loss 0.4336 Moving Loss 0.3936 Train Loss 0.3839
# 0.2285294532775879 secs
# Iter 21600 Loss 0.4335 Moving Loss 0.4083 Train Loss 0.4069
# 0.22020983695983887 secs
# Iter 21700 Loss 0.4333 Moving Loss 0.3999 Train Loss 0.3980
# 0.21843886375427246 secs
# Iter 21800 Loss 0.4331 Moving Loss 0.3844 Train Loss 0.3806
# 0.2219698429107666 secs
# Iter 21900 Loss 0.4330 Moving Loss 0.4097 Train Loss 0.4114
# 0.23179864883422852 secs
# Iter 22000 Loss 0.4328 Moving Loss 0.3948 Train Loss 0.3924
# 0.23152852058410645 secs
# Iter 22100 Loss 0.4326 Moving Loss 0.3890 Train Loss 0.3827
# 0.22543931007385254 secs
# Iter 22200 Loss 0.4324 Moving Loss 0.3948 Train Loss 0.3897
# 0.22586798667907715 secs
# Iter 22300 Loss 0.4323 Moving Loss 0.4015 Train Loss 0.3929
# 0.2189774513244629 secs
# Iter 22400 Loss 0.4321 Moving Loss 0.3883 Train Loss 0.3964
# 0.21960163116455078 secs
# Iter 22500 Loss 0.4320 Moving Loss 0.3957 Train Loss 0.3908
# 0.2552518844604492 secs
# Iter 22600 Loss 0.4318 Moving Loss 0.4015 Train Loss 0.3976
# 0.23496413230895996 secs
# Iter 22700 Loss 0.4317 Moving Loss 0.4040 Train Loss 0.3996
# 0.22434139251708984 secs
# Iter 22800 Loss 0.4315 Moving Loss 0.3897 Train Loss 0.3829
# 0.2181992530822754 secs
# Iter 22900 Loss 0.4314 Moving Loss 0.3968 Train Loss 0.3985
# 0.22118902206420898 secs
# Iter 23000 Loss 0.4312 Moving Loss 0.3934 Train Loss 0.3886
# 0.25115275382995605 secs
# Iter 23100 Loss 0.4311 Moving Loss 0.4085 Train Loss 0.4076
# 0.26589035987854004 secs
# Iter 23200 Loss 0.4310 Moving Loss 0.4016 Train Loss 0.3984
# 0.23719072341918945 secs
# Iter 23300 Loss 0.4308 Moving Loss 0.3904 Train Loss 0.3860
# 0.2223515510559082 secs
# Iter 23400 Loss 0.4306 Moving Loss 0.3900 Train Loss 0.3867
# 0.23369073867797852 secs
# Iter 23500 Loss 0.4305 Moving Loss 0.4002 Train Loss 0.3978
# 0.22315311431884766 secs
# Iter 23600 Loss 0.4303 Moving Loss 0.3847 Train Loss 0.3814
# 0.24644780158996582 secs
# Iter 23700 Loss 0.4301 Moving Loss 0.3809 Train Loss 0.3780
# 0.2291734218597412 secs
# Iter 23800 Loss 0.4299 Moving Loss 0.3951 Train Loss 0.3847
# 0.21798324584960938 secs
# Iter 23900 Loss 0.4298 Moving Loss 0.3966 Train Loss 0.4014
# 0.21856451034545898 secs
# Iter 24000 Loss 0.4297 Moving Loss 0.4026 Train Loss 0.3972
# 0.21935343742370605 secs
# Iter 24100 Loss 0.4295 Moving Loss 0.3829 Train Loss 0.3796
# 0.224015474319458 secs
# Iter 24200 Loss 0.4293 Moving Loss 0.3836 Train Loss 0.3784
# 0.2551238536834717 secs
# Iter 24300 Loss 0.4292 Moving Loss 0.4004 Train Loss 0.4031
# 0.22511887550354004 secs
# Iter 24400 Loss 0.4290 Moving Loss 0.3950 Train Loss 0.3898
# 0.2215590476989746 secs
# Iter 24500 Loss 0.4289 Moving Loss 0.3996 Train Loss 0.3992
# 0.21929216384887695 secs
# Iter 24600 Loss 0.4288 Moving Loss 0.3987 Train Loss 0.3882
# 0.21873068809509277 secs
# Iter 24700 Loss 0.4287 Moving Loss 0.3939 Train Loss 0.3975
# 0.2461693286895752 secs
# Iter 24800 Loss 0.4285 Moving Loss 0.3855 Train Loss 0.3831
# 0.2363898754119873 secs
# Iter 24900 Loss 0.4283 Moving Loss 0.3736 Train Loss 0.3646
# 0.21914052963256836 secs
# Iter 25000 Loss 0.4282 Moving Loss 0.4008 Train Loss 0.3979
# 0.21776151657104492 secs
# Iter 25100 Loss 0.4280 Moving Loss 0.3934 Train Loss 0.3930
# 0.2194819450378418 secs
# Iter 25200 Loss 0.4279 Moving Loss 0.3892 Train Loss 0.3838
# 0.2431349754333496 secs
# Iter 25300 Loss 0.4277 Moving Loss 0.3921 Train Loss 0.3921
# 0.2668728828430176 secs
# Iter 25400 Loss 0.4276 Moving Loss 0.3976 Train Loss 0.3926
# 0.21855735778808594 secs
# Iter 25500 Loss 0.4275 Moving Loss 0.3992 Train Loss 0.4007
# 0.21698260307312012 secs
# Iter 25600 Loss 0.4274 Moving Loss 0.3931 Train Loss 0.3899
# 0.21651625633239746 secs
# Iter 25700 Loss 0.4272 Moving Loss 0.3824 Train Loss 0.3744
# 0.2211453914642334 secs
# Iter 25800 Loss 0.4271 Moving Loss 0.4052 Train Loss 0.4055
# 0.2396540641784668 secs
# Iter 25900 Loss 0.4270 Moving Loss 0.4054 Train Loss 0.4046
# 0.2358686923980713 secs
# Iter 26000 Loss 0.4269 Moving Loss 0.4041 Train Loss 0.3997
# 0.2226548194885254 secs
# Iter 26100 Loss 0.4269 Moving Loss 0.4136 Train Loss 0.4113
# 0.2198338508605957 secs
# Iter 26200 Loss 0.4268 Moving Loss 0.3980 Train Loss 0.4034
# 0.21810269355773926 secs
# Iter 26300 Loss 0.4266 Moving Loss 0.3958 Train Loss 0.3837
# 0.21645450592041016 secs
# Iter 26400 Loss 0.4266 Moving Loss 0.4072 Train Loss 0.4079
# 0.2462625503540039 secs
# Iter 26500 Loss 0.4265 Moving Loss 0.4023 Train Loss 0.3965
# 0.21845221519470215 secs
# Iter 26600 Loss 0.4264 Moving Loss 0.3979 Train Loss 0.3931
# 0.22295904159545898 secs
# Iter 26700 Loss 0.4263 Moving Loss 0.3951 Train Loss 0.3949
# 0.21773076057434082 secs
# Iter 26800 Loss 0.4261 Moving Loss 0.3968 Train Loss 0.3919
# 0.21715688705444336 secs
# Iter 26900 Loss 0.4260 Moving Loss 0.3947 Train Loss 0.3915
# 0.2293989658355713 secs
# Iter 27000 Loss 0.4259 Moving Loss 0.3926 Train Loss 0.3937
# 0.2492208480834961 secs
# Iter 27100 Loss 0.4258 Moving Loss 0.3864 Train Loss 0.3786
# 0.22971439361572266 secs
# Iter 27200 Loss 0.4256 Moving Loss 0.3957 Train Loss 0.3952
# 0.2173900604248047 secs
# Iter 27300 Loss 0.4255 Moving Loss 0.3947 Train Loss 0.3922
# 0.21992921829223633 secs
# Iter 27400 Loss 0.4254 Moving Loss 0.3949 Train Loss 0.3920
# 0.22881722450256348 secs
# Iter 27500 Loss 0.4253 Moving Loss 0.3843 Train Loss 0.3774
# 0.2518136501312256 secs
# Iter 27600 Loss 0.4251 Moving Loss 0.3868 Train Loss 0.3853
# 0.22473382949829102 secs
# Iter 27700 Loss 0.4250 Moving Loss 0.4014 Train Loss 0.3975
# 0.21900439262390137 secs
# Iter 27800 Loss 0.4250 Moving Loss 0.4050 Train Loss 0.4050
# 0.2178971767425537 secs
# Iter 27900 Loss 0.4249 Moving Loss 0.4053 Train Loss 0.4086
# 0.2188570499420166 secs
# Iter 28000 Loss 0.4248 Moving Loss 0.3928 Train Loss 0.3866
# 0.22657132148742676 secs
# Iter 28100 Loss 0.4247 Moving Loss 0.3960 Train Loss 0.3972
# 0.25887537002563477 secs
# Iter 28200 Loss 0.4246 Moving Loss 0.3974 Train Loss 0.3942
# 0.21675872802734375 secs
# Iter 28300 Loss 0.4245 Moving Loss 0.3846 Train Loss 0.3821
# 0.2164757251739502 secs
# Iter 28400 Loss 0.4244 Moving Loss 0.3962 Train Loss 0.3890
# 0.21840190887451172 secs
# Iter 28500 Loss 0.4243 Moving Loss 0.3971 Train Loss 0.3974
# 0.2168588638305664 secs
# Iter 28600 Loss 0.4241 Moving Loss 0.3863 Train Loss 0.3896
# 0.24414968490600586 secs
# Iter 28700 Loss 0.4240 Moving Loss 0.3982 Train Loss 0.3862
# 0.23998093605041504 secs
# Iter 28800 Loss 0.4239 Moving Loss 0.3997 Train Loss 0.4010
# 0.21902966499328613 secs
# Iter 28900 Loss 0.4238 Moving Loss 0.3940 Train Loss 0.3963
# 0.22305774688720703 secs
# Iter 29000 Loss 0.4238 Moving Loss 0.4066 Train Loss 0.4005
# 0.21747994422912598 secs
# Iter 29100 Loss 0.4237 Moving Loss 0.4032 Train Loss 0.4014
# 0.21778106689453125 secs
# Iter 29200 Loss 0.4237 Moving Loss 0.4158 Train Loss 0.4160
# 0.2645447254180908 secs
# Iter 29300 Loss 0.4236 Moving Loss 0.4119 Train Loss 0.4130
# 0.22912335395812988 secs
# Iter 29400 Loss 0.4236 Moving Loss 0.3953 Train Loss 0.3877
# 0.21984338760375977 secs
# Iter 29500 Loss 0.4234 Moving Loss 0.3893 Train Loss 0.3888
# 0.22314047813415527 secs
# Iter 29600 Loss 0.4234 Moving Loss 0.4068 Train Loss 0.4001
# 0.2510669231414795 secs
# Iter 29700 Loss 0.4233 Moving Loss 0.3936 Train Loss 0.3971
# 0.259448766708374 secs
# Iter 29800 Loss 0.4232 Moving Loss 0.4081 Train Loss 0.4034
# 0.2449944019317627 secs
# Iter 29900 Loss 0.4232 Moving Loss 0.4051 Train Loss 0.4030
# 0.2197248935699463 secs
# Iter 30000 Loss 0.4231 Moving Loss 0.3946 Train Loss 0.3939
# 0.21893954277038574 secs
# Iter 30100 Loss 0.4230 Moving Loss 0.3881 Train Loss 0.3858
# 0.22024178504943848 secs
# Iter 30200 Loss 0.4229 Moving Loss 0.4014 Train Loss 0.3962
# 0.21915769577026367 secs
# Iter 30300 Loss 0.4227 Moving Loss 0.3808 Train Loss 0.3800
# 0.24611401557922363 secs
# Iter 30400 Loss 0.4226 Moving Loss 0.3909 Train Loss 0.3911
# 0.2219696044921875 secs
# Iter 30500 Loss 0.4226 Moving Loss 0.4121 Train Loss 0.4095
# 0.21798038482666016 secs
# Iter 30600 Loss 0.4225 Moving Loss 0.3880 Train Loss 0.3879
# 0.21709203720092773 secs
# Iter 30700 Loss 0.4224 Moving Loss 0.3908 Train Loss 0.3874
# 0.21693992614746094 secs
# Iter 30800 Loss 0.4223 Moving Loss 0.3896 Train Loss 0.3856
# 0.23120665550231934 secs
# Iter 30900 Loss 0.4222 Moving Loss 0.3817 Train Loss 0.3789
# 0.24758577346801758 secs
# Iter 31000 Loss 0.4221 Moving Loss 0.3957 Train Loss 0.3946
# 0.21918869018554688 secs
# Iter 31100 Loss 0.4220 Moving Loss 0.3998 Train Loss 0.3972
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash decompress.sh output/30_hmm_1m.dzip output/decom_hmm_1m com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5665 Moving Loss 0.5665
# 0.5571389198303223 secs
# Iter 200 Loss 0.5338 Moving Loss 0.5011
# 0.2323901653289795 secs
# Iter 300 Loss 0.5265 Moving Loss 0.5119
# 0.23228216171264648 secs
# Iter 400 Loss 0.5208 Moving Loss 0.5037
# 0.2329423427581787 secs
# Iter 500 Loss 0.5168 Moving Loss 0.5006
# 0.2482130527496338 secs
# Iter 600 Loss 0.5139 Moving Loss 0.4996
# 0.25073909759521484 secs
# Iter 700 Loss 0.5135 Moving Loss 0.5107
# 0.23254036903381348 secs
# Iter 800 Loss 0.5116 Moving Loss 0.4989
# 0.23497843742370605 secs
# Iter 900 Loss 0.5103 Moving Loss 0.5000
# 0.23281407356262207 secs
# Iter 1000 Loss 0.5094 Moving Loss 0.5013
# 0.25152587890625 secs
# Iter 1100 Loss 0.5091 Moving Loss 0.5053
# 0.2636876106262207 secs
# Iter 1200 Loss 0.5087 Moving Loss 0.5049
# 0.23415541648864746 secs
# Iter 1300 Loss 0.5081 Moving Loss 0.5010
# 0.23619699478149414 secs
# Iter 1400 Loss 0.5078 Moving Loss 0.5031
# 0.23984360694885254 secs
# Iter 1500 Loss 0.5071 Moving Loss 0.4970
# 0.2420201301574707 secs
# Iter 1600 Loss 0.5086 Moving Loss 0.5321
# 0.268798828125 secs
# Iter 1700 Loss 0.5081 Moving Loss 0.5000
# 0.26517510414123535 secs
# Iter 1800 Loss 0.5076 Moving Loss 0.4997
# 0.25762128829956055 secs
# Iter 1900 Loss 0.5072 Moving Loss 0.4994
# 0.2490527629852295 secs
# Iter 2000 Loss 0.5070 Moving Loss 0.5021
# 0.2504231929779053 secs
# Iter 2100 Loss 0.5066 Moving Loss 0.4998
# 0.28228330612182617 secs
# Iter 2200 Loss 0.5062 Moving Loss 0.4985
# 0.23505234718322754 secs
# Iter 2300 Loss 0.5061 Moving Loss 0.5019
# 0.2319777011871338 secs
# Iter 2400 Loss 0.5059 Moving Loss 0.5031
# 0.2324380874633789 secs
# Iter 2500 Loss 0.5057 Moving Loss 0.5001
# 0.23282384872436523 secs
# Iter 2600 Loss 0.5054 Moving Loss 0.4978
# 0.2630746364593506 secs
# Iter 2700 Loss 0.5052 Moving Loss 0.4995
# 0.23221611976623535 secs
# Iter 2800 Loss 0.5049 Moving Loss 0.4975
# 0.2622184753417969 secs
# Iter 2900 Loss 0.5048 Moving Loss 0.5030
# 0.2379164695739746 secs
# Iter 3000 Loss 0.5054 Moving Loss 0.5211
# 0.2395920753479004 secs
# Iter 3100 Loss 0.5052 Moving Loss 0.4990
# 0.26804304122924805 secs
# Iter 3200 Loss 0.5050 Moving Loss 0.4999
# 0.23285698890686035 secs
# Iter 3300 Loss 0.5048 Moving Loss 0.4975
# 0.230759859085083 secs
# Iter 3400 Loss 0.5047 Moving Loss 0.5026
# 0.2353222370147705 secs
# Iter 3500 Loss 0.5046 Moving Loss 0.5000
# 0.230316162109375 secs
# Iter 3600 Loss 0.5044 Moving Loss 0.4974
# 0.24039673805236816 secs
# Iter 3700 Loss 0.5041 Moving Loss 0.4955
# 0.2772676944732666 secs
# Iter 3800 Loss 0.5039 Moving Loss 0.4941
# 0.23990201950073242 secs
# Iter 3900 Loss 0.5036 Moving Loss 0.4942
# 0.24918794631958008 secs
# Iter 4000 Loss 0.5041 Moving Loss 0.5244
# 0.2364044189453125 secs
# Iter 4100 Loss 0.5040 Moving Loss 0.4997
# 0.24712562561035156 secs
# Iter 4200 Loss 0.5039 Moving Loss 0.4962
# 0.25664758682250977 secs
# Iter 4300 Loss 0.5037 Moving Loss 0.4959
# 0.23227572441101074 secs
# Iter 4400 Loss 0.5035 Moving Loss 0.4962
# 0.23302531242370605 secs
# Iter 4500 Loss 0.5034 Moving Loss 0.4986
# 0.23851227760314941 secs
# Iter 4600 Loss 0.5032 Moving Loss 0.4931
# 0.24086761474609375 secs
# Iter 4700 Loss 0.5030 Moving Loss 0.4947
# 0.26421594619750977 secs
# Iter 4800 Loss 0.5029 Moving Loss 0.4998
# 0.24487709999084473 secs
# Iter 4900 Loss 0.5027 Moving Loss 0.4918
# 0.2368326187133789 secs
# Iter 5000 Loss 0.5025 Moving Loss 0.4915
# 0.23837971687316895 secs
# Iter 5100 Loss 0.5021 Moving Loss 0.4851
# 0.2412111759185791 secs
# Iter 5200 Loss 0.5019 Moving Loss 0.4900
# 0.26941943168640137 secs
# Iter 5300 Loss 0.5013 Moving Loss 0.4690
# 0.2402040958404541 secs
# Iter 5400 Loss 0.5029 Moving Loss 0.5866
# 0.23522377014160156 secs
# Iter 5500 Loss 0.5028 Moving Loss 0.4981
# 0.23271918296813965 secs
# Iter 5600 Loss 0.5024 Moving Loss 0.4797
# 0.2312455177307129 secs
# Iter 5700 Loss 0.5018 Moving Loss 0.4724
# 0.2599363327026367 secs
# Iter 5800 Loss 0.5012 Moving Loss 0.4632
# 0.2548239231109619 secs
# Iter 5900 Loss 0.5002 Moving Loss 0.4446
# 0.2419734001159668 secs
# Iter 6000 Loss 0.4992 Moving Loss 0.4369
# 0.2433485984802246 secs
# Iter 6100 Loss 0.4982 Moving Loss 0.4422
# 0.23486733436584473 secs
# Iter 6200 Loss 0.4972 Moving Loss 0.4333
# 0.25481224060058594 secs
# Iter 6300 Loss 0.4959 Moving Loss 0.4150
# 0.2479698657989502 secs
# Iter 6400 Loss 0.4947 Moving Loss 0.4187
# 0.2411351203918457 secs
# Iter 6500 Loss 0.4935 Moving Loss 0.4185
# 0.23040246963500977 secs
# Iter 6600 Loss 0.4924 Moving Loss 0.4212
# 0.23132038116455078 secs
# Iter 6700 Loss 0.4912 Moving Loss 0.4148
# 0.24643278121948242 secs
# Iter 6800 Loss 0.4903 Moving Loss 0.4258
# 0.2541060447692871 secs
# Iter 6900 Loss 0.4892 Moving Loss 0.4164
# 0.23432254791259766 secs
# Iter 7000 Loss 0.4882 Moving Loss 0.4185
# 0.2373061180114746 secs
# Iter 7100 Loss 0.4871 Moving Loss 0.4128
# 0.23192977905273438 secs
# Iter 7200 Loss 0.4862 Moving Loss 0.4192
# 0.24181866645812988 secs
# Iter 7300 Loss 0.4852 Moving Loss 0.4168
# 0.25554680824279785 secs
# Iter 7400 Loss 0.4843 Moving Loss 0.4169
# 0.2504148483276367 secs
# Iter 7500 Loss 0.4835 Moving Loss 0.4203
# 0.23438262939453125 secs
# Iter 7600 Loss 0.4826 Moving Loss 0.4205
# 0.2299201488494873 secs
# Iter 7700 Loss 0.4817 Moving Loss 0.4145
# 0.23635649681091309 secs
# Iter 7800 Loss 0.4808 Moving Loss 0.4055
# 0.2543661594390869 secs
# Iter 7900 Loss 0.4800 Moving Loss 0.4200
# 0.24433493614196777 secs
# Iter 8000 Loss 0.4792 Moving Loss 0.4156
# 0.23071765899658203 secs
# Iter 8100 Loss 0.4784 Moving Loss 0.4150
# 0.23158049583435059 secs
# Iter 8200 Loss 0.4777 Moving Loss 0.4188
# 0.23395442962646484 secs
# Iter 8300 Loss 0.4770 Moving Loss 0.4196
# 0.2484581470489502 secs
# Iter 8400 Loss 0.4762 Moving Loss 0.4134
# 0.25751256942749023 secs
# Iter 8500 Loss 0.4755 Moving Loss 0.4111
# 0.22977519035339355 secs
# Iter 8600 Loss 0.4748 Moving Loss 0.4190
# 0.23006916046142578 secs
# Iter 8700 Loss 0.4741 Moving Loss 0.4150
# 0.23024916648864746 secs
# Iter 8800 Loss 0.4735 Moving Loss 0.4237
# 0.2386462688446045 secs
# Iter 8900 Loss 0.4729 Moving Loss 0.4140
# 0.2631840705871582 secs
# Iter 9000 Loss 0.4722 Moving Loss 0.4174
# 0.23618578910827637 secs
# Iter 9100 Loss 0.4717 Moving Loss 0.4250
# 0.2335813045501709 secs
# Iter 9200 Loss 0.4711 Moving Loss 0.4143
# 0.2451767921447754 secs
# Iter 9300 Loss 0.4706 Moving Loss 0.4196
# 0.2503185272216797 secs
# Iter 9400 Loss 0.4700 Moving Loss 0.4182
# 0.2635488510131836 secs
# Iter 9500 Loss 0.4694 Moving Loss 0.4143
# 0.23466825485229492 secs
# Iter 9600 Loss 0.4687 Moving Loss 0.4034
# 0.2351973056793213 secs
# Iter 9700 Loss 0.4680 Moving Loss 0.4023
# 0.2316422462463379 secs
# Iter 9800 Loss 0.4674 Moving Loss 0.4072
# 0.23912763595581055 secs
# Iter 9900 Loss 0.4669 Moving Loss 0.4123
# 0.26730775833129883 secs
# Iter 10000 Loss 0.4663 Moving Loss 0.4138
# 0.2699697017669678 secs
# Iter 10100 Loss 0.4658 Moving Loss 0.4133
# 0.23785901069641113 secs
# Iter 10200 Loss 0.4653 Moving Loss 0.4181
# 0.23114442825317383 secs
# Iter 10300 Loss 0.4648 Moving Loss 0.4084
# 0.23999261856079102 secs
# Iter 10400 Loss 0.4643 Moving Loss 0.4121
# 0.24193406105041504 secs
# Iter 10500 Loss 0.4637 Moving Loss 0.4067
# 0.2471315860748291 secs
# Iter 10600 Loss 0.4633 Moving Loss 0.4145
# 0.22987031936645508 secs
# Iter 10700 Loss 0.4628 Moving Loss 0.4163
# 0.22997784614562988 secs
# Iter 10800 Loss 0.4623 Moving Loss 0.4109
# 0.23967432975769043 secs
# Iter 10900 Loss 0.4618 Moving Loss 0.4005
# 0.2305595874786377 secs
# Iter 11000 Loss 0.4614 Moving Loss 0.4149
# 0.2539992332458496 secs
# Iter 11100 Loss 0.4610 Moving Loss 0.4178
# 0.2355954647064209 secs
# Iter 11200 Loss 0.4606 Moving Loss 0.4180
# 0.2395918369293213 secs
# Iter 11300 Loss 0.4602 Moving Loss 0.4180
# 0.255077600479126 secs
# Iter 11400 Loss 0.4598 Moving Loss 0.4117
# 0.2432878017425537 secs
# Iter 11500 Loss 0.4594 Moving Loss 0.4114
# 0.25636887550354004 secs
# Iter 11600 Loss 0.4590 Moving Loss 0.4206
# 0.23292922973632812 secs
# Iter 11700 Loss 0.4586 Moving Loss 0.4081
# 0.2308952808380127 secs
# Iter 11800 Loss 0.4582 Moving Loss 0.4123
# 0.23597264289855957 secs
# Iter 11900 Loss 0.4578 Moving Loss 0.4155
# 0.24425625801086426 secs
# Iter 12000 Loss 0.4574 Moving Loss 0.4066
# 0.26102304458618164 secs
# Iter 12100 Loss 0.4570 Moving Loss 0.4101
# 0.23285889625549316 secs
# Iter 12200 Loss 0.4567 Moving Loss 0.4168
# 0.23052382469177246 secs
# Iter 12300 Loss 0.4563 Moving Loss 0.4153
# 0.23843812942504883 secs
# Iter 12400 Loss 0.4560 Moving Loss 0.4189
# 0.23847699165344238 secs
# Iter 12500 Loss 0.4556 Moving Loss 0.4052
# 0.2538127899169922 secs
# Iter 12600 Loss 0.4552 Moving Loss 0.4030
# 0.2523062229156494 secs
# Iter 12700 Loss 0.4548 Moving Loss 0.4079
# 0.22962379455566406 secs
# Iter 12800 Loss 0.4545 Moving Loss 0.4091
# 0.23172450065612793 secs
# Iter 12900 Loss 0.4542 Moving Loss 0.4105
# 0.2354419231414795 secs
# Iter 13000 Loss 0.4538 Moving Loss 0.4090
# 0.2301337718963623 secs
# Iter 13100 Loss 0.4534 Moving Loss 0.4016
# 0.2572667598724365 secs
# Iter 13200 Loss 0.4530 Moving Loss 0.3971
# 0.22969484329223633 secs
# Iter 13300 Loss 0.4526 Moving Loss 0.4072
# 0.23453187942504883 secs
# Iter 13400 Loss 0.4523 Moving Loss 0.4085
# 0.2426748275756836 secs
# Iter 13500 Loss 0.4520 Moving Loss 0.4061
# 0.2283329963684082 secs
# Iter 13600 Loss 0.4516 Moving Loss 0.4032
# 0.248152494430542 secs
# Iter 13700 Loss 0.4513 Moving Loss 0.4155
# 0.23546838760375977 secs
# Iter 13800 Loss 0.4510 Moving Loss 0.4044
# 0.2308485507965088 secs
# Iter 13900 Loss 0.4506 Moving Loss 0.4015
# 0.24534225463867188 secs
# Iter 14000 Loss 0.4503 Moving Loss 0.3982
# 0.23996210098266602 secs
# Iter 14100 Loss 0.4500 Moving Loss 0.4166
# 0.2596776485443115 secs
# Iter 14200 Loss 0.4497 Moving Loss 0.4057
# 0.23100876808166504 secs
# Iter 14300 Loss 0.4493 Moving Loss 0.3964
# 0.23081088066101074 secs
# Iter 14400 Loss 0.4490 Moving Loss 0.3939
# 0.2406632900238037 secs
# Iter 14500 Loss 0.4488 Moving Loss 0.4250
# 0.2364673614501953 secs
# Iter 14600 Loss 0.4485 Moving Loss 0.4043
# 0.23821711540222168 secs
# Iter 14700 Loss 0.4482 Moving Loss 0.4078
# 0.24554133415222168 secs
# Iter 14800 Loss 0.4480 Moving Loss 0.4139
# 0.22921204566955566 secs
# Iter 14900 Loss 0.4476 Moving Loss 0.3961
# 0.23301005363464355 secs
# Iter 15000 Loss 0.4473 Moving Loss 0.4033
# 0.23372173309326172 secs
# Iter 15100 Loss 0.4471 Moving Loss 0.4134
# 0.23060965538024902 secs
# Iter 15200 Loss 0.4469 Moving Loss 0.4205
# 0.2606496810913086 secs
# Iter 15300 Loss 0.4467 Moving Loss 0.4154
# 0.24070191383361816 secs
# Iter 15400 Loss 0.4465 Moving Loss 0.4111
# 0.2432386875152588 secs
# Iter 15500 Loss 0.4463 Moving Loss 0.4149
# 0.24011754989624023 secs
# Iter 15600 Loss 0.4460 Moving Loss 0.4025
# 0.22891902923583984 secs
# Iter 15700 Loss 0.4457 Moving Loss 0.4024
# 0.25693273544311523 secs
# Iter 15800 Loss 0.4454 Moving Loss 0.3894
# 0.2405998706817627 secs
# Iter 15900 Loss 0.4451 Moving Loss 0.4010
# 0.22843217849731445 secs
# Iter 16000 Loss 0.4449 Moving Loss 0.4201
# 0.23593354225158691 secs
# Iter 16100 Loss 0.4447 Moving Loss 0.4130
# 0.24120211601257324 secs
# Iter 16200 Loss 0.4445 Moving Loss 0.4073
# 0.25713348388671875 secs
# Iter 16300 Loss 0.4442 Moving Loss 0.3998
# 0.23640036582946777 secs
# Iter 16400 Loss 0.4440 Moving Loss 0.4082
# 0.2377607822418213 secs
# Iter 16500 Loss 0.4438 Moving Loss 0.4124
# 0.23549914360046387 secs
# Iter 16600 Loss 0.4436 Moving Loss 0.4038
# 0.2297039031982422 secs
# Iter 16700 Loss 0.4434 Moving Loss 0.4082
# 0.22897028923034668 secs
# Iter 16800 Loss 0.4431 Moving Loss 0.3890
# 0.2539212703704834 secs
# Iter 16900 Loss 0.4428 Moving Loss 0.3994
# 0.22951102256774902 secs
# Iter 17000 Loss 0.4425 Moving Loss 0.3913
# 0.23565959930419922 secs
# Iter 17100 Loss 0.4423 Moving Loss 0.4054
# 0.2352766990661621 secs
# Iter 17200 Loss 0.4421 Moving Loss 0.4135
# 0.2305445671081543 secs
# Iter 17300 Loss 0.4420 Moving Loss 0.4165
# 0.2546253204345703 secs
# Iter 17400 Loss 0.4418 Moving Loss 0.4183
# 0.23033356666564941 secs
# Iter 17500 Loss 0.4416 Moving Loss 0.3980
# 0.23961472511291504 secs
# Iter 17600 Loss 0.4413 Moving Loss 0.3953
# 0.23956608772277832 secs
# Iter 17700 Loss 0.4410 Moving Loss 0.3870
# 0.2288837432861328 secs
# Iter 17800 Loss 0.4408 Moving Loss 0.4003
# 0.24669194221496582 secs
# Iter 17900 Loss 0.4405 Moving Loss 0.3954
# 0.25887131690979004 secs
# Iter 18000 Loss 0.4403 Moving Loss 0.4037
# 0.23138999938964844 secs
# Iter 18100 Loss 0.4401 Moving Loss 0.3922
# 0.23619389533996582 secs
# Iter 18200 Loss 0.4398 Moving Loss 0.3999
# 0.24562621116638184 secs
# Iter 18300 Loss 0.4396 Moving Loss 0.3949
# 0.24274182319641113 secs
# Iter 18400 Loss 0.4394 Moving Loss 0.4012
# 0.25905609130859375 secs
# Iter 18500 Loss 0.4391 Moving Loss 0.3931
# 0.2285761833190918 secs
# Iter 18600 Loss 0.4388 Moving Loss 0.3862
# 0.24205756187438965 secs
# Iter 18700 Loss 0.4386 Moving Loss 0.3953
# 0.23018622398376465 secs
# Iter 18800 Loss 0.4384 Moving Loss 0.3935
# 0.23326969146728516 secs
# Iter 18900 Loss 0.4381 Moving Loss 0.3904
# 0.2694978713989258 secs
# Iter 19000 Loss 0.4379 Moving Loss 0.4048
# 0.2353506088256836 secs
# Iter 19100 Loss 0.4378 Moving Loss 0.4065
# 0.2446584701538086 secs
# Iter 19200 Loss 0.4376 Moving Loss 0.3994
# 0.22979426383972168 secs
# Iter 19300 Loss 0.4374 Moving Loss 0.3972
# 0.22989559173583984 secs
# Iter 19400 Loss 0.4371 Moving Loss 0.3921
# 0.2550771236419678 secs
# Iter 19500 Loss 0.4370 Moving Loss 0.4160
# 0.24241423606872559 secs
# Iter 19600 Loss 0.4368 Moving Loss 0.3955
# 0.24808239936828613 secs
# Iter 19700 Loss 0.4366 Moving Loss 0.3946
# 0.23627543449401855 secs
# Iter 19800 Loss 0.4364 Moving Loss 0.3933
# 0.22968840599060059 secs
# Iter 19900 Loss 0.4362 Moving Loss 0.4024
# 0.23573017120361328 secs
# Iter 20000 Loss 0.4360 Moving Loss 0.3916
# 0.24795889854431152 secs
# Iter 20100 Loss 0.4358 Moving Loss 0.4070
# 0.23437142372131348 secs
# Iter 20200 Loss 0.4357 Moving Loss 0.4005
# 0.23671197891235352 secs
# Iter 20300 Loss 0.4355 Moving Loss 0.3979
# 0.24167156219482422 secs
# Iter 20400 Loss 0.4353 Moving Loss 0.4008
# 0.23749423027038574 secs
# Iter 20500 Loss 0.4352 Moving Loss 0.4077
# 0.2755875587463379 secs
# Iter 20600 Loss 0.4350 Moving Loss 0.4030
# 0.22882390022277832 secs
# Iter 20700 Loss 0.4349 Moving Loss 0.4033
# 0.24167394638061523 secs
# Iter 20800 Loss 0.4347 Moving Loss 0.4049
# 0.23080921173095703 secs
# Iter 20900 Loss 0.4346 Moving Loss 0.4131
# 0.227431058883667 secs
# Iter 21000 Loss 0.4344 Moving Loss 0.3986
# 0.26093578338623047 secs
# Iter 21100 Loss 0.4343 Moving Loss 0.4005
# 0.2351517677307129 secs
# Iter 21200 Loss 0.4341 Moving Loss 0.3924
# 0.2403709888458252 secs
# Iter 21300 Loss 0.4339 Moving Loss 0.3996
# 0.23932456970214844 secs
# Iter 21400 Loss 0.4338 Moving Loss 0.4021
# 0.23660731315612793 secs
# Iter 21500 Loss 0.4336 Moving Loss 0.3936
# 0.25502848625183105 secs
# Iter 21600 Loss 0.4335 Moving Loss 0.4083
# 0.23237824440002441 secs
# Iter 21700 Loss 0.4333 Moving Loss 0.3999
# 0.23939299583435059 secs
# Iter 21800 Loss 0.4331 Moving Loss 0.3844
# 0.23456525802612305 secs
# Iter 21900 Loss 0.4330 Moving Loss 0.4097
# 0.22825241088867188 secs
# Iter 22000 Loss 0.4328 Moving Loss 0.3948
# 0.23409295082092285 secs
# Iter 22100 Loss 0.4326 Moving Loss 0.3890
# 0.2488541603088379 secs
# Iter 22200 Loss 0.4324 Moving Loss 0.3948
# 0.23752045631408691 secs
# Iter 22300 Loss 0.4323 Moving Loss 0.4015
# 0.2281968593597412 secs
# Iter 22400 Loss 0.4321 Moving Loss 0.3883
# 0.23965764045715332 secs
# Iter 22500 Loss 0.4320 Moving Loss 0.3957
# 0.2288830280303955 secs
# Iter 22600 Loss 0.4318 Moving Loss 0.4015
# 0.24928903579711914 secs
# Iter 22700 Loss 0.4317 Moving Loss 0.4040
# 0.23717164993286133 secs
# Iter 22800 Loss 0.4315 Moving Loss 0.3897
# 0.2372572422027588 secs
# Iter 22900 Loss 0.4314 Moving Loss 0.3968
# 0.22887706756591797 secs
# Iter 23000 Loss 0.4312 Moving Loss 0.3934
# 0.22866272926330566 secs
# Iter 23100 Loss 0.4311 Moving Loss 0.4085
# 0.25316786766052246 secs
# Iter 23200 Loss 0.4310 Moving Loss 0.4016
# 0.25214648246765137 secs
# Iter 23300 Loss 0.4308 Moving Loss 0.3904
# 0.23957610130310059 secs
# Iter 23400 Loss 0.4306 Moving Loss 0.3900
# 0.22875189781188965 secs
# Iter 23500 Loss 0.4305 Moving Loss 0.4002
# 0.228224515914917 secs
# Iter 23600 Loss 0.4303 Moving Loss 0.3847
# 0.2464895248413086 secs
# Iter 23700 Loss 0.4301 Moving Loss 0.3809
# 0.24673151969909668 secs
# Iter 23800 Loss 0.4299 Moving Loss 0.3951
# 0.24622893333435059 secs
# Iter 23900 Loss 0.4298 Moving Loss 0.3966
# 0.23201370239257812 secs
# Iter 24000 Loss 0.4297 Moving Loss 0.4026
# 0.22996258735656738 secs
# Iter 24100 Loss 0.4295 Moving Loss 0.3829
# 0.2314136028289795 secs
# Iter 24200 Loss 0.4293 Moving Loss 0.3836
# 0.25144362449645996 secs
# Iter 24300 Loss 0.4292 Moving Loss 0.4004
# 0.2381753921508789 secs
# Iter 24400 Loss 0.4290 Moving Loss 0.3950
# 0.22857117652893066 secs
# Iter 24500 Loss 0.4289 Moving Loss 0.3996
# 0.24636411666870117 secs
# Iter 24600 Loss 0.4288 Moving Loss 0.3987
# 0.23407888412475586 secs
# Iter 24700 Loss 0.4287 Moving Loss 0.3939
# 0.2581634521484375 secs
# Iter 24800 Loss 0.4285 Moving Loss 0.3855
# 0.23765134811401367 secs
# Iter 24900 Loss 0.4283 Moving Loss 0.3736
# 0.23002862930297852 secs
# Iter 25000 Loss 0.4282 Moving Loss 0.4008
# 0.22818207740783691 secs
# Iter 25100 Loss 0.4280 Moving Loss 0.3934
# 0.22647714614868164 secs
# Iter 25200 Loss 0.4279 Moving Loss 0.3892
# 0.2546241283416748 secs
# Iter 25300 Loss 0.4277 Moving Loss 0.3921
# 0.23376941680908203 secs
# Iter 25400 Loss 0.4276 Moving Loss 0.3976
# 0.24231195449829102 secs
# Iter 25500 Loss 0.4275 Moving Loss 0.3992
# 0.229339599609375 secs
# Iter 25600 Loss 0.4274 Moving Loss 0.3931
# 0.23697137832641602 secs
# Iter 25700 Loss 0.4272 Moving Loss 0.3824
# 0.24509429931640625 secs
# Iter 25800 Loss 0.4271 Moving Loss 0.4052
# 0.25823307037353516 secs
# Iter 25900 Loss 0.4270 Moving Loss 0.4054
# 0.24462246894836426 secs
# Iter 26000 Loss 0.4269 Moving Loss 0.4041
# 0.2265617847442627 secs
# Iter 26100 Loss 0.4269 Moving Loss 0.4136
# 0.2262108325958252 secs
# Iter 26200 Loss 0.4268 Moving Loss 0.3980
# 0.2257840633392334 secs
# Iter 26300 Loss 0.4266 Moving Loss 0.3958
# 0.25785017013549805 secs
# Iter 26400 Loss 0.4266 Moving Loss 0.4072
# 0.23701906204223633 secs
# Iter 26500 Loss 0.4265 Moving Loss 0.4023
# 0.23114728927612305 secs
# Iter 26600 Loss 0.4264 Moving Loss 0.3979
# 0.24773120880126953 secs
# Iter 26700 Loss 0.4263 Moving Loss 0.3951
# 0.24155545234680176 secs
# Iter 26800 Loss 0.4261 Moving Loss 0.3968
# 0.25109291076660156 secs
# Iter 26900 Loss 0.4260 Moving Loss 0.3947
# 0.24695348739624023 secs
# Iter 27000 Loss 0.4259 Moving Loss 0.3926
# 0.2259836196899414 secs
# Iter 27100 Loss 0.4258 Moving Loss 0.3864
# 0.22764348983764648 secs
# Iter 27200 Loss 0.4256 Moving Loss 0.3957
# 0.22699785232543945 secs
# Iter 27300 Loss 0.4255 Moving Loss 0.3947
# 0.23883271217346191 secs
# Iter 27400 Loss 0.4254 Moving Loss 0.3949
# 0.23122644424438477 secs
# Iter 27500 Loss 0.4253 Moving Loss 0.3843
# 0.243011474609375 secs
# Iter 27600 Loss 0.4251 Moving Loss 0.3868
# 0.22861480712890625 secs
# Iter 27700 Loss 0.4250 Moving Loss 0.4014
# 0.22670459747314453 secs
# Iter 27800 Loss 0.4250 Moving Loss 0.4050
# 0.2305293083190918 secs
# Iter 27900 Loss 0.4249 Moving Loss 0.4053
# 0.2535591125488281 secs
# Iter 28000 Loss 0.4248 Moving Loss 0.3928
# 0.24631452560424805 secs
# Iter 28100 Loss 0.4247 Moving Loss 0.3960
# 0.22797775268554688 secs
# Iter 28200 Loss 0.4246 Moving Loss 0.3974
# 0.2267446517944336 secs
# Iter 28300 Loss 0.4245 Moving Loss 0.3846
# 0.2268359661102295 secs
# Iter 28400 Loss 0.4244 Moving Loss 0.3962
# 0.2589535713195801 secs
# Iter 28500 Loss 0.4243 Moving Loss 0.3971
# 0.24920296669006348 secs
# Iter 28600 Loss 0.4241 Moving Loss 0.3863
# 0.22611141204833984 secs
# Iter 28700 Loss 0.4240 Moving Loss 0.3982
# 0.24106264114379883 secs
# Iter 28800 Loss 0.4239 Moving Loss 0.3997
# 0.23654961585998535 secs
# Iter 28900 Loss 0.4238 Moving Loss 0.3940
# 0.24544358253479004 secs
# Iter 29000 Loss 0.4238 Moving Loss 0.4066
# 0.2580137252807617 secs
# Iter 29100 Loss 0.4237 Moving Loss 0.4032
# 0.22603678703308105 secs
# Iter 29200 Loss 0.4237 Moving Loss 0.4158
# 0.22690773010253906 secs
# Iter 29300 Loss 0.4236 Moving Loss 0.4119
# 0.22588443756103516 secs
# Iter 29400 Loss 0.4236 Moving Loss 0.3953
# 0.22584128379821777 secs
# Iter 29500 Loss 0.4234 Moving Loss 0.3893
# 0.2483386993408203 secs
# Iter 29600 Loss 0.4234 Moving Loss 0.4068
# 0.2537343502044678 secs
# Iter 29700 Loss 0.4233 Moving Loss 0.3936
# 0.2339036464691162 secs
# Iter 29800 Loss 0.4232 Moving Loss 0.4081
# 0.22672295570373535 secs
# Iter 29900 Loss 0.4232 Moving Loss 0.4051
# 0.2287003993988037 secs
# Iter 30000 Loss 0.4231 Moving Loss 0.3946
# 0.24184083938598633 secs
# Iter 30100 Loss 0.4230 Moving Loss 0.3881
# 0.25373387336730957 secs
# Iter 30200 Loss 0.4229 Moving Loss 0.4014
# 0.22676396369934082 secs
# Iter 30300 Loss 0.4227 Moving Loss 0.3808
# 0.22524380683898926 secs
# Iter 30400 Loss 0.4226 Moving Loss 0.3909
# 0.22587299346923828 secs
# Iter 30500 Loss 0.4226 Moving Loss 0.4121
# 0.22925019264221191 secs
# Iter 30600 Loss 0.4225 Moving Loss 0.3880
# 0.2617361545562744 secs
# Iter 30700 Loss 0.4224 Moving Loss 0.3908
# 0.23108911514282227 secs
# Iter 30800 Loss 0.4223 Moving Loss 0.3896
# 0.24060320854187012 secs
# Iter 30900 Loss 0.4222 Moving Loss 0.3817
# 0.23170781135559082 secs
# Iter 31000 Loss 0.4221 Moving Loss 0.3957
# 0.22645854949951172 secs
# Iter 31100 Loss 0.4220 Moving Loss 0.3998
# 0.2611863613128662 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/20-order_hidden_markov_chain_1000000.txt" is the same as "output/decom_hmm_1m"
# ```
