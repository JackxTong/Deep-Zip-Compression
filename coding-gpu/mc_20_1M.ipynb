# %% [markdown]
# # Compression logs order-20 HMM 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/20-order_markov_chain_1000000.txt output/20_mc_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/20_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/20-order_markov_chain_1000000.txt output/decom_mc_1m
# ```

# %% [markdown]
# ### Compression Log
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash compress.sh Simulated-data/20-order_markov_chain_1000000.txt output/20_mc_1m.dzip com MODEL_PATH
# Seq Length 1999999
# Using cuda
# Vocab Size 3
# CudNN version 8902
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.5465750694274902 secs
# 3.755585193634033 secs/976 Average loss: 1.7783
# ====> Epoch: 1 Average loss: 0.5125512784: 0.5238
# Loss went from 100000000.0000 to 0.5126
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.24806761741638184 secs
# 3.600121021270752 secs/976 Average loss: 0.5086
# ====> Epoch: 2 Average loss: 0.5002581668: 0.5003
# Loss went from 0.5126 to 0.5003
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23626470565795898 secs
# 3.8227152824401855 secs976 Average loss: 0.4877
# ====> Epoch: 3 Average loss: 0.5002777923: 0.5007
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.25400590896606445 secs
# 3.8487558364868164 secs976 Average loss: 0.4905
# ====> Epoch: 4 Average loss: 0.5001279203: 0.4997
# Loss went from 0.5003 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.24584603309631348 secs
# 3.7991418838500977 secs976 Average loss: 0.4879
# ====> Epoch: 5 Average loss: 0.5001045452: 0.4994
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2370293140411377 secs
# 3.73883318901062 secs1/976 Average loss: 0.4959
# ====> Epoch: 6 Average loss: 0.5001111686: 0.5002
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.27463817596435547 secs
# 3.7944588661193848 secs976 Average loss: 0.4833
# ====> Epoch: 7 Average loss: 0.5000680425: 0.5005
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.22800493240356445 secs
# 3.6785125732421875 secs976 Average loss: 0.5034
# ====> Epoch: 8 Average loss: 0.5000501590: 0.5001
# Loss went from 0.5001 to 0.5001
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# 0.5562996864318848 secs
# Iter 100 Loss 0.5367 Moving Loss 0.5367 Train Loss 0.8927
# 0.22854924201965332 secs
# Iter 200 Loss 0.5214 Moving Loss 0.5061 Train Loss 0.5544
# 0.22156572341918945 secs
# Iter 300 Loss 0.5149 Moving Loss 0.5018 Train Loss 0.5117
# 0.23359942436218262 secs
# Iter 400 Loss 0.5153 Moving Loss 0.5165 Train Loss 0.5753
# 0.22259211540222168 secs
# Iter 500 Loss 0.5122 Moving Loss 0.5000 Train Loss 0.5060
# 0.22177553176879883 secs
# Iter 600 Loss 0.5103 Moving Loss 0.5009 Train Loss 0.5073
# 0.23013949394226074 secs
# Iter 700 Loss 0.5097 Moving Loss 0.5058 Train Loss 0.5258
# 0.22053861618041992 secs
# Iter 800 Loss 0.5086 Moving Loss 0.5008 Train Loss 0.5070
# 0.22219157218933105 secs
# Iter 900 Loss 0.5080 Moving Loss 0.5037 Train Loss 0.5218
# 0.2236769199371338 secs
# Iter 1000 Loss 0.5073 Moving Loss 0.5011 Train Loss 0.5065
# 0.22471022605895996 secs
# Iter 1100 Loss 0.5068 Moving Loss 0.5013 Train Loss 0.5062
# 0.24114322662353516 secs
# Iter 1200 Loss 0.5063 Moving Loss 0.5004 Train Loss 0.5023
# 0.23671770095825195 secs
# Iter 1300 Loss 0.5059 Moving Loss 0.5017 Train Loss 0.5041
# 0.2553269863128662 secs
# Iter 1400 Loss 0.5056 Moving Loss 0.5019 Train Loss 0.5109
# 0.23370051383972168 secs
# Iter 1500 Loss 0.5053 Moving Loss 0.5009 Train Loss 0.5031
# 0.23139667510986328 secs
# Iter 1600 Loss 0.5050 Moving Loss 0.5008 Train Loss 0.5082
# 0.22024321556091309 secs
# Iter 1700 Loss 0.5049 Moving Loss 0.5027 Train Loss 0.5100
# 0.21906256675720215 secs
# Iter 1800 Loss 0.5047 Moving Loss 0.5006 Train Loss 0.5028
# 0.21971511840820312 secs
# Iter 1900 Loss 0.5047 Moving Loss 0.5049 Train Loss 0.5090
# 0.2203505039215088 secs
# Iter 2000 Loss 0.5045 Moving Loss 0.5006 Train Loss 0.5116
# 0.21952414512634277 secs
# Iter 2100 Loss 0.5042 Moving Loss 0.4998 Train Loss 0.5041
# 0.23848938941955566 secs
# Iter 2200 Loss 0.5041 Moving Loss 0.5014 Train Loss 0.5031
# 0.23632192611694336 secs
# Iter 2300 Loss 0.5039 Moving Loss 0.5001 Train Loss 0.5035
# 0.21836447715759277 secs
# Iter 2400 Loss 0.5038 Moving Loss 0.5008 Train Loss 0.5038
# 0.22010540962219238 secs
# Iter 2500 Loss 0.5037 Moving Loss 0.5018 Train Loss 0.5067
# 0.234724760055542 secs
# Iter 2600 Loss 0.5036 Moving Loss 0.4999 Train Loss 0.5015
# 0.2234055995941162 secs
# Iter 2700 Loss 0.5035 Moving Loss 0.5011 Train Loss 0.5037
# 0.22680091857910156 secs
# Iter 2800 Loss 0.5034 Moving Loss 0.4999 Train Loss 0.5011
# 0.22374176979064941 secs
# Iter 2900 Loss 0.5033 Moving Loss 0.5011 Train Loss 0.5030
# 0.2261514663696289 secs
# Iter 3000 Loss 0.5032 Moving Loss 0.5000 Train Loss 0.5022
# 0.22439193725585938 secs
# Iter 3100 Loss 0.5031 Moving Loss 0.5002 Train Loss 0.5017
# 0.22624611854553223 secs
# Iter 3200 Loss 0.5030 Moving Loss 0.5004 Train Loss 0.5019
# 0.22643089294433594 secs
# Iter 3300 Loss 0.5030 Moving Loss 0.5029 Train Loss 0.5066
# 0.2613952159881592 secs
# Iter 3400 Loss 0.5030 Moving Loss 0.5023 Train Loss 0.5170
# 0.23392581939697266 secs
# Iter 3500 Loss 0.5029 Moving Loss 0.5007 Train Loss 0.5039
# 0.272125244140625 secs
# Iter 3600 Loss 0.5028 Moving Loss 0.5003 Train Loss 0.5020
# 0.24777936935424805 secs
# Iter 3700 Loss 0.5028 Moving Loss 0.5012 Train Loss 0.5044
# 0.23221588134765625 secs
# Iter 3800 Loss 0.5027 Moving Loss 0.5009 Train Loss 0.5028
# 0.22577810287475586 secs
# Iter 3900 Loss 0.5027 Moving Loss 0.5003 Train Loss 0.5009
# 0.22527098655700684 secs
# Iter 4000 Loss 0.5026 Moving Loss 0.5007 Train Loss 0.5028
# 0.2231130599975586 secs
# Iter 4100 Loss 0.5026 Moving Loss 0.5007 Train Loss 0.5023
# 0.23747038841247559 secs
# Iter 4200 Loss 0.5025 Moving Loss 0.4995 Train Loss 0.5007
# 0.23718667030334473 secs
# Iter 4300 Loss 0.5024 Moving Loss 0.5001 Train Loss 0.4999
# 0.24430441856384277 secs
# Iter 4400 Loss 0.5024 Moving Loss 0.5003 Train Loss 0.5035
# 0.22311043739318848 secs
# Iter 4500 Loss 0.5024 Moving Loss 0.5002 Train Loss 0.5016
# 0.22241640090942383 secs
# Iter 4600 Loss 0.5023 Moving Loss 0.5007 Train Loss 0.5024
# 0.22182059288024902 secs
# Iter 4700 Loss 0.5023 Moving Loss 0.5000 Train Loss 0.5009
# 0.23244118690490723 secs
# Iter 4800 Loss 0.5022 Moving Loss 0.5006 Train Loss 0.5022
# 0.23421955108642578 secs
# Iter 4900 Loss 0.5022 Moving Loss 0.4998 Train Loss 0.5001
# 0.25075840950012207 secs
# Iter 5000 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5010
# 0.2959778308868408 secs
# Iter 5100 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5014
# 0.2216968536376953 secs
# Iter 5200 Loss 0.5021 Moving Loss 0.5008 Train Loss 0.5024
# 0.22323369979858398 secs
# Iter 5300 Loss 0.5021 Moving Loss 0.5010 Train Loss 0.5037
# 0.22409558296203613 secs
# Iter 5400 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5012
# 0.24639630317687988 secs
# Iter 5500 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5010
# 0.22970819473266602 secs
# Iter 5600 Loss 0.5020 Moving Loss 0.5018 Train Loss 0.5025
# 0.24959778785705566 secs
# Iter 5700 Loss 0.5020 Moving Loss 0.5005 Train Loss 0.5053
# 0.22497844696044922 secs
# Iter 5800 Loss 0.5019 Moving Loss 0.5004 Train Loss 0.5011
# 0.23844099044799805 secs
# Iter 5900 Loss 0.5019 Moving Loss 0.5003 Train Loss 0.5021
# 0.2283637523651123 secs
# Iter 6000 Loss 0.5019 Moving Loss 0.5006 Train Loss 0.5009
# 0.22269129753112793 secs
# Iter 6100 Loss 0.5019 Moving Loss 0.5005 Train Loss 0.5028
# 0.2255263328552246 secs
# Iter 6200 Loss 0.5018 Moving Loss 0.5011 Train Loss 0.5027
# 0.22313833236694336 secs
# Iter 6300 Loss 0.5018 Moving Loss 0.4999 Train Loss 0.5009
# 0.23276686668395996 secs
# Iter 6400 Loss 0.5018 Moving Loss 0.5005 Train Loss 0.5019
# 0.24999308586120605 secs
# Iter 6500 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5014
# 0.23453307151794434 secs
# Iter 6600 Loss 0.5017 Moving Loss 0.5004 Train Loss 0.5011
# 0.22513628005981445 secs
# Iter 6700 Loss 0.5017 Moving Loss 0.5016 Train Loss 0.5025
# 0.24124670028686523 secs
# Iter 6800 Loss 0.5032 Moving Loss 0.6006 Train Loss 0.7234
# 0.23439550399780273 secs
# Iter 6900 Loss 0.5036 Moving Loss 0.5302 Train Loss 0.8050
# 0.22697067260742188 secs
# Iter 7000 Loss 0.5035 Moving Loss 0.5008 Train Loss 0.5032
# 0.23043012619018555 secs
# Iter 7100 Loss 0.5035 Moving Loss 0.5004 Train Loss 0.5028
# 0.22547054290771484 secs
# Iter 7200 Loss 0.5035 Moving Loss 0.4999 Train Loss 0.5007
# 0.22645211219787598 secs
# Iter 7300 Loss 0.5034 Moving Loss 0.5005 Train Loss 0.5006
# 0.22529220581054688 secs
# Iter 7400 Loss 0.5034 Moving Loss 0.5005 Train Loss 0.5032
# 0.22992467880249023 secs
# Iter 7500 Loss 0.5033 Moving Loss 0.5006 Train Loss 0.5020
# 0.24009990692138672 secs
# Iter 7600 Loss 0.5033 Moving Loss 0.5002 Train Loss 0.5010
# 0.23594450950622559 secs
# Iter 7700 Loss 0.5033 Moving Loss 0.5000 Train Loss 0.5004
# 0.23571348190307617 secs
# Iter 7800 Loss 0.5032 Moving Loss 0.5004 Train Loss 0.5012
# 0.24011778831481934 secs
# Iter 7900 Loss 0.5032 Moving Loss 0.4998 Train Loss 0.5001
# 0.24600768089294434 secs
# Iter 8000 Loss 0.5031 Moving Loss 0.5001 Train Loss 0.5006
# 0.23787856101989746 secs
# Iter 8100 Loss 0.5031 Moving Loss 0.5004 Train Loss 0.5017
# 0.22387385368347168 secs
# Iter 8200 Loss 0.5031 Moving Loss 0.5005 Train Loss 0.5020
# 0.22498655319213867 secs
# Iter 8300 Loss 0.5030 Moving Loss 0.5006 Train Loss 0.5021
# 0.22326231002807617 secs
# Iter 8400 Loss 0.5030 Moving Loss 0.5001 Train Loss 0.5009
# 0.22519731521606445 secs
# Iter 8500 Loss 0.5030 Moving Loss 0.4999 Train Loss 0.5005
# 0.24152517318725586 secs
# Iter 8600 Loss 0.5029 Moving Loss 0.5004 Train Loss 0.5016
# 0.2499527931213379 secs
# Iter 8700 Loss 0.5029 Moving Loss 0.5000 Train Loss 0.5006
# 0.22347545623779297 secs
# Iter 8800 Loss 0.5029 Moving Loss 0.5004 Train Loss 0.5023
# 0.22403430938720703 secs
# Iter 8900 Loss 0.5028 Moving Loss 0.5004 Train Loss 0.5014
# 0.23096752166748047 secs
# Iter 9000 Loss 0.5028 Moving Loss 0.5000 Train Loss 0.5011
# 0.23227643966674805 secs
# Iter 9100 Loss 0.5028 Moving Loss 0.5008 Train Loss 0.5015
# 0.23105168342590332 secs
# Iter 9200 Loss 0.5028 Moving Loss 0.5000 Train Loss 0.5008
# 0.24319696426391602 secs
# Iter 9300 Loss 0.5027 Moving Loss 0.5001 Train Loss 0.5007
# 0.22426795959472656 secs
# Iter 9400 Loss 0.5027 Moving Loss 0.5002 Train Loss 0.5011
# 0.22708392143249512 secs
# Iter 9500 Loss 0.5027 Moving Loss 0.5006 Train Loss 0.5015
# 0.22541594505310059 secs
# Iter 9600 Loss 0.5027 Moving Loss 0.5000 Train Loss 0.5005
# 0.22574877738952637 secs
# Iter 9700 Loss 0.5026 Moving Loss 0.5005 Train Loss 0.5017
# 0.24988436698913574 secs
# Iter 9800 Loss 0.5026 Moving Loss 0.4996 Train Loss 0.4999
# 0.23209047317504883 secs
# Iter 9900 Loss 0.5026 Moving Loss 0.5003 Train Loss 0.5009
# 0.2448594570159912 secs
# Iter 10000 Loss 0.5026 Moving Loss 0.5003 Train Loss 0.5012
# 0.2462296485900879 secs
# Iter 10100 Loss 0.5025 Moving Loss 0.5000 Train Loss 0.5001
# 0.23079633712768555 secs
# Iter 10200 Loss 0.5025 Moving Loss 0.5003 Train Loss 0.5013
# 0.22451543807983398 secs
# Iter 10300 Loss 0.5025 Moving Loss 0.5000 Train Loss 0.5007
# 0.22388243675231934 secs
# Iter 10400 Loss 0.5025 Moving Loss 0.5002 Train Loss 0.5009
# 0.22383666038513184 secs
# Iter 10500 Loss 0.5024 Moving Loss 0.5000 Train Loss 0.5007
# 0.22398805618286133 secs
# Iter 10600 Loss 0.5024 Moving Loss 0.5001 Train Loss 0.5012
# 0.2278881072998047 secs
# Iter 10700 Loss 0.5024 Moving Loss 0.5002 Train Loss 0.5005
# 0.2522854804992676 secs
# Iter 10800 Loss 0.5024 Moving Loss 0.4999 Train Loss 0.5002
# 0.24202752113342285 secs
# Iter 10900 Loss 0.5024 Moving Loss 0.5006 Train Loss 0.5018
# 0.22472167015075684 secs
# Iter 11000 Loss 0.5023 Moving Loss 0.5002 Train Loss 0.5007
# 0.22496509552001953 secs
# Iter 11100 Loss 0.5023 Moving Loss 0.5004 Train Loss 0.5013
# 0.23585724830627441 secs
# Iter 11200 Loss 0.5023 Moving Loss 0.5004 Train Loss 0.5013
# 0.23105764389038086 secs
# Iter 11300 Loss 0.5023 Moving Loss 0.5002 Train Loss 0.5010
# 0.22923803329467773 secs
# Iter 11400 Loss 0.5023 Moving Loss 0.5001 Train Loss 0.5005
# 0.22447466850280762 secs
# Iter 11500 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5008
# 0.22577214241027832 secs
# Iter 11600 Loss 0.5022 Moving Loss 0.5003 Train Loss 0.5002
# 0.2275390625 secs
# Iter 11700 Loss 0.5022 Moving Loss 0.5007 Train Loss 0.5033
# 0.22909998893737793 secs
# Iter 11800 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5006
# 0.24270868301391602 secs
# Iter 11900 Loss 0.5022 Moving Loss 0.5003 Train Loss 0.5012
# 0.23117423057556152 secs
# Iter 12000 Loss 0.5022 Moving Loss 0.5008 Train Loss 0.5026
# 0.2380962371826172 secs
# Iter 12100 Loss 0.5022 Moving Loss 0.5005 Train Loss 0.5013
# 0.23621821403503418 secs
# Iter 12200 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5010
# 0.23592472076416016 secs
# Iter 12300 Loss 0.5021 Moving Loss 0.5003 Train Loss 0.5007
# 0.2253279685974121 secs
# Iter 12400 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5001
# 0.22449064254760742 secs
# Iter 12500 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5008
# 0.2249307632446289 secs
# Iter 12600 Loss 0.5021 Moving Loss 0.5007 Train Loss 0.5015
# 0.22386670112609863 secs
# Iter 12700 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5008
# 0.22438764572143555 secs
# Iter 12800 Loss 0.5021 Moving Loss 0.5000 Train Loss 0.5007
# 0.24031925201416016 secs
# Iter 12900 Loss 0.5020 Moving Loss 0.5003 Train Loss 0.5006
# 0.25262951850891113 secs
# Iter 13000 Loss 0.5020 Moving Loss 0.5004 Train Loss 0.5019
# 0.2245466709136963 secs
# Iter 13100 Loss 0.5020 Moving Loss 0.5010 Train Loss 0.5032
# 0.22131586074829102 secs
# Iter 13200 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5006
# 0.22890925407409668 secs
# Iter 13300 Loss 0.5020 Moving Loss 0.5004 Train Loss 0.5014
# 0.2383122444152832 secs
# Iter 13400 Loss 0.5020 Moving Loss 0.5002 Train Loss 0.5008
# 0.22839784622192383 secs
# Iter 13500 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5005
# 0.24036121368408203 secs
# Iter 13600 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5007
# 0.22556591033935547 secs
# Iter 13700 Loss 0.5019 Moving Loss 0.5002 Train Loss 0.5001
# 0.22293663024902344 secs
# Iter 13800 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5009
# 0.2268664836883545 secs
# Iter 13900 Loss 0.5019 Moving Loss 0.5002 Train Loss 0.5011
# 0.22367238998413086 secs
# Iter 14000 Loss 0.5019 Moving Loss 0.5002 Train Loss 0.5007
# 0.24782443046569824 secs
# Iter 14100 Loss 0.5019 Moving Loss 0.5002 Train Loss 0.5007
# 0.22710561752319336 secs
# Iter 14200 Loss 0.5019 Moving Loss 0.5004 Train Loss 0.5011
# 0.24956321716308594 secs
# Iter 14300 Loss 0.5019 Moving Loss 0.5007 Train Loss 0.5021
# 0.24638128280639648 secs
# Iter 14400 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5003
# 0.22964859008789062 secs
# Iter 14500 Loss 0.5018 Moving Loss 0.5007 Train Loss 0.5023
# 0.22638249397277832 secs
# Iter 14600 Loss 0.5018 Moving Loss 0.5003 Train Loss 0.5015
# 0.22243189811706543 secs
# Iter 14700 Loss 0.5018 Moving Loss 0.4999 Train Loss 0.4997
# 0.22329020500183105 secs
# Iter 14800 Loss 0.5018 Moving Loss 0.5003 Train Loss 0.5013
# 0.22107625007629395 secs
# Iter 14900 Loss 0.5018 Moving Loss 0.5009 Train Loss 0.5025
# 0.22261571884155273 secs
# Iter 15000 Loss 0.5018 Moving Loss 0.4999 Train Loss 0.5007
# 0.2392559051513672 secs
# Iter 15100 Loss 0.5018 Moving Loss 0.5005 Train Loss 0.5018
# 0.2482013702392578 secs
# Iter 15200 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5005
# 0.22407746315002441 secs
# Iter 15300 Loss 0.5018 Moving Loss 0.5004 Train Loss 0.5015
# 0.22489404678344727 secs
# Iter 15400 Loss 0.5018 Moving Loss 0.5003 Train Loss 0.5009
# 0.23271560668945312 secs
# Iter 15500 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5006
# 0.2297520637512207 secs
# Iter 15600 Loss 0.5017 Moving Loss 0.4998 Train Loss 0.5003
# 0.22710919380187988 secs
# Iter 15700 Loss 0.5017 Moving Loss 0.5003 Train Loss 0.5003
# 0.22230172157287598 secs
# Iter 15800 Loss 0.5017 Moving Loss 0.5007 Train Loss 0.5023
# 0.22498869895935059 secs
# Iter 15900 Loss 0.5017 Moving Loss 0.5005 Train Loss 0.5018
# 0.22474169731140137 secs
# Iter 16000 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5005
# 0.22843670845031738 secs
# Iter 16100 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5000
# 0.22484517097473145 secs
# Iter 16200 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5010
# 0.24393486976623535 secs
# Iter 16300 Loss 0.5017 Moving Loss 0.5005 Train Loss 0.5007
# 0.2310020923614502 secs
# Iter 16400 Loss 0.5017 Moving Loss 0.5002 Train Loss 0.5011
# 0.29625511169433594 secs
# Iter 16500 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5003
# 0.2718658447265625 secs
# Iter 16600 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5003
# 0.2525765895843506 secs
# Iter 16700 Loss 0.5016 Moving Loss 0.5001 Train Loss 0.5005
# 0.2584817409515381 secs
# Iter 16800 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5007
# 0.23528480529785156 secs
# Iter 16900 Loss 0.5016 Moving Loss 0.4999 Train Loss 0.5007
# 0.2333378791809082 secs
# Iter 17000 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5006
# 0.23272991180419922 secs
# Iter 17100 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5008
# 0.2512204647064209 secs
# Iter 17200 Loss 0.5016 Moving Loss 0.5000 Train Loss 0.5004
# 0.24808096885681152 secs
# Iter 17300 Loss 0.5016 Moving Loss 0.5002 Train Loss 0.5009
# 0.22433042526245117 secs
# Iter 17400 Loss 0.5016 Moving Loss 0.5006 Train Loss 0.5010
# 0.22516298294067383 secs
# Iter 17500 Loss 0.5016 Moving Loss 0.5004 Train Loss 0.5006
# 0.233673095703125 secs
# Iter 17600 Loss 0.5016 Moving Loss 0.5000 Train Loss 0.5020
# 0.2247905731201172 secs
# Iter 17700 Loss 0.5016 Moving Loss 0.5000 Train Loss 0.5001
# 0.22772717475891113 secs
# Iter 17800 Loss 0.5015 Moving Loss 0.5006 Train Loss 0.5016
# 0.24395442008972168 secs
# Iter 17900 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5009
# 0.22303199768066406 secs
# Iter 18000 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5000
# 0.22357797622680664 secs
# Iter 18100 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5009
# 0.22654366493225098 secs
# Iter 18200 Loss 0.5015 Moving Loss 0.4998 Train Loss 0.5004
# 0.22896170616149902 secs
# Iter 18300 Loss 0.5015 Moving Loss 0.5006 Train Loss 0.5019
# 0.24326610565185547 secs
# Iter 18400 Loss 0.5015 Moving Loss 0.5003 Train Loss 0.5005
# 0.2365422248840332 secs
# Iter 18500 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5008
# 0.2552788257598877 secs
# Iter 18600 Loss 0.5015 Moving Loss 0.5007 Train Loss 0.5017
# 0.24315118789672852 secs
# Iter 18700 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.5000
# 0.22385740280151367 secs
# Iter 18800 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5006
# 0.23560142517089844 secs
# Iter 18900 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5006
# 0.22437071800231934 secs
# Iter 19000 Loss 0.5015 Moving Loss 0.5003 Train Loss 0.5004
# 0.22460484504699707 secs
# Iter 19100 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.5005
# 0.22290277481079102 secs
# Iter 19200 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5008
# 0.23996448516845703 secs
# Iter 19300 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.5005
# 0.24588584899902344 secs
# Iter 19400 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.5002
# 0.2276298999786377 secs
# Iter 19500 Loss 0.5014 Moving Loss 0.4998 Train Loss 0.5001
# 0.220872163772583 secs
# Iter 19600 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5003
# 0.22507452964782715 secs
# Iter 19700 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5006
# 0.2305614948272705 secs
# Iter 19800 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5005
# 0.22751331329345703 secs
# Iter 19900 Loss 0.5014 Moving Loss 0.5005 Train Loss 0.5013
# 0.2256793975830078 secs
# Iter 20000 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5001
# 0.22195744514465332 secs
# Iter 20100 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5003
# 0.22394132614135742 secs
# Iter 20200 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5004
# 0.22446584701538086 secs
# Iter 20300 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5003
# 0.2388291358947754 secs
# Iter 20400 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5008
# 0.25676703453063965 secs
# Iter 20500 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5004
# 0.22312545776367188 secs
# Iter 20600 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.5003
# 0.23971152305603027 secs
# Iter 20700 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5001
# 0.24355721473693848 secs
# Iter 20800 Loss 0.5013 Moving Loss 0.5006 Train Loss 0.5016
# 0.23977231979370117 secs
# Iter 20900 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5004
# 0.23113155364990234 secs
# Iter 21000 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5015
# 0.2377457618713379 secs
# Iter 21100 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5004
# 0.22317981719970703 secs
# Iter 21200 Loss 0.5013 Moving Loss 0.5008 Train Loss 0.5006
# 0.22638320922851562 secs
# Iter 21300 Loss 0.5013 Moving Loss 0.4988 Train Loss 0.5012
# 0.2333202362060547 secs
# Iter 21400 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5006
# 0.26414966583251953 secs
# Iter 21500 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5014
# 0.2426750659942627 secs
# Iter 21600 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5003
# 0.22626423835754395 secs
# Iter 21700 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5008
# 0.2298445701599121 secs
# Iter 21800 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5005
# 0.23580098152160645 secs
# Iter 21900 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5002
# 0.22619414329528809 secs
# Iter 22000 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5002
# 0.23587322235107422 secs
# Iter 22100 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5012
# 0.231492280960083 secs
# Iter 22200 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5004
# 0.22623419761657715 secs
# Iter 22300 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5004
# 0.23050308227539062 secs
# Iter 22400 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5014
# 0.22926545143127441 secs
# Iter 22500 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5001
# 0.2349710464477539 secs
# Iter 22600 Loss 0.5013 Moving Loss 0.5008 Train Loss 0.5019
# 0.23680520057678223 secs
# Iter 22700 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5004
# 0.2394084930419922 secs
# Iter 22800 Loss 0.5012 Moving Loss 0.4998 Train Loss 0.5010
# 0.25769495964050293 secs
# Iter 22900 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5002
# 0.22461771965026855 secs
# Iter 23000 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5003
# 0.22232818603515625 secs
# Iter 23100 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5003
# 0.2315382957458496 secs
# Iter 23200 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5000
# 0.23408126831054688 secs
# Iter 23300 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5003
# 0.2221052646636963 secs
# Iter 23400 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5030
# 0.2210075855255127 secs
# Iter 23500 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.24029779434204102 secs
# Iter 23600 Loss 0.5012 Moving Loss 0.5009 Train Loss 0.5023
# 0.2477402687072754 secs
# Iter 23700 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.22586917877197266 secs
# Iter 23800 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5007
# 0.2241668701171875 secs
# Iter 23900 Loss 0.5012 Moving Loss 0.4999 Train Loss 0.5007
# 0.22383403778076172 secs
# Iter 24000 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5002
# 0.2306969165802002 secs
# Iter 24100 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5007
# 0.22700905799865723 secs
# Iter 24200 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5011
# 0.22312378883361816 secs
# Iter 24300 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5013
# 0.22333455085754395 secs
# Iter 24400 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.22324299812316895 secs
# Iter 24500 Loss 0.5012 Moving Loss 0.5009 Train Loss 0.5017
# 0.22405481338500977 secs
# Iter 24600 Loss 0.5012 Moving Loss 0.5005 Train Loss 0.5018
# 0.2261202335357666 secs
# Iter 24700 Loss 0.5012 Moving Loss 0.5004 Train Loss 0.5014
# 0.24245309829711914 secs
# Iter 24800 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5002
# 0.22426891326904297 secs
# Iter 24900 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5007
# 0.24559926986694336 secs
# Iter 25000 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5005
# 0.23813509941101074 secs
# Iter 25100 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5004
# 0.23582077026367188 secs
# Iter 25200 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.2238166332244873 secs
# Iter 25300 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.22493791580200195 secs
# Iter 25400 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5005
# 0.23909640312194824 secs
# Iter 25500 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5000
# 0.23102951049804688 secs
# Iter 25600 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5001
# 0.22605514526367188 secs
# Iter 25700 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5008
# 0.24021124839782715 secs
# Iter 25800 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.24700140953063965 secs
# Iter 25900 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5012
# 0.22574901580810547 secs
# Iter 26000 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5000
# 0.22173857688903809 secs
# Iter 26100 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.23415470123291016 secs
# Iter 26200 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5004
# 0.22886276245117188 secs
# Iter 26300 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5006
# 0.2321019172668457 secs
# Iter 26400 Loss 0.5011 Moving Loss 0.4997 Train Loss 0.5002
# 0.23761296272277832 secs
# Iter 26500 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5007
# 0.22610735893249512 secs
# Iter 26600 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5002
# 0.22648000717163086 secs
# Iter 26700 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5005
# 0.22995495796203613 secs
# Iter 26800 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.4999
# 0.23403453826904297 secs
# Iter 26900 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5006
# 0.23861002922058105 secs
# Iter 27000 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5013
# 0.23653721809387207 secs
# Iter 27100 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.22827577590942383 secs
# Iter 27200 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.4999
# 0.23013591766357422 secs
# Iter 27300 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5002
# 0.22616124153137207 secs
# Iter 27400 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5009
# 0.2284994125366211 secs
# Iter 27500 Loss 0.5011 Moving Loss 0.4998 Train Loss 0.5009
# 0.22842049598693848 secs
# Iter 27600 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5001
# 0.2377300262451172 secs
# Iter 27700 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5006
# 0.22965002059936523 secs
# Iter 27800 Loss 0.5011 Moving Loss 0.5041 Train Loss 0.5180
# 0.23363471031188965 secs
# Iter 27900 Loss 0.5011 Moving Loss 0.4997 Train Loss 0.5017
# 0.2554361820220947 secs
# Iter 28000 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5007
# 0.22843408584594727 secs
# Iter 28100 Loss 0.5011 Moving Loss 0.4997 Train Loss 0.5001
# 0.22710514068603516 secs
# Iter 28200 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.22668194770812988 secs
# Iter 28300 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5001
# 0.2470719814300537 secs
# Iter 28400 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5015
# 0.23786306381225586 secs
# Iter 28500 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5004
# 0.23028206825256348 secs
# Iter 28600 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5017
# 0.22670745849609375 secs
# Iter 28700 Loss 0.5010 Moving Loss 0.5004 Train Loss 0.5009
# 0.22670626640319824 secs
# Iter 28800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5002
# 0.22729873657226562 secs
# Iter 28900 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.22852587699890137 secs
# Iter 29000 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5008
# 0.24587035179138184 secs
# Iter 29100 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.22843074798583984 secs
# Iter 29200 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5005
# 0.2577805519104004 secs
# Iter 29300 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5003
# 0.26720643043518066 secs
# Iter 29400 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5002
# 0.23893070220947266 secs
# Iter 29500 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.4999
# 0.2243046760559082 secs
# Iter 29600 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5010
# 0.22376465797424316 secs
# Iter 29700 Loss 0.5010 Moving Loss 0.5005 Train Loss 0.5013
# 0.2234809398651123 secs
# Iter 29800 Loss 0.5010 Moving Loss 0.5004 Train Loss 0.5011
# 0.23842859268188477 secs
# Iter 29900 Loss 0.5010 Moving Loss 0.4998 Train Loss 0.4999
# 0.2264237403869629 secs
# Iter 30000 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.4999
# 0.24909234046936035 secs
# Iter 30100 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5012
# 0.23316335678100586 secs
# Iter 30200 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.22640633583068848 secs
# Iter 30300 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5009
# 0.22415447235107422 secs
# Iter 30400 Loss 0.5010 Moving Loss 0.4998 Train Loss 0.5001
# 0.23549151420593262 secs
# Iter 30500 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5001
# 0.22387361526489258 secs
# Iter 30600 Loss 0.5010 Moving Loss 0.5015 Train Loss 0.5056
# 0.23882508277893066 secs
# Iter 30700 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5001
# 0.23097634315490723 secs
# Iter 30800 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5002
# 0.22435426712036133 secs
# Iter 30900 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5000
# 0.22492265701293945 secs
# Iter 31000 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5004
# 0.22495508193969727 secs
# Iter 31100 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5003
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash decompress.sh output/20_mc_1m.dzip output/decom_mc_1m com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5367 Moving Loss 0.5367
# 0.5617306232452393 secs
# Iter 200 Loss 0.5214 Moving Loss 0.5061
# 0.25670933723449707 secs
# Iter 300 Loss 0.5149 Moving Loss 0.5018
# 0.23360371589660645 secs
# Iter 400 Loss 0.5153 Moving Loss 0.5165
# 0.2332134246826172 secs
# Iter 500 Loss 0.5122 Moving Loss 0.5000
# 0.2365856170654297 secs
# Iter 600 Loss 0.5103 Moving Loss 0.5009
# 0.25071191787719727 secs
# Iter 700 Loss 0.5097 Moving Loss 0.5058
# 0.2673017978668213 secs
# Iter 800 Loss 0.5086 Moving Loss 0.5008
# 0.23538494110107422 secs
# Iter 900 Loss 0.5080 Moving Loss 0.5037
# 0.23485469818115234 secs
# Iter 1000 Loss 0.5073 Moving Loss 0.5011
# 0.248138427734375 secs
# Iter 1100 Loss 0.5068 Moving Loss 0.5013
# 0.2394089698791504 secs
# Iter 1200 Loss 0.5063 Moving Loss 0.5004
# 0.23440957069396973 secs
# Iter 1300 Loss 0.5059 Moving Loss 0.5017
# 0.24100017547607422 secs
# Iter 1400 Loss 0.5056 Moving Loss 0.5019
# 0.24922847747802734 secs
# Iter 1500 Loss 0.5053 Moving Loss 0.5009
# 0.2343592643737793 secs
# Iter 1600 Loss 0.5050 Moving Loss 0.5008
# 0.23506665229797363 secs
# Iter 1700 Loss 0.5049 Moving Loss 0.5027
# 0.24999737739562988 secs
# Iter 1800 Loss 0.5047 Moving Loss 0.5006
# 0.23987174034118652 secs
# Iter 1900 Loss 0.5047 Moving Loss 0.5049
# 0.232987642288208 secs
# Iter 2000 Loss 0.5045 Moving Loss 0.5006
# 0.24015331268310547 secs
# Iter 2100 Loss 0.5042 Moving Loss 0.4998
# 0.3058433532714844 secs
# Iter 2200 Loss 0.5041 Moving Loss 0.5014
# 0.24610209465026855 secs
# Iter 2300 Loss 0.5039 Moving Loss 0.5001
# 0.2416839599609375 secs
# Iter 2400 Loss 0.5038 Moving Loss 0.5008
# 0.23274827003479004 secs
# Iter 2500 Loss 0.5037 Moving Loss 0.5018
# 0.2321934700012207 secs
# Iter 2600 Loss 0.5036 Moving Loss 0.4999
# 0.2359931468963623 secs
# Iter 2700 Loss 0.5035 Moving Loss 0.5011
# 0.25622105598449707 secs
# Iter 2800 Loss 0.5034 Moving Loss 0.4999
# 0.237105131149292 secs
# Iter 2900 Loss 0.5033 Moving Loss 0.5011
# 0.23328590393066406 secs
# Iter 3000 Loss 0.5032 Moving Loss 0.5000
# 0.23207831382751465 secs
# Iter 3100 Loss 0.5031 Moving Loss 0.5002
# 0.24683833122253418 secs
# Iter 3200 Loss 0.5030 Moving Loss 0.5004
# 0.22961688041687012 secs
# Iter 3300 Loss 0.5030 Moving Loss 0.5029
# 0.23152780532836914 secs
# Iter 3400 Loss 0.5030 Moving Loss 0.5023
# 0.23306536674499512 secs
# Iter 3500 Loss 0.5029 Moving Loss 0.5007
# 0.23757529258728027 secs
# Iter 3600 Loss 0.5028 Moving Loss 0.5003
# 0.23011469841003418 secs
# Iter 3700 Loss 0.5028 Moving Loss 0.5012
# 0.23337507247924805 secs
# Iter 3800 Loss 0.5027 Moving Loss 0.5009
# 0.2490854263305664 secs
# Iter 3900 Loss 0.5027 Moving Loss 0.5003
# 0.23190760612487793 secs
# Iter 4000 Loss 0.5026 Moving Loss 0.5007
# 0.2384333610534668 secs
# Iter 4100 Loss 0.5026 Moving Loss 0.5007
# 0.2340536117553711 secs
# Iter 4200 Loss 0.5025 Moving Loss 0.4995
# 0.23601913452148438 secs
# Iter 4300 Loss 0.5024 Moving Loss 0.5001
# 0.23315906524658203 secs
# Iter 4400 Loss 0.5024 Moving Loss 0.5003
# 0.2393193244934082 secs
# Iter 4500 Loss 0.5024 Moving Loss 0.5002
# 0.23102712631225586 secs
# Iter 4600 Loss 0.5023 Moving Loss 0.5007
# 0.23501157760620117 secs
# Iter 4700 Loss 0.5023 Moving Loss 0.5000
# 0.2339916229248047 secs
# Iter 4800 Loss 0.5022 Moving Loss 0.5006
# 0.25840210914611816 secs
# Iter 4900 Loss 0.5022 Moving Loss 0.4998
# 0.24025535583496094 secs
# Iter 5000 Loss 0.5021 Moving Loss 0.5000
# 0.23538446426391602 secs
# Iter 5100 Loss 0.5021 Moving Loss 0.5002
# 0.23290324211120605 secs
# Iter 5200 Loss 0.5021 Moving Loss 0.5008
# 0.24706506729125977 secs
# Iter 5300 Loss 0.5021 Moving Loss 0.5010
# 0.23723173141479492 secs
# Iter 5400 Loss 0.5020 Moving Loss 0.5000
# 0.244157075881958 secs
# Iter 5500 Loss 0.5020 Moving Loss 0.5001
# 0.24468111991882324 secs
# Iter 5600 Loss 0.5020 Moving Loss 0.5018
# 0.24188590049743652 secs
# Iter 5700 Loss 0.5020 Moving Loss 0.5005
# 0.2340402603149414 secs
# Iter 5800 Loss 0.5019 Moving Loss 0.5004
# 0.2552154064178467 secs
# Iter 5900 Loss 0.5019 Moving Loss 0.5003
# 0.24092912673950195 secs
# Iter 6000 Loss 0.5019 Moving Loss 0.5006
# 0.2366950511932373 secs
# Iter 6100 Loss 0.5019 Moving Loss 0.5005
# 0.25227880477905273 secs
# Iter 6200 Loss 0.5018 Moving Loss 0.5011
# 0.24590730667114258 secs
# Iter 6300 Loss 0.5018 Moving Loss 0.4999
# 0.24453520774841309 secs
# Iter 6400 Loss 0.5018 Moving Loss 0.5005
# 0.23786234855651855 secs
# Iter 6500 Loss 0.5018 Moving Loss 0.5002
# 0.23471903800964355 secs
# Iter 6600 Loss 0.5017 Moving Loss 0.5004
# 0.24495697021484375 secs
# Iter 6700 Loss 0.5017 Moving Loss 0.5016
# 0.23810672760009766 secs
# Iter 6800 Loss 0.5032 Moving Loss 0.6006
# 0.2457568645477295 secs
# Iter 6900 Loss 0.5036 Moving Loss 0.5302
# 0.25426673889160156 secs
# Iter 7000 Loss 0.5035 Moving Loss 0.5008
# 0.2368321418762207 secs
# Iter 7100 Loss 0.5035 Moving Loss 0.5004
# 0.2337183952331543 secs
# Iter 7200 Loss 0.5035 Moving Loss 0.4999
# 0.23677945137023926 secs
# Iter 7300 Loss 0.5034 Moving Loss 0.5005
# 0.24711871147155762 secs
# Iter 7400 Loss 0.5034 Moving Loss 0.5005
# 0.23308634757995605 secs
# Iter 7500 Loss 0.5033 Moving Loss 0.5006
# 0.23866891860961914 secs
# Iter 7600 Loss 0.5033 Moving Loss 0.5002
# 0.23516011238098145 secs
# Iter 7700 Loss 0.5033 Moving Loss 0.5000
# 0.2409968376159668 secs
# Iter 7800 Loss 0.5032 Moving Loss 0.5004
# 0.23570489883422852 secs
# Iter 7900 Loss 0.5032 Moving Loss 0.4998
# 0.2575690746307373 secs
# Iter 8000 Loss 0.5031 Moving Loss 0.5001
# 0.23273110389709473 secs
# Iter 8100 Loss 0.5031 Moving Loss 0.5004
# 0.23510193824768066 secs
# Iter 8200 Loss 0.5031 Moving Loss 0.5005
# 0.25090622901916504 secs
# Iter 8300 Loss 0.5030 Moving Loss 0.5006
# 0.23624873161315918 secs
# Iter 8400 Loss 0.5030 Moving Loss 0.5001
# 0.23280644416809082 secs
# Iter 8500 Loss 0.5030 Moving Loss 0.4999
# 0.23136520385742188 secs
# Iter 8600 Loss 0.5029 Moving Loss 0.5004
# 0.23288226127624512 secs
# Iter 8700 Loss 0.5029 Moving Loss 0.5000
# 0.24346256256103516 secs
# Iter 8800 Loss 0.5029 Moving Loss 0.5004
# 0.23084664344787598 secs
# Iter 8900 Loss 0.5028 Moving Loss 0.5004
# 0.25478315353393555 secs
# Iter 9000 Loss 0.5028 Moving Loss 0.5000
# 0.23853111267089844 secs
# Iter 9100 Loss 0.5028 Moving Loss 0.5008
# 0.2332465648651123 secs
# Iter 9200 Loss 0.5028 Moving Loss 0.5000
# 0.23087096214294434 secs
# Iter 9300 Loss 0.5027 Moving Loss 0.5001
# 0.23421192169189453 secs
# Iter 9400 Loss 0.5027 Moving Loss 0.5002
# 0.24269700050354004 secs
# Iter 9500 Loss 0.5027 Moving Loss 0.5006
# 0.23117685317993164 secs
# Iter 9600 Loss 0.5027 Moving Loss 0.5000
# 0.25078511238098145 secs
# Iter 9700 Loss 0.5026 Moving Loss 0.5005
# 0.2315371036529541 secs
# Iter 9800 Loss 0.5026 Moving Loss 0.4996
# 0.24080348014831543 secs
# Iter 9900 Loss 0.5026 Moving Loss 0.5003
# 0.25179076194763184 secs
# Iter 10000 Loss 0.5026 Moving Loss 0.5003
# 0.23570513725280762 secs
# Iter 10100 Loss 0.5025 Moving Loss 0.5000
# 0.23053288459777832 secs
# Iter 10200 Loss 0.5025 Moving Loss 0.5003
# 0.23312139511108398 secs
# Iter 10300 Loss 0.5025 Moving Loss 0.5000
# 0.24992156028747559 secs
# Iter 10400 Loss 0.5025 Moving Loss 0.5002
# 0.24716758728027344 secs
# Iter 10500 Loss 0.5024 Moving Loss 0.5000
# 0.2458333969116211 secs
# Iter 10600 Loss 0.5024 Moving Loss 0.5001
# 0.23392033576965332 secs
# Iter 10700 Loss 0.5024 Moving Loss 0.5002
# 0.23145747184753418 secs
# Iter 10800 Loss 0.5024 Moving Loss 0.4999
# 0.24063801765441895 secs
# Iter 10900 Loss 0.5024 Moving Loss 0.5006
# 0.2505035400390625 secs
# Iter 11000 Loss 0.5023 Moving Loss 0.5002
# 0.23815393447875977 secs
# Iter 11100 Loss 0.5023 Moving Loss 0.5004
# 0.23807096481323242 secs
# Iter 11200 Loss 0.5023 Moving Loss 0.5004
# 0.2312335968017578 secs
# Iter 11300 Loss 0.5023 Moving Loss 0.5002
# 0.23157596588134766 secs
# Iter 11400 Loss 0.5023 Moving Loss 0.5001
# 0.23802995681762695 secs
# Iter 11500 Loss 0.5022 Moving Loss 0.5002
# 0.24071502685546875 secs
# Iter 11600 Loss 0.5022 Moving Loss 0.5003
# 0.23038434982299805 secs
# Iter 11700 Loss 0.5022 Moving Loss 0.5007
# 0.24356627464294434 secs
# Iter 11800 Loss 0.5022 Moving Loss 0.5002
# 0.23040556907653809 secs
# Iter 11900 Loss 0.5022 Moving Loss 0.5003
# 0.23575115203857422 secs
# Iter 12000 Loss 0.5022 Moving Loss 0.5008
# 0.25092315673828125 secs
# Iter 12100 Loss 0.5022 Moving Loss 0.5005
# 0.23360824584960938 secs
# Iter 12200 Loss 0.5021 Moving Loss 0.5002
# 0.23042058944702148 secs
# Iter 12300 Loss 0.5021 Moving Loss 0.5003
# 0.23361682891845703 secs
# Iter 12400 Loss 0.5021 Moving Loss 0.5000
# 0.25091075897216797 secs
# Iter 12500 Loss 0.5021 Moving Loss 0.5000
# 0.24066543579101562 secs
# Iter 12600 Loss 0.5021 Moving Loss 0.5007
# 0.23176002502441406 secs
# Iter 12700 Loss 0.5021 Moving Loss 0.5002
# 0.2303917407989502 secs
# Iter 12800 Loss 0.5021 Moving Loss 0.5000
# 0.2325129508972168 secs
# Iter 12900 Loss 0.5020 Moving Loss 0.5003
# 0.233811616897583 secs
# Iter 13000 Loss 0.5020 Moving Loss 0.5004
# 0.26710057258605957 secs
# Iter 13100 Loss 0.5020 Moving Loss 0.5010
# 0.23435425758361816 secs
# Iter 13200 Loss 0.5020 Moving Loss 0.5001
# 0.269512414932251 secs
# Iter 13300 Loss 0.5020 Moving Loss 0.5004
# 0.24920153617858887 secs
# Iter 13400 Loss 0.5020 Moving Loss 0.5002
# 0.23950815200805664 secs
# Iter 13500 Loss 0.5020 Moving Loss 0.5001
# 0.2473909854888916 secs
# Iter 13600 Loss 0.5020 Moving Loss 0.5001
# 0.25316667556762695 secs
# Iter 13700 Loss 0.5019 Moving Loss 0.5002
# 0.24374747276306152 secs
# Iter 13800 Loss 0.5019 Moving Loss 0.5000
# 0.25353097915649414 secs
# Iter 13900 Loss 0.5019 Moving Loss 0.5002
# 0.24798917770385742 secs
# Iter 14000 Loss 0.5019 Moving Loss 0.5002
# 0.2598991394042969 secs
# Iter 14100 Loss 0.5019 Moving Loss 0.5002
# 0.24309062957763672 secs
# Iter 14200 Loss 0.5019 Moving Loss 0.5004
# 0.2385091781616211 secs
# Iter 14300 Loss 0.5019 Moving Loss 0.5007
# 0.2384049892425537 secs
# Iter 14400 Loss 0.5019 Moving Loss 0.5001
# 0.2508563995361328 secs
# Iter 14500 Loss 0.5018 Moving Loss 0.5007
# 0.24769043922424316 secs
# Iter 14600 Loss 0.5018 Moving Loss 0.5003
# 0.2443544864654541 secs
# Iter 14700 Loss 0.5018 Moving Loss 0.4999
# 0.23582839965820312 secs
# Iter 14800 Loss 0.5018 Moving Loss 0.5003
# 0.23254680633544922 secs
# Iter 14900 Loss 0.5018 Moving Loss 0.5009
# 0.2342221736907959 secs
# Iter 15000 Loss 0.5018 Moving Loss 0.4999
# 0.26108574867248535 secs
# Iter 15100 Loss 0.5018 Moving Loss 0.5005
# 0.2731354236602783 secs
# Iter 15200 Loss 0.5018 Moving Loss 0.5002
# 0.2517862319946289 secs
# Iter 15300 Loss 0.5018 Moving Loss 0.5004
# 0.24300122261047363 secs
# Iter 15400 Loss 0.5018 Moving Loss 0.5003
# 0.24118423461914062 secs
# Iter 15500 Loss 0.5017 Moving Loss 0.5000
# 0.25907087326049805 secs
# Iter 15600 Loss 0.5017 Moving Loss 0.4998
# 0.24239039421081543 secs
# Iter 15700 Loss 0.5017 Moving Loss 0.5003
# 0.23449134826660156 secs
# Iter 15800 Loss 0.5017 Moving Loss 0.5007
# 0.23767423629760742 secs
# Iter 15900 Loss 0.5017 Moving Loss 0.5005
# 0.23492813110351562 secs
# Iter 16000 Loss 0.5017 Moving Loss 0.5001
# 0.2608785629272461 secs
# Iter 16100 Loss 0.5017 Moving Loss 0.5001
# 0.23376893997192383 secs
# Iter 16200 Loss 0.5017 Moving Loss 0.5001
# 0.23621487617492676 secs
# Iter 16300 Loss 0.5017 Moving Loss 0.5005
# 0.23683476448059082 secs
# Iter 16400 Loss 0.5017 Moving Loss 0.5002
# 0.23578739166259766 secs
# Iter 16500 Loss 0.5017 Moving Loss 0.5001
# 0.24672412872314453 secs
# Iter 16600 Loss 0.5016 Moving Loss 0.5002
# 0.23382019996643066 secs
# Iter 16700 Loss 0.5016 Moving Loss 0.5001
# 0.23245882987976074 secs
# Iter 16800 Loss 0.5016 Moving Loss 0.5003
# 0.23232817649841309 secs
# Iter 16900 Loss 0.5016 Moving Loss 0.4999
# 0.23279595375061035 secs
# Iter 17000 Loss 0.5016 Moving Loss 0.5002
# 0.26015639305114746 secs
# Iter 17100 Loss 0.5016 Moving Loss 0.5002
# 0.24242424964904785 secs
# Iter 17200 Loss 0.5016 Moving Loss 0.5000
# 0.25365686416625977 secs
# Iter 17300 Loss 0.5016 Moving Loss 0.5002
# 0.2629585266113281 secs
# Iter 17400 Loss 0.5016 Moving Loss 0.5006
# 0.23482918739318848 secs
# Iter 17500 Loss 0.5016 Moving Loss 0.5004
# 0.23243069648742676 secs
# Iter 17600 Loss 0.5016 Moving Loss 0.5000
# 0.2452549934387207 secs
# Iter 17700 Loss 0.5016 Moving Loss 0.5000
# 0.24068522453308105 secs
# Iter 17800 Loss 0.5015 Moving Loss 0.5006
# 0.2351226806640625 secs
# Iter 17900 Loss 0.5015 Moving Loss 0.5002
# 0.2497873306274414 secs
# Iter 18000 Loss 0.5015 Moving Loss 0.5001
# 0.2598762512207031 secs
# Iter 18100 Loss 0.5015 Moving Loss 0.5002
# 0.2411212921142578 secs
# Iter 18200 Loss 0.5015 Moving Loss 0.4998
# 0.2382199764251709 secs
# Iter 18300 Loss 0.5015 Moving Loss 0.5006
# 0.233198881149292 secs
# Iter 18400 Loss 0.5015 Moving Loss 0.5003
# 0.232712984085083 secs
# Iter 18500 Loss 0.5015 Moving Loss 0.5001
# 0.24145078659057617 secs
# Iter 18600 Loss 0.5015 Moving Loss 0.5007
# 0.23400402069091797 secs
# Iter 18700 Loss 0.5015 Moving Loss 0.5000
# 0.2331836223602295 secs
# Iter 18800 Loss 0.5015 Moving Loss 0.5001
# 0.2314906120300293 secs
# Iter 18900 Loss 0.5015 Moving Loss 0.5002
# 0.2333066463470459 secs
# Iter 19000 Loss 0.5015 Moving Loss 0.5003
# 0.2524592876434326 secs
# Iter 19100 Loss 0.5015 Moving Loss 0.5000
# 0.24305415153503418 secs
# Iter 19200 Loss 0.5015 Moving Loss 0.5001
# 0.23114776611328125 secs
# Iter 19300 Loss 0.5014 Moving Loss 0.4999
# 0.2518796920776367 secs
# Iter 19400 Loss 0.5014 Moving Loss 0.4999
# 0.23376035690307617 secs
# Iter 19500 Loss 0.5014 Moving Loss 0.4998
# 0.23230481147766113 secs
# Iter 19600 Loss 0.5014 Moving Loss 0.5001
# 0.2310044765472412 secs
# Iter 19700 Loss 0.5014 Moving Loss 0.5002
# 0.24488186836242676 secs
# Iter 19800 Loss 0.5014 Moving Loss 0.5000
# 0.23748230934143066 secs
# Iter 19900 Loss 0.5014 Moving Loss 0.5005
# 0.23481273651123047 secs
# Iter 20000 Loss 0.5014 Moving Loss 0.5000
# 0.23303747177124023 secs
# Iter 20100 Loss 0.5014 Moving Loss 0.5001
# 0.25779032707214355 secs
# Iter 20200 Loss 0.5014 Moving Loss 0.5000
# 0.23188543319702148 secs
# Iter 20300 Loss 0.5014 Moving Loss 0.5002
# 0.23333454132080078 secs
# Iter 20400 Loss 0.5014 Moving Loss 0.5002
# 0.23351049423217773 secs
# Iter 20500 Loss 0.5014 Moving Loss 0.5001
# 0.2313849925994873 secs
# Iter 20600 Loss 0.5014 Moving Loss 0.4999
# 0.23970913887023926 secs
# Iter 20700 Loss 0.5013 Moving Loss 0.5001
# 0.27985715866088867 secs
# Iter 20800 Loss 0.5013 Moving Loss 0.5006
# 0.2696716785430908 secs
# Iter 20900 Loss 0.5013 Moving Loss 0.5001
# 0.23234105110168457 secs
# Iter 21000 Loss 0.5013 Moving Loss 0.5005
# 0.23309540748596191 secs
# Iter 21100 Loss 0.5013 Moving Loss 0.5002
# 0.24690914154052734 secs
# Iter 21200 Loss 0.5013 Moving Loss 0.5008
# 0.23302054405212402 secs
# Iter 21300 Loss 0.5013 Moving Loss 0.4988
# 0.23337936401367188 secs
# Iter 21400 Loss 0.5013 Moving Loss 0.5002
# 0.24496150016784668 secs
# Iter 21500 Loss 0.5013 Moving Loss 0.5002
# 0.23406291007995605 secs
# Iter 21600 Loss 0.5013 Moving Loss 0.5002
# 0.23430132865905762 secs
# Iter 21700 Loss 0.5013 Moving Loss 0.5002
# 0.23053812980651855 secs
# Iter 21800 Loss 0.5013 Moving Loss 0.5002
# 0.24774765968322754 secs
# Iter 21900 Loss 0.5013 Moving Loss 0.5001
# 0.23533177375793457 secs
# Iter 22000 Loss 0.5013 Moving Loss 0.5002
# 0.23432660102844238 secs
# Iter 22100 Loss 0.5013 Moving Loss 0.5005
# 0.26213717460632324 secs
# Iter 22200 Loss 0.5013 Moving Loss 0.5000
# 0.23793649673461914 secs
# Iter 22300 Loss 0.5013 Moving Loss 0.5001
# 0.23546528816223145 secs
# Iter 22400 Loss 0.5013 Moving Loss 0.5005
# 0.2362501621246338 secs
# Iter 22500 Loss 0.5013 Moving Loss 0.5000
# 0.23136067390441895 secs
# Iter 22600 Loss 0.5013 Moving Loss 0.5008
# 0.2333545684814453 secs
# Iter 22700 Loss 0.5013 Moving Loss 0.5001
# 0.24382734298706055 secs
# Iter 22800 Loss 0.5012 Moving Loss 0.4998
# 0.24609732627868652 secs
# Iter 22900 Loss 0.5012 Moving Loss 0.5001
# 0.2430124282836914 secs
# Iter 23000 Loss 0.5012 Moving Loss 0.5001
# 0.23430252075195312 secs
# Iter 23100 Loss 0.5012 Moving Loss 0.5000
# 0.24200868606567383 secs
# Iter 23200 Loss 0.5012 Moving Loss 0.5001
# 0.242034912109375 secs
# Iter 23300 Loss 0.5012 Moving Loss 0.5006
# 0.2333683967590332 secs
# Iter 23400 Loss 0.5012 Moving Loss 0.5006
# 0.23352479934692383 secs
# Iter 23500 Loss 0.5012 Moving Loss 0.5001
# 0.23905301094055176 secs
# Iter 23600 Loss 0.5012 Moving Loss 0.5009
# 0.24151992797851562 secs
# Iter 23700 Loss 0.5012 Moving Loss 0.5001
# 0.23317623138427734 secs
# Iter 23800 Loss 0.5012 Moving Loss 0.5002
# 0.22948980331420898 secs
# Iter 23900 Loss 0.5012 Moving Loss 0.4999
# 0.2503790855407715 secs
# Iter 24000 Loss 0.5012 Moving Loss 0.5000
# 0.2349410057067871 secs
# Iter 24100 Loss 0.5012 Moving Loss 0.5001
# 0.2374732494354248 secs
# Iter 24200 Loss 0.5012 Moving Loss 0.5006
# 0.2512028217315674 secs
# Iter 24300 Loss 0.5012 Moving Loss 0.5002
# 0.23833227157592773 secs
# Iter 24400 Loss 0.5012 Moving Loss 0.5001
# 0.2332158088684082 secs
# Iter 24500 Loss 0.5012 Moving Loss 0.5009
# 0.24189114570617676 secs
# Iter 24600 Loss 0.5012 Moving Loss 0.5005
# 0.24202370643615723 secs
# Iter 24700 Loss 0.5012 Moving Loss 0.5004
# 0.23070383071899414 secs
# Iter 24800 Loss 0.5012 Moving Loss 0.5001
# 0.24876904487609863 secs
# Iter 24900 Loss 0.5012 Moving Loss 0.5002
# 0.2484731674194336 secs
# Iter 25000 Loss 0.5012 Moving Loss 0.5002
# 0.2307901382446289 secs
# Iter 25100 Loss 0.5012 Moving Loss 0.5000
# 0.23239731788635254 secs
# Iter 25200 Loss 0.5011 Moving Loss 0.5001
# 0.2539842128753662 secs
# Iter 25300 Loss 0.5011 Moving Loss 0.4999
# 0.2325301170349121 secs
# Iter 25400 Loss 0.5011 Moving Loss 0.5001
# 0.23398923873901367 secs
# Iter 25500 Loss 0.5011 Moving Loss 0.4999
# 0.25257229804992676 secs
# Iter 25600 Loss 0.5011 Moving Loss 0.5000
# 0.24012255668640137 secs
# Iter 25700 Loss 0.5011 Moving Loss 0.5005
# 0.24500584602355957 secs
# Iter 25800 Loss 0.5011 Moving Loss 0.5000
# 0.23172569274902344 secs
# Iter 25900 Loss 0.5011 Moving Loss 0.5004
# 0.2345445156097412 secs
# Iter 26000 Loss 0.5011 Moving Loss 0.5000
# 0.24691510200500488 secs
# Iter 26100 Loss 0.5011 Moving Loss 0.5000
# 0.23222637176513672 secs
# Iter 26200 Loss 0.5011 Moving Loss 0.5001
# 0.2722041606903076 secs
# Iter 26300 Loss 0.5011 Moving Loss 0.5002
# 0.2529582977294922 secs
# Iter 26400 Loss 0.5011 Moving Loss 0.4997
# 0.23890948295593262 secs
# Iter 26500 Loss 0.5011 Moving Loss 0.5005
# 0.23218584060668945 secs
# Iter 26600 Loss 0.5011 Moving Loss 0.5001
# 0.23471832275390625 secs
# Iter 26700 Loss 0.5011 Moving Loss 0.5001
# 0.23164725303649902 secs
# Iter 26800 Loss 0.5011 Moving Loss 0.4999
# 0.2342517375946045 secs
# Iter 26900 Loss 0.5011 Moving Loss 0.5003
# 0.25045204162597656 secs
# Iter 27000 Loss 0.5011 Moving Loss 0.5002
# 0.245743989944458 secs
# Iter 27100 Loss 0.5011 Moving Loss 0.5001
# 0.24237608909606934 secs
# Iter 27200 Loss 0.5011 Moving Loss 0.5000
# 0.24464702606201172 secs
# Iter 27300 Loss 0.5011 Moving Loss 0.5000
# 0.23980045318603516 secs
# Iter 27400 Loss 0.5011 Moving Loss 0.5005
# 0.2339482307434082 secs
# Iter 27500 Loss 0.5011 Moving Loss 0.4998
# 0.23159217834472656 secs
# Iter 27600 Loss 0.5011 Moving Loss 0.5002
# 0.23250246047973633 secs
# Iter 27700 Loss 0.5011 Moving Loss 0.5002
# 0.2386631965637207 secs
# Iter 27800 Loss 0.5011 Moving Loss 0.5041
# 0.24667882919311523 secs
# Iter 27900 Loss 0.5011 Moving Loss 0.4997
# 0.2315053939819336 secs
# Iter 28000 Loss 0.5011 Moving Loss 0.5000
# 0.24212002754211426 secs
# Iter 28100 Loss 0.5011 Moving Loss 0.4997
# 0.23720288276672363 secs
# Iter 28200 Loss 0.5011 Moving Loss 0.5001
# 0.2310473918914795 secs
# Iter 28300 Loss 0.5010 Moving Loss 0.5002
# 0.2569708824157715 secs
# Iter 28400 Loss 0.5010 Moving Loss 0.5002
# 0.23641729354858398 secs
# Iter 28500 Loss 0.5010 Moving Loss 0.5002
# 0.23920583724975586 secs
# Iter 28600 Loss 0.5010 Moving Loss 0.5001
# 0.2377302646636963 secs
# Iter 28700 Loss 0.5010 Moving Loss 0.5004
# 0.23694896697998047 secs
# Iter 28800 Loss 0.5010 Moving Loss 0.5000
# 0.23315715789794922 secs
# Iter 28900 Loss 0.5010 Moving Loss 0.5002
# 0.23561906814575195 secs
# Iter 29000 Loss 0.5010 Moving Loss 0.5001
# 0.2451941967010498 secs
# Iter 29100 Loss 0.5010 Moving Loss 0.5002
# 0.23846173286437988 secs
# Iter 29200 Loss 0.5010 Moving Loss 0.5002
# 0.23604035377502441 secs
# Iter 29300 Loss 0.5010 Moving Loss 0.5001
# 0.2510099411010742 secs
# Iter 29400 Loss 0.5010 Moving Loss 0.5000
# 0.2354583740234375 secs
# Iter 29500 Loss 0.5010 Moving Loss 0.4999
# 0.2372450828552246 secs
# Iter 29600 Loss 0.5010 Moving Loss 0.5003
# 0.23665213584899902 secs
# Iter 29700 Loss 0.5010 Moving Loss 0.5005
# 0.24106645584106445 secs
# Iter 29800 Loss 0.5010 Moving Loss 0.5004
# 0.24352288246154785 secs
# Iter 29900 Loss 0.5010 Moving Loss 0.4998
# 0.2401719093322754 secs
# Iter 30000 Loss 0.5010 Moving Loss 0.5002
# 0.2488710880279541 secs
# Iter 30100 Loss 0.5010 Moving Loss 0.5000
# 0.2500901222229004 secs
# Iter 30200 Loss 0.5010 Moving Loss 0.5002
# 0.24021601676940918 secs
# Iter 30300 Loss 0.5010 Moving Loss 0.5003
# 0.25617122650146484 secs
# Iter 30400 Loss 0.5010 Moving Loss 0.4998
# 0.25371861457824707 secs
# Iter 30500 Loss 0.5010 Moving Loss 0.5002
# 0.2388474941253662 secs
# Iter 30600 Loss 0.5010 Moving Loss 0.5015
# 0.23343324661254883 secs
# Iter 30700 Loss 0.5010 Moving Loss 0.4999
# 0.23691916465759277 secs
# Iter 30800 Loss 0.5010 Moving Loss 0.5001
# 0.24193120002746582 secs
# Iter 30900 Loss 0.5010 Moving Loss 0.5000
# 0.23823285102844238 secs
# Iter 31000 Loss 0.5010 Moving Loss 0.4999
# 0.24575352668762207 secs
# Iter 31100 Loss 0.5010 Moving Loss 0.5001
# 0.25057172775268555 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/20-order_markov_chain_1000000.txt" is the same as "output/decom_mc_1m"
# ```
