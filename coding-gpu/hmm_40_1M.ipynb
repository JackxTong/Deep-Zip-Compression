# %% [markdown]
# # Compression logs order-40 HMM 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/40-order_hidden_markov_chain_1000000.txt output/40_hmm_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/40_hmm_1m.dzip output/decom_hmm_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/40-order_hidden_markov_chain_1000000.txt output/decom_hmm_1m
# ```

# %% [markdown]
# ### Compression Log
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash compress.sh Simulated-data/40-order_hidden_markov_chain_1000000.txt output/40_hmm_1m.dzip com MODEL_PATH
# Seq Length 1999999
# Using cuda
# Vocab Size 3
# CudNN version 8902
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.5271837711334229 secs
# 3.516824245452881 secs/976 Average loss: 1.7793
# ====> Epoch: 1 Average loss: 0.5120371351: 0.5228
# Loss went from 100000000.0000 to 0.5120
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2552978992462158 secs
# 3.5943706035614014 secs976 Average loss: 0.5086
# ====> Epoch: 2 Average loss: 0.5003569560: 0.5004
# Loss went from 0.5120 to 0.5004
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.24407529830932617 secs
# 3.5583853721618652 secs976 Average loss: 0.4884
# ====> Epoch: 3 Average loss: 0.5002092068: 0.5006
# Loss went from 0.5004 to 0.5002
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23767828941345215 secs
# 3.5370185375213623 secs976 Average loss: 0.4902
# ====> Epoch: 4 Average loss: 0.5001309480: 0.4997
# Loss went from 0.5002 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.22930216789245605 secs
# 3.495495080947876 secs/976 Average loss: 0.4879
# ====> Epoch: 5 Average loss: 0.5001268393: 0.4995
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23967361450195312 secs
# 3.486880302429199 secs/976 Average loss: 0.4957
# ====> Epoch: 6 Average loss: 0.5001124810: 0.5002
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.23208022117614746 secs
# 3.5535919666290283 secs976 Average loss: 0.4833
# ====> Epoch: 7 Average loss: 0.5001080251: 0.5005
# Loss went from 0.5001 to 0.5001
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/.local/lib/python3.9/site-packages/torch/utils/data/_utils/collate.py:222: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2226579189300537 secs
# 3.5703139305114746 secs976 Average loss: 0.5031
# ====> Epoch: 8 Average loss: 0.5000612080: 0.5002
# Loss went from 0.5001 to 0.5001
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# 0.5379664897918701 secs
# Iter 100 Loss 0.5471 Moving Loss 0.5471 Train Loss 0.9082
# 0.23691487312316895 secs
# Iter 200 Loss 0.5307 Moving Loss 0.5144 Train Loss 0.5677
# 0.23225617408752441 secs
# Iter 300 Loss 0.5228 Moving Loss 0.5068 Train Loss 0.5317
# 0.22353458404541016 secs
# Iter 400 Loss 0.5180 Moving Loss 0.5039 Train Loss 0.5374
# 0.2231614589691162 secs
# Iter 500 Loss 0.5146 Moving Loss 0.5006 Train Loss 0.5068
# 0.2228400707244873 secs
# Iter 600 Loss 0.5127 Moving Loss 0.5032 Train Loss 0.5196
# 0.22034597396850586 secs
# Iter 700 Loss 0.5109 Moving Loss 0.5000 Train Loss 0.5051
# 0.22154474258422852 secs
# Iter 800 Loss 0.5102 Moving Loss 0.5056 Train Loss 0.5241
# 0.2398691177368164 secs
# Iter 900 Loss 0.5091 Moving Loss 0.5000 Train Loss 0.5034
# 0.22385811805725098 secs
# Iter 1000 Loss 0.5086 Moving Loss 0.5045 Train Loss 0.5168
# 0.22523784637451172 secs
# Iter 1100 Loss 0.5079 Moving Loss 0.5003 Train Loss 0.5056
# 0.220167875289917 secs
# Iter 1200 Loss 0.5073 Moving Loss 0.5008 Train Loss 0.5052
# 0.22966575622558594 secs
# Iter 1300 Loss 0.5068 Moving Loss 0.5013 Train Loss 0.5046
# 0.22063708305358887 secs
# Iter 1400 Loss 0.5063 Moving Loss 0.5002 Train Loss 0.5043
# 0.22525286674499512 secs
# Iter 1500 Loss 0.5061 Moving Loss 0.5028 Train Loss 0.5081
# 0.2508871555328369 secs
# Iter 1600 Loss 0.5057 Moving Loss 0.4998 Train Loss 0.5050
# 0.2283313274383545 secs
# Iter 1700 Loss 0.5054 Moving Loss 0.5001 Train Loss 0.5019
# 0.22276091575622559 secs
# Iter 1800 Loss 0.5052 Moving Loss 0.5021 Train Loss 0.5121
# 0.22139310836791992 secs
# Iter 1900 Loss 0.5050 Moving Loss 0.5015 Train Loss 0.5066
# 0.22472429275512695 secs
# Iter 2000 Loss 0.5047 Moving Loss 0.5000 Train Loss 0.5009
# 0.2226705551147461 secs
# Iter 2100 Loss 0.5045 Moving Loss 0.4997 Train Loss 0.5005
# 0.22165560722351074 secs
# Iter 2200 Loss 0.5043 Moving Loss 0.5004 Train Loss 0.5023
# 0.2314915657043457 secs
# Iter 2300 Loss 0.5042 Moving Loss 0.5021 Train Loss 0.5066
# 0.23690247535705566 secs
# Iter 2400 Loss 0.5041 Moving Loss 0.5007 Train Loss 0.5047
# 0.23472929000854492 secs
# Iter 2500 Loss 0.5041 Moving Loss 0.5035 Train Loss 0.5093
# 0.22450017929077148 secs
# Iter 2600 Loss 0.5039 Moving Loss 0.5003 Train Loss 0.5070
# 0.2195425033569336 secs
# Iter 2700 Loss 0.5038 Moving Loss 0.5005 Train Loss 0.5027
# 0.22154879570007324 secs
# Iter 2800 Loss 0.5037 Moving Loss 0.5003 Train Loss 0.5015
# 0.22190070152282715 secs
# Iter 2900 Loss 0.5035 Moving Loss 0.5003 Train Loss 0.5013
# 0.22278666496276855 secs
# Iter 3000 Loss 0.5034 Moving Loss 0.4999 Train Loss 0.5017
# 0.22133946418762207 secs
# Iter 3100 Loss 0.5034 Moving Loss 0.5029 Train Loss 0.5086
# 0.2524912357330322 secs
# Iter 3200 Loss 0.5033 Moving Loss 0.5002 Train Loss 0.5037
# 0.22589397430419922 secs
# Iter 3300 Loss 0.5033 Moving Loss 0.5018 Train Loss 0.5043
# 0.221940279006958 secs
# Iter 3400 Loss 0.5032 Moving Loss 0.5003 Train Loss 0.5042
# 0.22842144966125488 secs
# Iter 3500 Loss 0.5031 Moving Loss 0.4999 Train Loss 0.5004
# 0.2216172218322754 secs
# Iter 3600 Loss 0.5030 Moving Loss 0.5006 Train Loss 0.5022
# 0.22172093391418457 secs
# Iter 3700 Loss 0.5029 Moving Loss 0.5004 Train Loss 0.5022
# 0.22548747062683105 secs
# Iter 3800 Loss 0.5029 Moving Loss 0.5003 Train Loss 0.5015
# 0.22400450706481934 secs
# Iter 3900 Loss 0.5028 Moving Loss 0.5004 Train Loss 0.5035
# 0.22166085243225098 secs
# Iter 4000 Loss 0.5028 Moving Loss 0.5019 Train Loss 0.5062
# 0.22180891036987305 secs
# Iter 4100 Loss 0.5027 Moving Loss 0.5003 Train Loss 0.5013
# 0.2238469123840332 secs
# Iter 4200 Loss 0.5027 Moving Loss 0.5005 Train Loss 0.5017
# 0.2205486297607422 secs
# Iter 4300 Loss 0.5026 Moving Loss 0.5011 Train Loss 0.5046
# 0.22189116477966309 secs
# Iter 4400 Loss 0.5026 Moving Loss 0.5004 Train Loss 0.5019
# 0.22334575653076172 secs
# Iter 4500 Loss 0.5026 Moving Loss 0.5027 Train Loss 0.5538
# 0.23514318466186523 secs
# Iter 4600 Loss 0.5051 Moving Loss 0.6176 Train Loss 0.8018
# 0.2268679141998291 secs
# Iter 4700 Loss 0.5050 Moving Loss 0.5014 Train Loss 0.6153
# 0.2266244888305664 secs
# Iter 4800 Loss 0.5049 Moving Loss 0.5007 Train Loss 0.5035
# 0.22531580924987793 secs
# Iter 4900 Loss 0.5048 Moving Loss 0.5003 Train Loss 0.5013
# 0.2227001190185547 secs
# Iter 5000 Loss 0.5047 Moving Loss 0.5004 Train Loss 0.5025
# 0.22349262237548828 secs
# Iter 5100 Loss 0.5046 Moving Loss 0.5003 Train Loss 0.5018
# 0.22298669815063477 secs
# Iter 5200 Loss 0.5046 Moving Loss 0.5001 Train Loss 0.5006
# 0.22754549980163574 secs
# Iter 5300 Loss 0.5045 Moving Loss 0.5003 Train Loss 0.5016
# 0.23085331916809082 secs
# Iter 5400 Loss 0.5044 Moving Loss 0.5003 Train Loss 0.5010
# 0.2232346534729004 secs
# Iter 5500 Loss 0.5043 Moving Loss 0.5004 Train Loss 0.5014
# 0.22345733642578125 secs
# Iter 5600 Loss 0.5043 Moving Loss 0.5005 Train Loss 0.5008
# 0.22738003730773926 secs
# Iter 5700 Loss 0.5042 Moving Loss 0.5011 Train Loss 0.5044
# 0.22098445892333984 secs
# Iter 5800 Loss 0.5041 Moving Loss 0.5000 Train Loss 0.5006
# 0.22129511833190918 secs
# Iter 5900 Loss 0.5041 Moving Loss 0.5002 Train Loss 0.5002
# 0.24532151222229004 secs
# Iter 6000 Loss 0.5040 Moving Loss 0.5001 Train Loss 0.5019
# 0.22670650482177734 secs
# Iter 6100 Loss 0.5039 Moving Loss 0.5008 Train Loss 0.5019
# 0.22270488739013672 secs
# Iter 6200 Loss 0.5039 Moving Loss 0.5009 Train Loss 0.5034
# 0.22029781341552734 secs
# Iter 6300 Loss 0.5038 Moving Loss 0.5002 Train Loss 0.5017
# 0.2217423915863037 secs
# Iter 6400 Loss 0.5038 Moving Loss 0.5005 Train Loss 0.5023
# 0.22290778160095215 secs
# Iter 6500 Loss 0.5037 Moving Loss 0.5000 Train Loss 0.5007
# 0.2263345718383789 secs
# Iter 6600 Loss 0.5037 Moving Loss 0.5005 Train Loss 0.5017
# 0.22093510627746582 secs
# Iter 6700 Loss 0.5036 Moving Loss 0.5005 Train Loss 0.5016
# 0.23627305030822754 secs
# Iter 6800 Loss 0.5036 Moving Loss 0.5006 Train Loss 0.5015
# 0.23163866996765137 secs
# Iter 6900 Loss 0.5035 Moving Loss 0.5006 Train Loss 0.5028
# 0.23177075386047363 secs
# Iter 7000 Loss 0.5035 Moving Loss 0.5000 Train Loss 0.5007
# 0.22092819213867188 secs
# Iter 7100 Loss 0.5035 Moving Loss 0.5005 Train Loss 0.5016
# 0.2220313549041748 secs
# Iter 7200 Loss 0.5034 Moving Loss 0.5005 Train Loss 0.5013
# 0.22226643562316895 secs
# Iter 7300 Loss 0.5034 Moving Loss 0.5004 Train Loss 0.5011
# 0.2204148769378662 secs
# Iter 7400 Loss 0.5033 Moving Loss 0.5000 Train Loss 0.5018
# 0.23209166526794434 secs
# Iter 7500 Loss 0.5033 Moving Loss 0.5002 Train Loss 0.5012
# 0.22054719924926758 secs
# Iter 7600 Loss 0.5032 Moving Loss 0.5004 Train Loss 0.5010
# 0.22976899147033691 secs
# Iter 7700 Loss 0.5032 Moving Loss 0.5006 Train Loss 0.5017
# 0.22126984596252441 secs
# Iter 7800 Loss 0.5032 Moving Loss 0.5005 Train Loss 0.5021
# 0.2228693962097168 secs
# Iter 7900 Loss 0.5031 Moving Loss 0.5004 Train Loss 0.5008
# 0.22033429145812988 secs
# Iter 8000 Loss 0.5031 Moving Loss 0.5003 Train Loss 0.5014
# 0.2202455997467041 secs
# Iter 8100 Loss 0.5031 Moving Loss 0.5003 Train Loss 0.5014
# 0.22954034805297852 secs
# Iter 8200 Loss 0.5030 Moving Loss 0.4999 Train Loss 0.4999
# 0.23188161849975586 secs
# Iter 8300 Loss 0.5030 Moving Loss 0.4999 Train Loss 0.4999
# 0.2235877513885498 secs
# Iter 8400 Loss 0.5030 Moving Loss 0.5001 Train Loss 0.5010
# 0.2224268913269043 secs
# Iter 8500 Loss 0.5029 Moving Loss 0.5004 Train Loss 0.5014
# 0.22133636474609375 secs
# Iter 8600 Loss 0.5029 Moving Loss 0.4998 Train Loss 0.5003
# 0.22267508506774902 secs
# Iter 8700 Loss 0.5029 Moving Loss 0.5002 Train Loss 0.5016
# 0.2220618724822998 secs
# Iter 8800 Loss 0.5028 Moving Loss 0.5007 Train Loss 0.5021
# 0.22259926795959473 secs
# Iter 8900 Loss 0.5028 Moving Loss 0.5001 Train Loss 0.5007
# 0.23636412620544434 secs
# Iter 9000 Loss 0.5028 Moving Loss 0.5001 Train Loss 0.5006
# 0.2335216999053955 secs
# Iter 9100 Loss 0.5028 Moving Loss 0.5008 Train Loss 0.5026
# 0.2227616310119629 secs
# Iter 9200 Loss 0.5027 Moving Loss 0.5007 Train Loss 0.5023
# 0.22089171409606934 secs
# Iter 9300 Loss 0.5027 Moving Loss 0.5001 Train Loss 0.5007
# 0.2203512191772461 secs
# Iter 9400 Loss 0.5027 Moving Loss 0.5004 Train Loss 0.5001
# 0.2215423583984375 secs
# Iter 9500 Loss 0.5027 Moving Loss 0.4999 Train Loss 0.5020
# 0.22114968299865723 secs
# Iter 9600 Loss 0.5026 Moving Loss 0.4999 Train Loss 0.5003
# 0.22479605674743652 secs
# Iter 9700 Loss 0.5026 Moving Loss 0.5003 Train Loss 0.5006
# 0.22137188911437988 secs
# Iter 9800 Loss 0.5026 Moving Loss 0.5007 Train Loss 0.5027
# 0.2211322784423828 secs
# Iter 9900 Loss 0.5026 Moving Loss 0.5000 Train Loss 0.5006
# 0.2341163158416748 secs
# Iter 10000 Loss 0.5025 Moving Loss 0.5005 Train Loss 0.5010
# 0.22076988220214844 secs
# Iter 10100 Loss 0.5025 Moving Loss 0.5000 Train Loss 0.5016
# 0.22422051429748535 secs
# Iter 10200 Loss 0.5025 Moving Loss 0.5001 Train Loss 0.5002
# 0.22098684310913086 secs
# Iter 10300 Loss 0.5025 Moving Loss 0.5000 Train Loss 0.5005
# 0.229248046875 secs
# Iter 10400 Loss 0.5024 Moving Loss 0.5004 Train Loss 0.5018
# 0.23497271537780762 secs
# Iter 10500 Loss 0.5024 Moving Loss 0.5001 Train Loss 0.5004
# 0.22274160385131836 secs
# Iter 10600 Loss 0.5024 Moving Loss 0.5005 Train Loss 0.5016
# 0.21826481819152832 secs
# Iter 10700 Loss 0.5024 Moving Loss 0.5002 Train Loss 0.5012
# 0.22065448760986328 secs
# Iter 10800 Loss 0.5024 Moving Loss 0.5007 Train Loss 0.5018
# 0.22296500205993652 secs
# Iter 10900 Loss 0.5023 Moving Loss 0.5003 Train Loss 0.5015
# 0.22139668464660645 secs
# Iter 11000 Loss 0.5023 Moving Loss 0.5001 Train Loss 0.5012
# 0.22839689254760742 secs
# Iter 11100 Loss 0.5023 Moving Loss 0.5003 Train Loss 0.5010
# 0.23405790328979492 secs
# Iter 11200 Loss 0.5023 Moving Loss 0.5006 Train Loss 0.5013
# 0.23630976676940918 secs
# Iter 11300 Loss 0.5023 Moving Loss 0.5002 Train Loss 0.5007
# 0.23820710182189941 secs
# Iter 11400 Loss 0.5023 Moving Loss 0.5004 Train Loss 0.5016
# 0.22887039184570312 secs
# Iter 11500 Loss 0.5022 Moving Loss 0.5004 Train Loss 0.5011
# 0.22420620918273926 secs
# Iter 11600 Loss 0.5022 Moving Loss 0.5003 Train Loss 0.5009
# 0.22278809547424316 secs
# Iter 11700 Loss 0.5022 Moving Loss 0.5011 Train Loss 0.5008
# 0.22201848030090332 secs
# Iter 11800 Loss 0.5022 Moving Loss 0.5039 Train Loss 0.5260
# 0.22634267807006836 secs
# Iter 11900 Loss 0.5022 Moving Loss 0.5008 Train Loss 0.5024
# 0.22511839866638184 secs
# Iter 12000 Loss 0.5022 Moving Loss 0.5003 Train Loss 0.5013
# 0.2239542007446289 secs
# Iter 12100 Loss 0.5022 Moving Loss 0.4996 Train Loss 0.4996
# 0.22763586044311523 secs
# Iter 12200 Loss 0.5022 Moving Loss 0.5002 Train Loss 0.5007
# 0.22714924812316895 secs
# Iter 12300 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5004
# 0.2226719856262207 secs
# Iter 12400 Loss 0.5021 Moving Loss 0.5001 Train Loss 0.5008
# 0.22037386894226074 secs
# Iter 12500 Loss 0.5021 Moving Loss 0.5003 Train Loss 0.5006
# 0.2225484848022461 secs
# Iter 12600 Loss 0.5021 Moving Loss 0.5006 Train Loss 0.5023
# 0.23886775970458984 secs
# Iter 12700 Loss 0.5021 Moving Loss 0.5002 Train Loss 0.5001
# 0.22640633583068848 secs
# Iter 12800 Loss 0.5021 Moving Loss 0.5001 Train Loss 0.5019
# 0.23119378089904785 secs
# Iter 12900 Loss 0.5021 Moving Loss 0.5007 Train Loss 0.5022
# 0.22133517265319824 secs
# Iter 13000 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5009
# 0.22404170036315918 secs
# Iter 13100 Loss 0.5020 Moving Loss 0.5002 Train Loss 0.4999
# 0.2213895320892334 secs
# Iter 13200 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5019
# 0.22432899475097656 secs
# Iter 13300 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5005
# 0.23432564735412598 secs
# Iter 13400 Loss 0.5020 Moving Loss 0.5004 Train Loss 0.5015
# 0.23254179954528809 secs
# Iter 13500 Loss 0.5020 Moving Loss 0.5000 Train Loss 0.5000
# 0.2286510467529297 secs
# Iter 13600 Loss 0.5020 Moving Loss 0.5001 Train Loss 0.5009
# 0.2215287685394287 secs
# Iter 13700 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5008
# 0.23308038711547852 secs
# Iter 13800 Loss 0.5019 Moving Loss 0.5006 Train Loss 0.5014
# 0.21980571746826172 secs
# Iter 13900 Loss 0.5019 Moving Loss 0.5005 Train Loss 0.5015
# 0.22050142288208008 secs
# Iter 14000 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5003
# 0.22516298294067383 secs
# Iter 14100 Loss 0.5019 Moving Loss 0.5000 Train Loss 0.5002
# 0.22162342071533203 secs
# Iter 14200 Loss 0.5019 Moving Loss 0.5011 Train Loss 0.5007
# 0.22139286994934082 secs
# Iter 14300 Loss 0.5019 Moving Loss 0.5004 Train Loss 0.5039
# 0.22301721572875977 secs
# Iter 14400 Loss 0.5019 Moving Loss 0.5001 Train Loss 0.5005
# 0.22999095916748047 secs
# Iter 14500 Loss 0.5019 Moving Loss 0.4999 Train Loss 0.5003
# 0.2238161563873291 secs
# Iter 14600 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5009
# 0.23105835914611816 secs
# Iter 14700 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5008
# 0.22153925895690918 secs
# Iter 14800 Loss 0.5018 Moving Loss 0.4999 Train Loss 0.5007
# 0.24668431282043457 secs
# Iter 14900 Loss 0.5018 Moving Loss 0.5001 Train Loss 0.5003
# 0.2264547348022461 secs
# Iter 15000 Loss 0.5018 Moving Loss 0.5001 Train Loss 0.5001
# 0.22467899322509766 secs
# Iter 15100 Loss 0.5018 Moving Loss 0.5000 Train Loss 0.5009
# 0.22054839134216309 secs
# Iter 15200 Loss 0.5018 Moving Loss 0.5001 Train Loss 0.5003
# 0.22890186309814453 secs
# Iter 15300 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5009
# 0.22971415519714355 secs
# Iter 15400 Loss 0.5018 Moving Loss 0.5002 Train Loss 0.5008
# 0.22431278228759766 secs
# Iter 15500 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5004
# 0.23280811309814453 secs
# Iter 15600 Loss 0.5017 Moving Loss 0.5004 Train Loss 0.5013
# 0.23403143882751465 secs
# Iter 15700 Loss 0.5017 Moving Loss 0.5003 Train Loss 0.5010
# 0.23054051399230957 secs
# Iter 15800 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5004
# 0.2236948013305664 secs
# Iter 15900 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5007
# 0.2194972038269043 secs
# Iter 16000 Loss 0.5017 Moving Loss 0.5001 Train Loss 0.5005
# 0.22089433670043945 secs
# Iter 16100 Loss 0.5017 Moving Loss 0.5002 Train Loss 0.5000
# 0.22072553634643555 secs
# Iter 16200 Loss 0.5017 Moving Loss 0.4997 Train Loss 0.5008
# 0.22365236282348633 secs
# Iter 16300 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5001
# 0.22157573699951172 secs
# Iter 16400 Loss 0.5017 Moving Loss 0.5000 Train Loss 0.5002
# 0.22153139114379883 secs
# Iter 16500 Loss 0.5016 Moving Loss 0.5006 Train Loss 0.5016
# 0.2217090129852295 secs
# Iter 16600 Loss 0.5016 Moving Loss 0.5010 Train Loss 0.5030
# 0.22205162048339844 secs
# Iter 16700 Loss 0.5016 Moving Loss 0.5001 Train Loss 0.5008
# 0.2339191436767578 secs
# Iter 16800 Loss 0.5016 Moving Loss 0.5001 Train Loss 0.5004
# 0.22029590606689453 secs
# Iter 16900 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5010
# 0.2207012176513672 secs
# Iter 17000 Loss 0.5016 Moving Loss 0.5006 Train Loss 0.5018
# 0.23273992538452148 secs
# Iter 17100 Loss 0.5016 Moving Loss 0.4999 Train Loss 0.4996
# 0.22881388664245605 secs
# Iter 17200 Loss 0.5016 Moving Loss 0.5005 Train Loss 0.5013
# 0.22153401374816895 secs
# Iter 17300 Loss 0.5016 Moving Loss 0.5000 Train Loss 0.5010
# 0.2222898006439209 secs
# Iter 17400 Loss 0.5016 Moving Loss 0.5005 Train Loss 0.5014
# 0.2420363426208496 secs
# Iter 17500 Loss 0.5016 Moving Loss 0.5008 Train Loss 0.5025
# 0.2207326889038086 secs
# Iter 17600 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5004
# 0.2237091064453125 secs
# Iter 17700 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5014
# 0.2280745506286621 secs
# Iter 17800 Loss 0.5016 Moving Loss 0.5003 Train Loss 0.5012
# 0.2264082431793213 secs
# Iter 17900 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5008
# 0.22432446479797363 secs
# Iter 18000 Loss 0.5015 Moving Loss 0.5003 Train Loss 0.5003
# 0.2258009910583496 secs
# Iter 18100 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5019
# 0.22524189949035645 secs
# Iter 18200 Loss 0.5015 Moving Loss 0.5000 Train Loss 0.4999
# 0.2220468521118164 secs
# Iter 18300 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5014
# 0.22104549407958984 secs
# Iter 18400 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5006
# 0.2221508026123047 secs
# Iter 18500 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5008
# 0.22653961181640625 secs
# Iter 18600 Loss 0.5015 Moving Loss 0.5001 Train Loss 0.5014
# 0.2229161262512207 secs
# Iter 18700 Loss 0.5015 Moving Loss 0.5006 Train Loss 0.5006
# 0.22329092025756836 secs
# Iter 18800 Loss 0.5015 Moving Loss 0.5007 Train Loss 0.5030
# 0.22164559364318848 secs
# Iter 18900 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5008
# 0.2296428680419922 secs
# Iter 19000 Loss 0.5015 Moving Loss 0.5004 Train Loss 0.5010
# 0.2266230583190918 secs
# Iter 19100 Loss 0.5015 Moving Loss 0.5002 Train Loss 0.5011
# 0.21944427490234375 secs
# Iter 19200 Loss 0.5015 Moving Loss 0.5003 Train Loss 0.5011
# 0.22713255882263184 secs
# Iter 19300 Loss 0.5015 Moving Loss 0.4998 Train Loss 0.4999
# 0.22063136100769043 secs
# Iter 19400 Loss 0.5014 Moving Loss 0.5003 Train Loss 0.5011
# 0.22376203536987305 secs
# Iter 19500 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.5003
# 0.21918153762817383 secs
# Iter 19600 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5003
# 0.220062255859375 secs
# Iter 19700 Loss 0.5014 Moving Loss 0.4999 Train Loss 0.4997
# 0.2224571704864502 secs
# Iter 19800 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5004
# 0.2191765308380127 secs
# Iter 19900 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5004
# 0.21946430206298828 secs
# Iter 20000 Loss 0.5014 Moving Loss 0.5006 Train Loss 0.5022
# 0.23160052299499512 secs
# Iter 20100 Loss 0.5014 Moving Loss 0.5000 Train Loss 0.5000
# 0.22484827041625977 secs
# Iter 20200 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5006
# 0.22704005241394043 secs
# Iter 20300 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5004
# 0.2206859588623047 secs
# Iter 20400 Loss 0.5014 Moving Loss 0.5002 Train Loss 0.5003
# 0.21984410285949707 secs
# Iter 20500 Loss 0.5014 Moving Loss 0.5003 Train Loss 0.5019
# 0.21951532363891602 secs
# Iter 20600 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5003
# 0.22052907943725586 secs
# Iter 20700 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5000
# 0.22350096702575684 secs
# Iter 20800 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5011
# 0.22150611877441406 secs
# Iter 20900 Loss 0.5014 Moving Loss 0.5001 Train Loss 0.5007
# 0.21915221214294434 secs
# Iter 21000 Loss 0.5013 Moving Loss 0.4999 Train Loss 0.5003
# 0.22094297409057617 secs
# Iter 21100 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5008
# 0.22200798988342285 secs
# Iter 21200 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5003
# 0.22246503829956055 secs
# Iter 21300 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5005
# 0.23035883903503418 secs
# Iter 21400 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5004
# 0.22057414054870605 secs
# Iter 21500 Loss 0.5013 Moving Loss 0.5002 Train Loss 0.5007
# 0.2253115177154541 secs
# Iter 21600 Loss 0.5013 Moving Loss 0.5005 Train Loss 0.5012
# 0.22052860260009766 secs
# Iter 21700 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5006
# 0.22118330001831055 secs
# Iter 21800 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5003
# 0.21959638595581055 secs
# Iter 21900 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5008
# 0.22417235374450684 secs
# Iter 22000 Loss 0.5013 Moving Loss 0.5000 Train Loss 0.5004
# 0.2190549373626709 secs
# Iter 22100 Loss 0.5013 Moving Loss 0.4998 Train Loss 0.5003
# 0.22034144401550293 secs
# Iter 22200 Loss 0.5013 Moving Loss 0.5004 Train Loss 0.5004
# 0.23334193229675293 secs
# Iter 22300 Loss 0.5013 Moving Loss 0.4999 Train Loss 0.5005
# 0.23776960372924805 secs
# Iter 22400 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5005
# 0.2410602569580078 secs
# Iter 22500 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5006
# 0.23983168601989746 secs
# Iter 22600 Loss 0.5013 Moving Loss 0.5003 Train Loss 0.5005
# 0.21943378448486328 secs
# Iter 22700 Loss 0.5013 Moving Loss 0.5023 Train Loss 0.5105
# 0.21881532669067383 secs
# Iter 22800 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5002
# 0.22035527229309082 secs
# Iter 22900 Loss 0.5013 Moving Loss 0.5001 Train Loss 0.5006
# 0.22186040878295898 secs
# Iter 23000 Loss 0.5013 Moving Loss 0.5006 Train Loss 0.5019
# 0.22036981582641602 secs
# Iter 23100 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5007
# 0.2189493179321289 secs
# Iter 23200 Loss 0.5012 Moving Loss 0.4999 Train Loss 0.5001
# 0.2185044288635254 secs
# Iter 23300 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5003
# 0.21787691116333008 secs
# Iter 23400 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5005
# 0.22333121299743652 secs
# Iter 23500 Loss 0.5012 Moving Loss 0.5003 Train Loss 0.5008
# 0.22898244857788086 secs
# Iter 23600 Loss 0.5012 Moving Loss 0.4997 Train Loss 0.5003
# 0.21940159797668457 secs
# Iter 23700 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5004
# 0.26251983642578125 secs
# Iter 23800 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5000
# 0.23032522201538086 secs
# Iter 23900 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5011
# 0.21797776222229004 secs
# Iter 24000 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5002
# 0.22033238410949707 secs
# Iter 24100 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5012
# 0.2228858470916748 secs
# Iter 24200 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5020
# 0.21863770484924316 secs
# Iter 24300 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5015
# 0.220794677734375 secs
# Iter 24400 Loss 0.5012 Moving Loss 0.5006 Train Loss 0.5015
# 0.2287302017211914 secs
# Iter 24500 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5005
# 0.22743868827819824 secs
# Iter 24600 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5003
# 0.22144103050231934 secs
# Iter 24700 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5006
# 0.220780611038208 secs
# Iter 24800 Loss 0.5012 Moving Loss 0.5001 Train Loss 0.5008
# 0.22072696685791016 secs
# Iter 24900 Loss 0.5012 Moving Loss 0.5004 Train Loss 0.5005
# 0.2175900936126709 secs
# Iter 25000 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5009
# 0.21865296363830566 secs
# Iter 25100 Loss 0.5012 Moving Loss 0.5002 Train Loss 0.5006
# 0.21855735778808594 secs
# Iter 25200 Loss 0.5012 Moving Loss 0.5000 Train Loss 0.5002
# 0.22383332252502441 secs
# Iter 25300 Loss 0.5012 Moving Loss 0.4995 Train Loss 0.4999
# 0.21917128562927246 secs
# Iter 25400 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5010
# 0.21712422370910645 secs
# Iter 25500 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5002
# 0.21929383277893066 secs
# Iter 25600 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5006
# 0.22314906120300293 secs
# Iter 25700 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5004
# 0.2212827205657959 secs
# Iter 25800 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5008
# 0.22672796249389648 secs
# Iter 25900 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5004
# 0.22121953964233398 secs
# Iter 26000 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.4999
# 0.22092080116271973 secs
# Iter 26100 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5006
# 0.22223997116088867 secs
# Iter 26200 Loss 0.5011 Moving Loss 0.5004 Train Loss 0.5007
# 0.21953678131103516 secs
# Iter 26300 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5004
# 0.219940185546875 secs
# Iter 26400 Loss 0.5011 Moving Loss 0.4999 Train Loss 0.5003
# 0.2228250503540039 secs
# Iter 26500 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5004
# 0.22062993049621582 secs
# Iter 26600 Loss 0.5011 Moving Loss 0.5003 Train Loss 0.5007
# 0.21932625770568848 secs
# Iter 26700 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.23136663436889648 secs
# Iter 26800 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5005
# 0.23197293281555176 secs
# Iter 26900 Loss 0.5011 Moving Loss 0.5002 Train Loss 0.5006
# 0.22470545768737793 secs
# Iter 27000 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5003
# 0.2203207015991211 secs
# Iter 27100 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5000
# 0.22002434730529785 secs
# Iter 27200 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5004
# 0.21907281875610352 secs
# Iter 27300 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5003
# 0.21845030784606934 secs
# Iter 27400 Loss 0.5011 Moving Loss 0.4991 Train Loss 0.4995
# 0.22107386589050293 secs
# Iter 27500 Loss 0.5011 Moving Loss 0.5013 Train Loss 0.5022
# 0.22008681297302246 secs
# Iter 27600 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5009
# 0.21921706199645996 secs
# Iter 27700 Loss 0.5011 Moving Loss 0.5005 Train Loss 0.5010
# 0.22568631172180176 secs
# Iter 27800 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5004
# 0.2181415557861328 secs
# Iter 27900 Loss 0.5011 Moving Loss 0.5001 Train Loss 0.5001
# 0.22388219833374023 secs
# Iter 28000 Loss 0.5011 Moving Loss 0.5000 Train Loss 0.5002
# 0.21972990036010742 secs
# Iter 28100 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.4998
# 0.22842764854431152 secs
# Iter 28200 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5011
# 0.24053168296813965 secs
# Iter 28300 Loss 0.5010 Moving Loss 0.4996 Train Loss 0.4996
# 0.22652816772460938 secs
# Iter 28400 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5007
# 0.22028255462646484 secs
# Iter 28500 Loss 0.5010 Moving Loss 0.5004 Train Loss 0.5009
# 0.21748042106628418 secs
# Iter 28600 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5010
# 0.223222017288208 secs
# Iter 28700 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5002
# 0.2179098129272461 secs
# Iter 28800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5007
# 0.22046875953674316 secs
# Iter 28900 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5002
# 0.22895002365112305 secs
# Iter 29000 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5003
# 0.2523384094238281 secs
# Iter 29100 Loss 0.5010 Moving Loss 0.4996 Train Loss 0.4995
# 0.2525618076324463 secs
# Iter 29200 Loss 0.5010 Moving Loss 0.5001 Train Loss 0.5003
# 0.2198808193206787 secs
# Iter 29300 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5005
# 0.21800661087036133 secs
# Iter 29400 Loss 0.5010 Moving Loss 0.4998 Train Loss 0.4999
# 0.2227952480316162 secs
# Iter 29500 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5003
# 0.22089242935180664 secs
# Iter 29600 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5002
# 0.2215721607208252 secs
# Iter 29700 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5001
# 0.22242236137390137 secs
# Iter 29800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5004
# 0.21992921829223633 secs
# Iter 29900 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.4999
# 0.22035861015319824 secs
# Iter 30000 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5006
# 0.21866297721862793 secs
# Iter 30100 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5003
# 0.22751188278198242 secs
# Iter 30200 Loss 0.5010 Moving Loss 0.4996 Train Loss 0.4999
# 0.2197880744934082 secs
# Iter 30300 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5008
# 0.21752214431762695 secs
# Iter 30400 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5002
# 0.2378830909729004 secs
# Iter 30500 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5001
# 0.2294149398803711 secs
# Iter 30600 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5006
# 0.22220087051391602 secs
# Iter 30700 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5002
# 0.21890473365783691 secs
# Iter 30800 Loss 0.5010 Moving Loss 0.5000 Train Loss 0.5000
# 0.22408127784729004 secs
# Iter 30900 Loss 0.5010 Moving Loss 0.5002 Train Loss 0.5008
# 0.2192676067352295 secs
# Iter 31000 Loss 0.5010 Moving Loss 0.4999 Train Loss 0.5000
# 0.21968317031860352 secs
# Iter 31100 Loss 0.5010 Moving Loss 0.5003 Train Loss 0.5013
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# [jx1421@ee-tarrasque coding-gpu]$ bash decompress.sh output/40_hmm_1m.dzip output/decom_hmm_1m com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5471 Moving Loss 0.5471
# 0.5477302074432373 secs
# Iter 200 Loss 0.5307 Moving Loss 0.5144
# 0.23380541801452637 secs
# Iter 300 Loss 0.5228 Moving Loss 0.5068
# 0.23459863662719727 secs
# Iter 400 Loss 0.5180 Moving Loss 0.5039
# 0.23427248001098633 secs
# Iter 500 Loss 0.5146 Moving Loss 0.5006
# 0.23691487312316895 secs
# Iter 600 Loss 0.5127 Moving Loss 0.5032
# 0.23801493644714355 secs
# Iter 700 Loss 0.5109 Moving Loss 0.5000
# 0.23435592651367188 secs
# Iter 800 Loss 0.5102 Moving Loss 0.5056
# 0.23566746711730957 secs
# Iter 900 Loss 0.5091 Moving Loss 0.5000
# 0.23269391059875488 secs
# Iter 1000 Loss 0.5086 Moving Loss 0.5045
# 0.23239541053771973 secs
# Iter 1100 Loss 0.5079 Moving Loss 0.5003
# 0.23543238639831543 secs
# Iter 1200 Loss 0.5073 Moving Loss 0.5008
# 0.24880027770996094 secs
# Iter 1300 Loss 0.5068 Moving Loss 0.5013
# 0.2359330654144287 secs
# Iter 1400 Loss 0.5063 Moving Loss 0.5002
# 0.24802350997924805 secs
# Iter 1500 Loss 0.5061 Moving Loss 0.5028
# 0.24704647064208984 secs
# Iter 1600 Loss 0.5057 Moving Loss 0.4998
# 0.2332768440246582 secs
# Iter 1700 Loss 0.5054 Moving Loss 0.5001
# 0.2341611385345459 secs
# Iter 1800 Loss 0.5052 Moving Loss 0.5021
# 0.23513221740722656 secs
# Iter 1900 Loss 0.5050 Moving Loss 0.5015
# 0.23943495750427246 secs
# Iter 2000 Loss 0.5047 Moving Loss 0.5000
# 0.23488163948059082 secs
# Iter 2100 Loss 0.5045 Moving Loss 0.4997
# 0.23469853401184082 secs
# Iter 2200 Loss 0.5043 Moving Loss 0.5004
# 0.23376989364624023 secs
# Iter 2300 Loss 0.5042 Moving Loss 0.5021
# 0.23821163177490234 secs
# Iter 2400 Loss 0.5041 Moving Loss 0.5007
# 0.2331676483154297 secs
# Iter 2500 Loss 0.5041 Moving Loss 0.5035
# 0.23306965827941895 secs
# Iter 2600 Loss 0.5039 Moving Loss 0.5003
# 0.23288464546203613 secs
# Iter 2700 Loss 0.5038 Moving Loss 0.5005
# 0.2368149757385254 secs
# Iter 2800 Loss 0.5037 Moving Loss 0.5003
# 0.2431485652923584 secs
# Iter 2900 Loss 0.5035 Moving Loss 0.5003
# 0.23415112495422363 secs
# Iter 3000 Loss 0.5034 Moving Loss 0.4999
# 0.23360371589660645 secs
# Iter 3100 Loss 0.5034 Moving Loss 0.5029
# 0.2340853214263916 secs
# Iter 3200 Loss 0.5033 Moving Loss 0.5002
# 0.23610353469848633 secs
# Iter 3300 Loss 0.5033 Moving Loss 0.5018
# 0.2337794303894043 secs
# Iter 3400 Loss 0.5032 Moving Loss 0.5003
# 0.24730181694030762 secs
# Iter 3500 Loss 0.5031 Moving Loss 0.4999
# 0.24182891845703125 secs
# Iter 3600 Loss 0.5030 Moving Loss 0.5006
# 0.24809718132019043 secs
# Iter 3700 Loss 0.5029 Moving Loss 0.5004
# 0.24618148803710938 secs
# Iter 3800 Loss 0.5029 Moving Loss 0.5003
# 0.23281478881835938 secs
# Iter 3900 Loss 0.5028 Moving Loss 0.5004
# 0.23287510871887207 secs
# Iter 4000 Loss 0.5028 Moving Loss 0.5019
# 0.23312020301818848 secs
# Iter 4100 Loss 0.5027 Moving Loss 0.5003
# 0.23320388793945312 secs
# Iter 4200 Loss 0.5027 Moving Loss 0.5005
# 0.23225617408752441 secs
# Iter 4300 Loss 0.5026 Moving Loss 0.5011
# 0.23189115524291992 secs
# Iter 4400 Loss 0.5026 Moving Loss 0.5004
# 0.23645591735839844 secs
# Iter 4500 Loss 0.5026 Moving Loss 0.5027
# 0.23212552070617676 secs
# Iter 4600 Loss 0.5051 Moving Loss 0.6176
# 0.23317527770996094 secs
# Iter 4700 Loss 0.5050 Moving Loss 0.5014
# 0.23345637321472168 secs
# Iter 4800 Loss 0.5049 Moving Loss 0.5007
# 0.23257875442504883 secs
# Iter 4900 Loss 0.5048 Moving Loss 0.5003
# 0.24255132675170898 secs
# Iter 5000 Loss 0.5047 Moving Loss 0.5004
# 0.2470722198486328 secs
# Iter 5100 Loss 0.5046 Moving Loss 0.5003
# 0.23228240013122559 secs
# Iter 5200 Loss 0.5046 Moving Loss 0.5001
# 0.23224949836730957 secs
# Iter 5300 Loss 0.5045 Moving Loss 0.5003
# 0.23238277435302734 secs
# Iter 5400 Loss 0.5044 Moving Loss 0.5003
# 0.23480010032653809 secs
# Iter 5500 Loss 0.5043 Moving Loss 0.5004
# 0.23237299919128418 secs
# Iter 5600 Loss 0.5043 Moving Loss 0.5005
# 0.24583768844604492 secs
# Iter 5700 Loss 0.5042 Moving Loss 0.5011
# 0.24355292320251465 secs
# Iter 5800 Loss 0.5041 Moving Loss 0.5000
# 0.23927760124206543 secs
# Iter 5900 Loss 0.5041 Moving Loss 0.5002
# 0.23701190948486328 secs
# Iter 6000 Loss 0.5040 Moving Loss 0.5001
# 0.2332003116607666 secs
# Iter 6100 Loss 0.5039 Moving Loss 0.5008
# 0.2329399585723877 secs
# Iter 6200 Loss 0.5039 Moving Loss 0.5009
# 0.23144245147705078 secs
# Iter 6300 Loss 0.5038 Moving Loss 0.5002
# 0.2321455478668213 secs
# Iter 6400 Loss 0.5038 Moving Loss 0.5005
# 0.23604726791381836 secs
# Iter 6500 Loss 0.5037 Moving Loss 0.5000
# 0.23627018928527832 secs
# Iter 6600 Loss 0.5037 Moving Loss 0.5005
# 0.23196053504943848 secs
# Iter 6700 Loss 0.5036 Moving Loss 0.5005
# 0.2337937355041504 secs
# Iter 6800 Loss 0.5036 Moving Loss 0.5006
# 0.23220086097717285 secs
# Iter 6900 Loss 0.5035 Moving Loss 0.5006
# 0.23450016975402832 secs
# Iter 7000 Loss 0.5035 Moving Loss 0.5000
# 0.23947548866271973 secs
# Iter 7100 Loss 0.5035 Moving Loss 0.5005
# 0.252108097076416 secs
# Iter 7200 Loss 0.5034 Moving Loss 0.5005
# 0.23446440696716309 secs
# Iter 7300 Loss 0.5034 Moving Loss 0.5004
# 0.2318115234375 secs
# Iter 7400 Loss 0.5033 Moving Loss 0.5000
# 0.23185229301452637 secs
# Iter 7500 Loss 0.5033 Moving Loss 0.5002
# 0.23445940017700195 secs
# Iter 7600 Loss 0.5032 Moving Loss 0.5004
# 0.2335500717163086 secs
# Iter 7700 Loss 0.5032 Moving Loss 0.5006
# 0.24914145469665527 secs
# Iter 7800 Loss 0.5032 Moving Loss 0.5005
# 0.25065088272094727 secs
# Iter 7900 Loss 0.5031 Moving Loss 0.5004
# 0.24789738655090332 secs
# Iter 8000 Loss 0.5031 Moving Loss 0.5003
# 0.2462787628173828 secs
# Iter 8100 Loss 0.5031 Moving Loss 0.5003
# 0.2598559856414795 secs
# Iter 8200 Loss 0.5030 Moving Loss 0.4999
# 0.24201369285583496 secs
# Iter 8300 Loss 0.5030 Moving Loss 0.4999
# 0.22978854179382324 secs
# Iter 8400 Loss 0.5030 Moving Loss 0.5001
# 0.23256254196166992 secs
# Iter 8500 Loss 0.5029 Moving Loss 0.5004
# 0.2332916259765625 secs
# Iter 8600 Loss 0.5029 Moving Loss 0.4998
# 0.23745203018188477 secs
# Iter 8700 Loss 0.5029 Moving Loss 0.5002
# 0.23555207252502441 secs
# Iter 8800 Loss 0.5028 Moving Loss 0.5007
# 0.232957124710083 secs
# Iter 8900 Loss 0.5028 Moving Loss 0.5001
# 0.23389077186584473 secs
# Iter 9000 Loss 0.5028 Moving Loss 0.5001
# 0.233504056930542 secs
# Iter 9100 Loss 0.5028 Moving Loss 0.5008
# 0.23774981498718262 secs
# Iter 9200 Loss 0.5027 Moving Loss 0.5007
# 0.24837827682495117 secs
# Iter 9300 Loss 0.5027 Moving Loss 0.5001
# 0.23462557792663574 secs
# Iter 9400 Loss 0.5027 Moving Loss 0.5004
# 0.23243355751037598 secs
# Iter 9500 Loss 0.5027 Moving Loss 0.4999
# 0.2318878173828125 secs
# Iter 9600 Loss 0.5026 Moving Loss 0.4999
# 0.2344968318939209 secs
# Iter 9700 Loss 0.5026 Moving Loss 0.5003
# 0.23120880126953125 secs
# Iter 9800 Loss 0.5026 Moving Loss 0.5007
# 0.23273301124572754 secs
# Iter 9900 Loss 0.5026 Moving Loss 0.5000
# 0.24552035331726074 secs
# Iter 10000 Loss 0.5025 Moving Loss 0.5005
# 0.23268914222717285 secs
# Iter 10100 Loss 0.5025 Moving Loss 0.5000
# 0.23445487022399902 secs
# Iter 10200 Loss 0.5025 Moving Loss 0.5001
# 0.23327851295471191 secs
# Iter 10300 Loss 0.5025 Moving Loss 0.5000
# 0.23246455192565918 secs
# Iter 10400 Loss 0.5024 Moving Loss 0.5004
# 0.23359942436218262 secs
# Iter 10500 Loss 0.5024 Moving Loss 0.5001
# 0.2326040267944336 secs
# Iter 10600 Loss 0.5024 Moving Loss 0.5005
# 0.23520588874816895 secs
# Iter 10700 Loss 0.5024 Moving Loss 0.5002
# 0.23555231094360352 secs
# Iter 10800 Loss 0.5024 Moving Loss 0.5007
# 0.23111319541931152 secs
# Iter 10900 Loss 0.5023 Moving Loss 0.5003
# 0.23205184936523438 secs
# Iter 11000 Loss 0.5023 Moving Loss 0.5001
# 0.2328031063079834 secs
# Iter 11100 Loss 0.5023 Moving Loss 0.5003
# 0.23401498794555664 secs
# Iter 11200 Loss 0.5023 Moving Loss 0.5006
# 0.23396944999694824 secs
# Iter 11300 Loss 0.5023 Moving Loss 0.5002
# 0.25125646591186523 secs
# Iter 11400 Loss 0.5023 Moving Loss 0.5004
# 0.23697590827941895 secs
# Iter 11500 Loss 0.5022 Moving Loss 0.5004
# 0.23121356964111328 secs
# Iter 11600 Loss 0.5022 Moving Loss 0.5003
# 0.2323317527770996 secs
# Iter 11700 Loss 0.5022 Moving Loss 0.5011
# 0.23377561569213867 secs
# Iter 11800 Loss 0.5022 Moving Loss 0.5039
# 0.2321608066558838 secs
# Iter 11900 Loss 0.5022 Moving Loss 0.5008
# 0.2333204746246338 secs
# Iter 12000 Loss 0.5022 Moving Loss 0.5003
# 0.25409626960754395 secs
# Iter 12100 Loss 0.5022 Moving Loss 0.4996
# 0.23853516578674316 secs
# Iter 12200 Loss 0.5022 Moving Loss 0.5002
# 0.2331407070159912 secs
# Iter 12300 Loss 0.5021 Moving Loss 0.5002
# 0.23522520065307617 secs
# Iter 12400 Loss 0.5021 Moving Loss 0.5001
# 0.23105955123901367 secs
# Iter 12500 Loss 0.5021 Moving Loss 0.5003
# 0.23006725311279297 secs
# Iter 12600 Loss 0.5021 Moving Loss 0.5006
# 0.23106837272644043 secs
# Iter 12700 Loss 0.5021 Moving Loss 0.5002
# 0.23115181922912598 secs
# Iter 12800 Loss 0.5021 Moving Loss 0.5001
# 0.23618316650390625 secs
# Iter 12900 Loss 0.5021 Moving Loss 0.5007
# 0.23342657089233398 secs
# Iter 13000 Loss 0.5020 Moving Loss 0.5000
# 0.2312319278717041 secs
# Iter 13100 Loss 0.5020 Moving Loss 0.5002
# 0.23411893844604492 secs
# Iter 13200 Loss 0.5020 Moving Loss 0.5001
# 0.2329576015472412 secs
# Iter 13300 Loss 0.5020 Moving Loss 0.5000
# 0.2346820831298828 secs
# Iter 13400 Loss 0.5020 Moving Loss 0.5004
# 0.24622631072998047 secs
# Iter 13500 Loss 0.5020 Moving Loss 0.5000
# 0.2384507656097412 secs
# Iter 13600 Loss 0.5020 Moving Loss 0.5001
# 0.2447202205657959 secs
# Iter 13700 Loss 0.5019 Moving Loss 0.5001
# 0.23516440391540527 secs
# Iter 13800 Loss 0.5019 Moving Loss 0.5006
# 0.2356703281402588 secs
# Iter 13900 Loss 0.5019 Moving Loss 0.5005
# 0.23177671432495117 secs
# Iter 14000 Loss 0.5019 Moving Loss 0.5000
# 0.2354564666748047 secs
# Iter 14100 Loss 0.5019 Moving Loss 0.5000
# 0.2470841407775879 secs
# Iter 14200 Loss 0.5019 Moving Loss 0.5011
# 0.2559511661529541 secs
# Iter 14300 Loss 0.5019 Moving Loss 0.5004
# 0.23920655250549316 secs
# Iter 14400 Loss 0.5019 Moving Loss 0.5001
# 0.2349693775177002 secs
# Iter 14500 Loss 0.5019 Moving Loss 0.4999
# 0.24618911743164062 secs
# Iter 14600 Loss 0.5018 Moving Loss 0.5002
# 0.23452258110046387 secs
# Iter 14700 Loss 0.5018 Moving Loss 0.5002
# 0.24822425842285156 secs
# Iter 14800 Loss 0.5018 Moving Loss 0.4999
# 0.2758481502532959 secs
# Iter 14900 Loss 0.5018 Moving Loss 0.5001
# 0.2758340835571289 secs
# Iter 15000 Loss 0.5018 Moving Loss 0.5001
# 0.2770071029663086 secs
# Iter 15100 Loss 0.5018 Moving Loss 0.5000
# 0.27498626708984375 secs
# Iter 15200 Loss 0.5018 Moving Loss 0.5001
# 0.28676486015319824 secs
# Iter 15300 Loss 0.5018 Moving Loss 0.5002
# 0.27515530586242676 secs
# Iter 15400 Loss 0.5018 Moving Loss 0.5002
# 0.27805185317993164 secs
# Iter 15500 Loss 0.5017 Moving Loss 0.5001
# 0.2751271724700928 secs
# Iter 15600 Loss 0.5017 Moving Loss 0.5004
# 0.27513837814331055 secs
# Iter 15700 Loss 0.5017 Moving Loss 0.5003
# 0.27562403678894043 secs
# Iter 15800 Loss 0.5017 Moving Loss 0.5001
# 0.2752864360809326 secs
# Iter 15900 Loss 0.5017 Moving Loss 0.5001
# 0.2746903896331787 secs
# Iter 16000 Loss 0.5017 Moving Loss 0.5001
# 0.2896769046783447 secs
# Iter 16100 Loss 0.5017 Moving Loss 0.5002
# 0.2956874370574951 secs
# Iter 16200 Loss 0.5017 Moving Loss 0.4997
# 0.2997856140136719 secs
# Iter 16300 Loss 0.5017 Moving Loss 0.5000
# 0.27759695053100586 secs
# Iter 16400 Loss 0.5017 Moving Loss 0.5000
# 0.27646708488464355 secs
# Iter 16500 Loss 0.5016 Moving Loss 0.5006
# 0.2760295867919922 secs
# Iter 16600 Loss 0.5016 Moving Loss 0.5010
# 0.27498769760131836 secs
# Iter 16700 Loss 0.5016 Moving Loss 0.5001
# 0.28054118156433105 secs
# Iter 16800 Loss 0.5016 Moving Loss 0.5001
# 0.2772648334503174 secs
# Iter 16900 Loss 0.5016 Moving Loss 0.5003
# 0.2770705223083496 secs
# Iter 17000 Loss 0.5016 Moving Loss 0.5006
# 0.2752974033355713 secs
# Iter 17100 Loss 0.5016 Moving Loss 0.4999
# 0.2766251564025879 secs
# Iter 17200 Loss 0.5016 Moving Loss 0.5005
# 0.2809581756591797 secs
# Iter 17300 Loss 0.5016 Moving Loss 0.5000
# 0.276108980178833 secs
# Iter 17400 Loss 0.5016 Moving Loss 0.5005
# 0.2754335403442383 secs
# Iter 17500 Loss 0.5016 Moving Loss 0.5008
# 0.2799515724182129 secs
# Iter 17600 Loss 0.5016 Moving Loss 0.5003
# 0.27607274055480957 secs
# Iter 17700 Loss 0.5016 Moving Loss 0.5003
# 0.281998872756958 secs
# Iter 17800 Loss 0.5016 Moving Loss 0.5003
# 0.29076600074768066 secs
# Iter 17900 Loss 0.5015 Moving Loss 0.5001
# 0.27973055839538574 secs
# Iter 18000 Loss 0.5015 Moving Loss 0.5003
# 0.2833077907562256 secs
# Iter 18100 Loss 0.5015 Moving Loss 0.5001
# 0.2740640640258789 secs
# Iter 18200 Loss 0.5015 Moving Loss 0.5000
# 0.2748398780822754 secs
# Iter 18300 Loss 0.5015 Moving Loss 0.5002
# 0.2758958339691162 secs
# Iter 18400 Loss 0.5015 Moving Loss 0.5002
# 0.2743246555328369 secs
# Iter 18500 Loss 0.5015 Moving Loss 0.5004
# 0.2860538959503174 secs
# Iter 18600 Loss 0.5015 Moving Loss 0.5001
# 0.2747457027435303 secs
# Iter 18700 Loss 0.5015 Moving Loss 0.5006
# 0.2765488624572754 secs
# Iter 18800 Loss 0.5015 Moving Loss 0.5007
# 0.27454495429992676 secs
# Iter 18900 Loss 0.5015 Moving Loss 0.5002
# 0.2790794372558594 secs
# Iter 19000 Loss 0.5015 Moving Loss 0.5004
# 0.29554080963134766 secs
# Iter 19100 Loss 0.5015 Moving Loss 0.5002
# 0.2765977382659912 secs
# Iter 19200 Loss 0.5015 Moving Loss 0.5003
# 0.27500271797180176 secs
# Iter 19300 Loss 0.5015 Moving Loss 0.4998
# 0.2822127342224121 secs
# Iter 19400 Loss 0.5014 Moving Loss 0.5003
# 0.29178524017333984 secs
# Iter 19500 Loss 0.5014 Moving Loss 0.4999
# 0.2759284973144531 secs
# Iter 19600 Loss 0.5014 Moving Loss 0.5000
# 0.298738956451416 secs
# Iter 19700 Loss 0.5014 Moving Loss 0.4999
# 0.29419851303100586 secs
# Iter 19800 Loss 0.5014 Moving Loss 0.5000
# 0.2857546806335449 secs
# Iter 19900 Loss 0.5014 Moving Loss 0.5002
# 0.27391600608825684 secs
# Iter 20000 Loss 0.5014 Moving Loss 0.5006
# 0.27357983589172363 secs
# Iter 20100 Loss 0.5014 Moving Loss 0.5000
# 0.2744448184967041 secs
# Iter 20200 Loss 0.5014 Moving Loss 0.5002
# 0.2742609977722168 secs
# Iter 20300 Loss 0.5014 Moving Loss 0.5002
# 0.28204917907714844 secs
# Iter 20400 Loss 0.5014 Moving Loss 0.5002
# 0.27673935890197754 secs
# Iter 20500 Loss 0.5014 Moving Loss 0.5003
# 0.27628564834594727 secs
# Iter 20600 Loss 0.5014 Moving Loss 0.5001
# 0.2751152515411377 secs
# Iter 20700 Loss 0.5014 Moving Loss 0.5001
# 0.29359912872314453 secs
# Iter 20800 Loss 0.5014 Moving Loss 0.5001
# 0.24791836738586426 secs
# Iter 20900 Loss 0.5014 Moving Loss 0.5001
# 0.23750805854797363 secs
# Iter 21000 Loss 0.5013 Moving Loss 0.4999
# 0.23621797561645508 secs
# Iter 21100 Loss 0.5013 Moving Loss 0.5003
# 0.23697948455810547 secs
# Iter 21200 Loss 0.5013 Moving Loss 0.5001
# 0.23977923393249512 secs
# Iter 21300 Loss 0.5013 Moving Loss 0.5001
# 0.2367854118347168 secs
# Iter 21400 Loss 0.5013 Moving Loss 0.5001
# 0.23928475379943848 secs
# Iter 21500 Loss 0.5013 Moving Loss 0.5002
# 0.25312256813049316 secs
# Iter 21600 Loss 0.5013 Moving Loss 0.5005
# 0.25362682342529297 secs
# Iter 21700 Loss 0.5013 Moving Loss 0.5001
# 0.2562220096588135 secs
# Iter 21800 Loss 0.5013 Moving Loss 0.5001
# 0.2370004653930664 secs
# Iter 21900 Loss 0.5013 Moving Loss 0.5000
# 0.23694491386413574 secs
# Iter 22000 Loss 0.5013 Moving Loss 0.5000
# 0.23772740364074707 secs
# Iter 22100 Loss 0.5013 Moving Loss 0.4998
# 0.23697614669799805 secs
# Iter 22200 Loss 0.5013 Moving Loss 0.5004
# 0.23842859268188477 secs
# Iter 22300 Loss 0.5013 Moving Loss 0.4999
# 0.23811841011047363 secs
# Iter 22400 Loss 0.5013 Moving Loss 0.5003
# 0.23814892768859863 secs
# Iter 22500 Loss 0.5013 Moving Loss 0.5001
# 0.23697519302368164 secs
# Iter 22600 Loss 0.5013 Moving Loss 0.5003
# 0.23682188987731934 secs
# Iter 22700 Loss 0.5013 Moving Loss 0.5023
# 0.23691177368164062 secs
# Iter 22800 Loss 0.5013 Moving Loss 0.5001
# 0.24793648719787598 secs
# Iter 22900 Loss 0.5013 Moving Loss 0.5001
# 0.242919921875 secs
# Iter 23000 Loss 0.5013 Moving Loss 0.5006
# 0.23658156394958496 secs
# Iter 23100 Loss 0.5012 Moving Loss 0.5001
# 0.23694682121276855 secs
# Iter 23200 Loss 0.5012 Moving Loss 0.4999
# 0.23878812789916992 secs
# Iter 23300 Loss 0.5012 Moving Loss 0.5002
# 0.23792481422424316 secs
# Iter 23400 Loss 0.5012 Moving Loss 0.5001
# 0.23605108261108398 secs
# Iter 23500 Loss 0.5012 Moving Loss 0.5003
# 0.24797892570495605 secs
# Iter 23600 Loss 0.5012 Moving Loss 0.4997
# 0.25680041313171387 secs
# Iter 23700 Loss 0.5012 Moving Loss 0.5002
# 0.23749303817749023 secs
# Iter 23800 Loss 0.5012 Moving Loss 0.5000
# 0.237684965133667 secs
# Iter 23900 Loss 0.5012 Moving Loss 0.5001
# 0.24722814559936523 secs
# Iter 24000 Loss 0.5012 Moving Loss 0.5002
# 0.2388150691986084 secs
# Iter 24100 Loss 0.5012 Moving Loss 0.5002
# 0.23970770835876465 secs
# Iter 24200 Loss 0.5012 Moving Loss 0.5006
# 0.2387998104095459 secs
# Iter 24300 Loss 0.5012 Moving Loss 0.5006
# 0.23991680145263672 secs
# Iter 24400 Loss 0.5012 Moving Loss 0.5006
# 0.24199581146240234 secs
# Iter 24500 Loss 0.5012 Moving Loss 0.5000
# 0.23811793327331543 secs
# Iter 24600 Loss 0.5012 Moving Loss 0.5002
# 0.23773932456970215 secs
# Iter 24700 Loss 0.5012 Moving Loss 0.5001
# 0.23613333702087402 secs
# Iter 24800 Loss 0.5012 Moving Loss 0.5001
# 0.23703527450561523 secs
# Iter 24900 Loss 0.5012 Moving Loss 0.5004
# 0.24678897857666016 secs
# Iter 25000 Loss 0.5012 Moving Loss 0.5000
# 0.24246573448181152 secs
# Iter 25100 Loss 0.5012 Moving Loss 0.5002
# 0.2368764877319336 secs
# Iter 25200 Loss 0.5012 Moving Loss 0.5000
# 0.23677802085876465 secs
# Iter 25300 Loss 0.5012 Moving Loss 0.4995
# 0.23958420753479004 secs
# Iter 25400 Loss 0.5011 Moving Loss 0.5004
# 0.23661017417907715 secs
# Iter 25500 Loss 0.5011 Moving Loss 0.4999
# 0.23697352409362793 secs
# Iter 25600 Loss 0.5011 Moving Loss 0.5004
# 0.2487785816192627 secs
# Iter 25700 Loss 0.5011 Moving Loss 0.5002
# 0.24213218688964844 secs
# Iter 25800 Loss 0.5011 Moving Loss 0.5002
# 0.23979878425598145 secs
# Iter 25900 Loss 0.5011 Moving Loss 0.5001
# 0.23642706871032715 secs
# Iter 26000 Loss 0.5011 Moving Loss 0.5000
# 0.24925637245178223 secs
# Iter 26100 Loss 0.5011 Moving Loss 0.5001
# 0.2378995418548584 secs
# Iter 26200 Loss 0.5011 Moving Loss 0.5004
# 0.23719167709350586 secs
# Iter 26300 Loss 0.5011 Moving Loss 0.5000
# 0.2366621494293213 secs
# Iter 26400 Loss 0.5011 Moving Loss 0.4999
# 0.23973488807678223 secs
# Iter 26500 Loss 0.5011 Moving Loss 0.5000
# 0.23686575889587402 secs
# Iter 26600 Loss 0.5011 Moving Loss 0.5003
# 0.23816728591918945 secs
# Iter 26700 Loss 0.5011 Moving Loss 0.5000
# 0.23707079887390137 secs
# Iter 26800 Loss 0.5011 Moving Loss 0.5002
# 0.23737215995788574 secs
# Iter 26900 Loss 0.5011 Moving Loss 0.5002
# 0.23710060119628906 secs
# Iter 27000 Loss 0.5011 Moving Loss 0.5000
# 0.2516806125640869 secs
# Iter 27100 Loss 0.5011 Moving Loss 0.5000
# 0.24084138870239258 secs
# Iter 27200 Loss 0.5011 Moving Loss 0.5001
# 0.23761296272277832 secs
# Iter 27300 Loss 0.5011 Moving Loss 0.5001
# 0.23743581771850586 secs
# Iter 27400 Loss 0.5011 Moving Loss 0.4991
# 0.23951148986816406 secs
# Iter 27500 Loss 0.5011 Moving Loss 0.5013
# 0.2377321720123291 secs
# Iter 27600 Loss 0.5011 Moving Loss 0.5000
# 0.241163969039917 secs
# Iter 27700 Loss 0.5011 Moving Loss 0.5005
# 0.24744868278503418 secs
# Iter 27800 Loss 0.5011 Moving Loss 0.5000
# 0.2389843463897705 secs
# Iter 27900 Loss 0.5011 Moving Loss 0.5001
# 0.23763370513916016 secs
# Iter 28000 Loss 0.5011 Moving Loss 0.5000
# 0.23792195320129395 secs
# Iter 28100 Loss 0.5010 Moving Loss 0.4999
# 0.24805402755737305 secs
# Iter 28200 Loss 0.5010 Moving Loss 0.5003
# 0.2395632266998291 secs
# Iter 28300 Loss 0.5010 Moving Loss 0.4996
# 0.2389202117919922 secs
# Iter 28400 Loss 0.5010 Moving Loss 0.5003
# 0.23717093467712402 secs
# Iter 28500 Loss 0.5010 Moving Loss 0.5004
# 0.2396101951599121 secs
# Iter 28600 Loss 0.5010 Moving Loss 0.5002
# 0.23870253562927246 secs
# Iter 28700 Loss 0.5010 Moving Loss 0.4999
# 0.23953795433044434 secs
# Iter 28800 Loss 0.5010 Moving Loss 0.5000
# 0.23914766311645508 secs
# Iter 28900 Loss 0.5010 Moving Loss 0.5001
# 0.2379617691040039 secs
# Iter 29000 Loss 0.5010 Moving Loss 0.5001
# 0.23751473426818848 secs
# Iter 29100 Loss 0.5010 Moving Loss 0.4996
# 0.24063968658447266 secs
# Iter 29200 Loss 0.5010 Moving Loss 0.5001
# 0.23948144912719727 secs
# Iter 29300 Loss 0.5010 Moving Loss 0.4999
# 0.23859286308288574 secs
# Iter 29400 Loss 0.5010 Moving Loss 0.4998
# 0.2374250888824463 secs
# Iter 29500 Loss 0.5010 Moving Loss 0.5002
# 0.2415757179260254 secs
# Iter 29600 Loss 0.5010 Moving Loss 0.4999
# 0.2371535301208496 secs
# Iter 29700 Loss 0.5010 Moving Loss 0.5002
# 0.23880410194396973 secs
# Iter 29800 Loss 0.5010 Moving Loss 0.5000
# 0.2565581798553467 secs
# Iter 29900 Loss 0.5010 Moving Loss 0.4999
# 0.25403428077697754 secs
# Iter 30000 Loss 0.5010 Moving Loss 0.5002
# 0.24113059043884277 secs
# Iter 30100 Loss 0.5010 Moving Loss 0.5000
# 0.23799490928649902 secs
# Iter 30200 Loss 0.5010 Moving Loss 0.4996
# 0.23798227310180664 secs
# Iter 30300 Loss 0.5010 Moving Loss 0.5003
# 0.2495133876800537 secs
# Iter 30400 Loss 0.5010 Moving Loss 0.5000
# 0.23743271827697754 secs
# Iter 30500 Loss 0.5010 Moving Loss 0.4999
# 0.23799848556518555 secs
# Iter 30600 Loss 0.5010 Moving Loss 0.5000
# 0.24790573120117188 secs
# Iter 30700 Loss 0.5010 Moving Loss 0.4999
# 0.23790764808654785 secs
# Iter 30800 Loss 0.5010 Moving Loss 0.5000
# 0.23712587356567383 secs
# Iter 30900 Loss 0.5010 Moving Loss 0.5002
# 0.23600101470947266 secs
# Iter 31000 Loss 0.5010 Moving Loss 0.4999
# 0.2361466884613037 secs
# Iter 31100 Loss 0.5010 Moving Loss 0.5003
# 0.24352312088012695 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/40-order_hidden_markov_chain_1000000.txt" is the same as "output/decom_hmm_1m"
# ```
