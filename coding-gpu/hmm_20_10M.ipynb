# %% [markdown]
# # Compression logs order-20 HMM 1 Million
#
# Compression
# ```bash
# bash compress.sh Simulated-data/20-order_hidden_markov_chain_1000000.txt output/20_hmm_1m.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/20_hmm_1m.dzip output/decom_hmm_1m com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data/20-order_hidden_markov_chain_1000000.txt output/decom_hmm_1m
# ```

# %% [markdown]
# ### Compression Log
#
# ```bash
# Iter 28300 Loss 0.4235 Moving Loss 0.3877 Train Loss 0.3863
# 0.2270817756652832 secs
# Iter 28400 Loss 0.4234 Moving Loss 0.3960 Train Loss 0.3948
# 0.22720599174499512 secs
# Iter 28500 Loss 0.4233 Moving Loss 0.3938 Train Loss 0.3948
# 0.22646713256835938 secs
# Iter 28600 Loss 0.4232 Moving Loss 0.3938 Train Loss 0.3872
# 0.2237861156463623 secs
# Iter 28700 Loss 0.4230 Moving Loss 0.3826 Train Loss 0.3787
# 0.22214245796203613 secs
# Iter 28800 Loss 0.4229 Moving Loss 0.3744 Train Loss 0.3755
# 0.22616291046142578 secs
# Iter 28900 Loss 0.4228 Moving Loss 0.3994 Train Loss 0.3972
# 0.25788068771362305 secs
# Iter 29000 Loss 0.4227 Moving Loss 0.3913 Train Loss 0.3875
# 0.23645377159118652 secs
# Iter 29100 Loss 0.4226 Moving Loss 0.4013 Train Loss 0.4006
# 0.23266196250915527 secs
# Iter 29200 Loss 0.4225 Moving Loss 0.3966 Train Loss 0.3899
# 0.23485326766967773 secs
# Iter 29300 Loss 0.4224 Moving Loss 0.3993 Train Loss 0.3979
# 0.23792099952697754 secs
# Iter 29400 Loss 0.4223 Moving Loss 0.3916 Train Loss 0.3887
# 0.22595643997192383 secs
# Iter 29500 Loss 0.4223 Moving Loss 0.4048 Train Loss 0.4027
# 0.22417473793029785 secs
# Iter 29600 Loss 0.4221 Moving Loss 0.3883 Train Loss 0.3826
# 0.22317290306091309 secs
# Iter 29700 Loss 0.4220 Moving Loss 0.3795 Train Loss 0.3841
# 0.22586274147033691 secs
# Iter 29800 Loss 0.4219 Moving Loss 0.3909 Train Loss 0.3899
# 0.22930383682250977 secs
# Iter 29900 Loss 0.4218 Moving Loss 0.3803 Train Loss 0.3730
# 0.23347687721252441 secs
# Iter 30000 Loss 0.4217 Moving Loss 0.3989 Train Loss 0.3948
# 0.24436450004577637 secs
# Iter 30100 Loss 0.4216 Moving Loss 0.3932 Train Loss 0.4005
# 0.2253735065460205 secs
# Iter 30200 Loss 0.4216 Moving Loss 0.4145 Train Loss 0.4036
# 0.22380280494689941 secs
# Iter 30300 Loss 0.4215 Moving Loss 0.4124 Train Loss 0.4132
# 0.22339820861816406 secs
# Iter 30400 Loss 0.4215 Moving Loss 0.3994 Train Loss 0.3966
# 0.22362303733825684 secs
# Iter 30500 Loss 0.4213 Moving Loss 0.3841 Train Loss 0.3827
# 0.22622370719909668 secs
# Iter 30600 Loss 0.4213 Moving Loss 0.3947 Train Loss 0.3896
# 0.22472310066223145 secs
# Iter 30700 Loss 0.4212 Moving Loss 0.3963 Train Loss 0.3931
# 0.22975730895996094 secs
# Iter 30800 Loss 0.4211 Moving Loss 0.3879 Train Loss 0.3876
# 0.2257378101348877 secs
# Iter 30900 Loss 0.4210 Moving Loss 0.3856 Train Loss 0.3828
# 0.24393463134765625 secs
# Iter 31000 Loss 0.4209 Moving Loss 0.4027 Train Loss 0.3997
# 0.23651432991027832 secs
# Iter 31100 Loss 0.4208 Moving Loss 0.3972 Train Loss 0.3989
# Done
# ```

# %% [markdown]
# ### Decompression Logs
#
# ```bash
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/.local/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 31249
# Iter 100 Loss 0.5543 Moving Loss 0.5543
# 0.6098670959472656 secs
# Iter 200 Loss 0.5311 Moving Loss 0.5079
# 0.2784135341644287 secs
# Iter 300 Loss 0.5229 Moving Loss 0.5063
# 0.28121209144592285 secs
# Iter 400 Loss 0.5179 Moving Loss 0.5029
# 0.30443620681762695 secs
# Iter 500 Loss 0.5142 Moving Loss 0.4995
# 0.28925347328186035 secs
# Iter 600 Loss 0.5132 Moving Loss 0.5083
# 0.27791786193847656 secs
# Iter 700 Loss 0.5121 Moving Loss 0.5055
# 0.2772190570831299 secs
# Iter 800 Loss 0.5106 Moving Loss 0.5002
# 0.26515817642211914 secs
# Iter 900 Loss 0.5097 Moving Loss 0.5021
# 0.2476189136505127 secs
# Iter 1000 Loss 0.5090 Moving Loss 0.5032
# 0.2506110668182373 secs
# Iter 1100 Loss 0.5082 Moving Loss 0.4997
# 0.2625732421875 secs
# Iter 1200 Loss 0.5076 Moving Loss 0.5017
# 0.26487016677856445 secs
# Iter 1300 Loss 0.5070 Moving Loss 0.4996
# 0.24906277656555176 secs
# Iter 1400 Loss 0.5079 Moving Loss 0.5186
# 0.2447206974029541 secs
# Iter 1500 Loss 0.5073 Moving Loss 0.5000
# 0.23913979530334473 secs
# Iter 1600 Loss 0.5071 Moving Loss 0.5030
# 0.24200224876403809 secs
# Iter 1700 Loss 0.5066 Moving Loss 0.4997
# 0.2563638687133789 secs
# Iter 1800 Loss 0.5062 Moving Loss 0.4992
# 0.2603631019592285 secs
# Iter 1900 Loss 0.5065 Moving Loss 0.5124
# 0.2507789134979248 secs
# Iter 2000 Loss 0.5062 Moving Loss 0.5000
# 0.2410907745361328 secs
# Iter 2100 Loss 0.5062 Moving Loss 0.5062
# 0.24077415466308594 secs
# Iter 2200 Loss 0.5062 Moving Loss 0.5056
# 0.24452638626098633 secs
# Iter 2300 Loss 0.5058 Moving Loss 0.4984
# 0.2406914234161377 secs
# Iter 2400 Loss 0.5055 Moving Loss 0.4985
# 0.2508385181427002 secs
# Iter 2500 Loss 0.5054 Moving Loss 0.5011
# 0.24011850357055664 secs
# Iter 2600 Loss 0.5051 Moving Loss 0.4982
# 0.25067830085754395 secs
# Iter 2700 Loss 0.5047 Moving Loss 0.4960
# 0.25850534439086914 secs
# Iter 2800 Loss 0.5046 Moving Loss 0.5000
# 0.24810528755187988 secs
# Iter 2900 Loss 0.5043 Moving Loss 0.4979
# 0.24089527130126953 secs
# Iter 3000 Loss 0.5042 Moving Loss 0.5008
# 0.253115177154541 secs
# Iter 3100 Loss 0.5041 Moving Loss 0.4990
# 0.27784228324890137 secs
# Iter 3200 Loss 0.5038 Moving Loss 0.4956
# 0.26107263565063477 secs
# Iter 3300 Loss 0.5039 Moving Loss 0.5084
# 0.24601054191589355 secs
# Iter 3400 Loss 0.5038 Moving Loss 0.4985
# 0.2488696575164795 secs
# Iter 3500 Loss 0.5036 Moving Loss 0.4980
# 0.2494046688079834 secs
# Iter 3600 Loss 0.5035 Moving Loss 0.4992
# 0.25737857818603516 secs
# Iter 3700 Loss 0.5033 Moving Loss 0.4952
# 0.2451765537261963 secs
# Iter 3800 Loss 0.5030 Moving Loss 0.4948
# 0.24528813362121582 secs
# Iter 3900 Loss 0.5028 Moving Loss 0.4951
# 0.2515585422515869 secs
# Iter 4000 Loss 0.5028 Moving Loss 0.4993
# 0.24187541007995605 secs
# Iter 4100 Loss 0.5029 Moving Loss 0.5081
# 0.2423553466796875 secs
# Iter 4200 Loss 0.5028 Moving Loss 0.5010
# 0.24283790588378906 secs
# Iter 4300 Loss 0.5026 Moving Loss 0.4938
# 0.24025321006774902 secs
# Iter 4400 Loss 0.5025 Moving Loss 0.4949
# 0.2580246925354004 secs
# Iter 4500 Loss 0.5023 Moving Loss 0.4963
# 0.2700166702270508 secs
# Iter 4600 Loss 0.5020 Moving Loss 0.4895
# 0.2473902702331543 secs
# Iter 4700 Loss 0.5024 Moving Loss 0.5173
# 0.2417435646057129 secs
# Iter 4800 Loss 0.5022 Moving Loss 0.4929
# 0.24227309226989746 secs
# Iter 4900 Loss 0.5020 Moving Loss 0.4927
# 0.2390296459197998 secs
# Iter 5000 Loss 0.5020 Moving Loss 0.5055
# 0.2552509307861328 secs
# Iter 5100 Loss 0.5020 Moving Loss 0.4975
# 0.25344085693359375 secs
# Iter 5200 Loss 0.5018 Moving Loss 0.4928
# 0.25023460388183594 secs
# Iter 5300 Loss 0.5016 Moving Loss 0.4902
# 0.24582457542419434 secs
# Iter 5400 Loss 0.5013 Moving Loss 0.4878
# 0.26293420791625977 secs
# Iter 5500 Loss 0.5010 Moving Loss 0.4845
# 0.25067758560180664 secs
# Iter 5600 Loss 0.5013 Moving Loss 0.5189
# 0.24177002906799316 secs
# Iter 5700 Loss 0.5010 Moving Loss 0.4804
# 0.2395007610321045 secs
# Iter 5800 Loss 0.5008 Moving Loss 0.4904
# 0.24416542053222656 secs
# Iter 5900 Loss 0.5007 Moving Loss 0.4956
# 0.24265360832214355 secs
# Iter 6000 Loss 0.5004 Moving Loss 0.4837
# 0.25260281562805176 secs
# Iter 6100 Loss 0.4998 Moving Loss 0.4644
# 0.24087309837341309 secs
# Iter 6200 Loss 0.4991 Moving Loss 0.4543
# 0.24539589881896973 secs
# Iter 6300 Loss 0.4982 Moving Loss 0.4429
# 0.25374484062194824 secs
# Iter 6400 Loss 0.4974 Moving Loss 0.4507
# 0.2765369415283203 secs
# Iter 6500 Loss 0.4965 Moving Loss 0.4382
# 0.23963451385498047 secs
# Iter 6600 Loss 0.4952 Moving Loss 0.4111
# 0.2406764030456543 secs
# Iter 6700 Loss 0.4941 Moving Loss 0.4187
# 0.24037957191467285 secs
# Iter 6800 Loss 0.4931 Moving Loss 0.4238
# 0.24341821670532227 secs
# Iter 6900 Loss 0.4919 Moving Loss 0.4152
# 0.2468256950378418 secs
# Iter 7000 Loss 0.4906 Moving Loss 0.4010
# 0.24562668800354004 secs
# Iter 7100 Loss 0.4896 Moving Loss 0.4143
# 0.25843214988708496 secs
# Iter 7200 Loss 0.4886 Moving Loss 0.4219
# 0.2565445899963379 secs
# Iter 7300 Loss 0.4879 Moving Loss 0.4341
# 0.25340986251831055 secs
# Iter 7400 Loss 0.4868 Moving Loss 0.4104
# 0.2532060146331787 secs
# Iter 7500 Loss 0.4858 Moving Loss 0.4098
# 0.26099085807800293 secs
# Iter 7600 Loss 0.4847 Moving Loss 0.4036
# 0.24251627922058105 secs
# Iter 7700 Loss 0.4838 Moving Loss 0.4131
# 0.24413108825683594 secs
# Iter 7800 Loss 0.4830 Moving Loss 0.4211
# 0.24807405471801758 secs
# Iter 7900 Loss 0.4820 Moving Loss 0.4091
# 0.2417910099029541 secs
# Iter 8000 Loss 0.4812 Moving Loss 0.4155
# 0.24686145782470703 secs
# Iter 8100 Loss 0.4804 Moving Loss 0.4144
# 0.251967191696167 secs
# Iter 8200 Loss 0.4795 Moving Loss 0.4036
# 0.2568342685699463 secs
# Iter 8300 Loss 0.4789 Moving Loss 0.4304
# 0.2523181438446045 secs
# Iter 8400 Loss 0.4782 Moving Loss 0.4221
# 0.2620375156402588 secs
# Iter 8500 Loss 0.4776 Moving Loss 0.4285
# 0.24831676483154297 secs
# Iter 8600 Loss 0.4769 Moving Loss 0.4136
# 0.24185919761657715 secs
# Iter 8700 Loss 0.4761 Moving Loss 0.4092
# 0.2408890724182129 secs
# Iter 8800 Loss 0.4752 Moving Loss 0.3986
# 0.24397659301757812 secs
# Iter 8900 Loss 0.4746 Moving Loss 0.4245
# 0.24207687377929688 secs
# Iter 9000 Loss 0.4739 Moving Loss 0.4106
# 0.24051594734191895 secs
# Iter 9100 Loss 0.4732 Moving Loss 0.4112
# 0.2636106014251709 secs
# Iter 9200 Loss 0.4726 Moving Loss 0.4176
# 0.2893550395965576 secs
# Iter 9300 Loss 0.4718 Moving Loss 0.3978
# 0.24817752838134766 secs
# Iter 9400 Loss 0.4712 Moving Loss 0.4112
# 0.23958754539489746 secs
# Iter 9500 Loss 0.4706 Moving Loss 0.4171
# 0.24259400367736816 secs
# Iter 9600 Loss 0.4701 Moving Loss 0.4176
# 0.23760151863098145 secs
# Iter 9700 Loss 0.4695 Moving Loss 0.4129
# 0.239668607711792 secs
# Iter 9800 Loss 0.4689 Moving Loss 0.4104
# 0.2677953243255615 secs
# Iter 9900 Loss 0.4682 Moving Loss 0.4074
# 0.23529577255249023 secs
# Iter 10000 Loss 0.4677 Moving Loss 0.4122
# 0.23963117599487305 secs
# Iter 10100 Loss 0.4671 Moving Loss 0.4079
# 0.2565767765045166 secs
# Iter 10200 Loss 0.4665 Moving Loss 0.4084
# 0.2552034854888916 secs
# Iter 10300 Loss 0.4659 Moving Loss 0.4074
# 0.23899388313293457 secs
# Iter 10400 Loss 0.4655 Moving Loss 0.4173
# 0.25261545181274414 secs
# Iter 10500 Loss 0.4649 Moving Loss 0.4041
# 0.24399280548095703 secs
# Iter 10600 Loss 0.4643 Moving Loss 0.3982
# 0.2381291389465332 secs
# Iter 10700 Loss 0.4637 Moving Loss 0.4077
# 0.24294495582580566 secs
# Iter 10800 Loss 0.4632 Moving Loss 0.4044
# 0.24173665046691895 secs
# Iter 10900 Loss 0.4625 Moving Loss 0.3899
# 0.23907971382141113 secs
# Iter 11000 Loss 0.4620 Moving Loss 0.4073
# 0.24954843521118164 secs
# Iter 11100 Loss 0.4615 Moving Loss 0.4107
# 0.2734348773956299 secs
# Iter 11200 Loss 0.4609 Moving Loss 0.3839
# 0.24960923194885254 secs
# Iter 11300 Loss 0.4606 Moving Loss 0.4268
# 0.23756027221679688 secs
# Iter 11400 Loss 0.4601 Moving Loss 0.4083
# 0.237274169921875 secs
# Iter 11500 Loss 0.4597 Moving Loss 0.4162
# 0.29042863845825195 secs
# Iter 11600 Loss 0.4593 Moving Loss 0.4132
# 0.24147939682006836 secs
# Iter 11700 Loss 0.4590 Moving Loss 0.4183
# 0.2407667636871338 secs
# Iter 11800 Loss 0.4586 Moving Loss 0.4121
# 0.24310564994812012 secs
# Iter 11900 Loss 0.4582 Moving Loss 0.4097
# 0.23720073699951172 secs
# Iter 12000 Loss 0.4577 Moving Loss 0.4077
# 0.23741912841796875 secs
# Iter 12100 Loss 0.4573 Moving Loss 0.4114
# 0.2385716438293457 secs
# Iter 12200 Loss 0.4570 Moving Loss 0.4124
# 0.24981236457824707 secs
# Iter 12300 Loss 0.4566 Moving Loss 0.4150
# 0.23670625686645508 secs
# Iter 12400 Loss 0.4562 Moving Loss 0.4018
# 0.2501540184020996 secs
# Iter 12500 Loss 0.4558 Moving Loss 0.4115
# 0.24962115287780762 secs
# Iter 12600 Loss 0.4555 Moving Loss 0.4127
# 0.24512100219726562 secs
# Iter 12700 Loss 0.4551 Moving Loss 0.4081
# 0.23694896697998047 secs
# Iter 12800 Loss 0.4548 Moving Loss 0.4173
# 0.2388472557067871 secs
# Iter 12900 Loss 0.4545 Moving Loss 0.4105
# 0.23945999145507812 secs
# Iter 13000 Loss 0.4541 Moving Loss 0.4090
# 0.23651933670043945 secs
# Iter 13100 Loss 0.4538 Moving Loss 0.4064
# 0.2551581859588623 secs
# Iter 13200 Loss 0.4535 Moving Loss 0.4188
# 0.2508251667022705 secs
# Iter 13300 Loss 0.4531 Moving Loss 0.3996
# 0.2423701286315918 secs
# Iter 13400 Loss 0.4527 Moving Loss 0.3935
# 0.23879122734069824 secs
# Iter 13500 Loss 0.4522 Moving Loss 0.3961
# 0.23771119117736816 secs
# Iter 13600 Loss 0.4519 Moving Loss 0.4006
# 0.2450399398803711 secs
# Iter 13700 Loss 0.4515 Moving Loss 0.3996
# 0.23825550079345703 secs
# Iter 13800 Loss 0.4511 Moving Loss 0.4061
# 0.23772382736206055 secs
# Iter 13900 Loss 0.4508 Moving Loss 0.4055
# 0.24202728271484375 secs
# Iter 14000 Loss 0.4505 Moving Loss 0.4023
# 0.23955368995666504 secs
# Iter 14100 Loss 0.4501 Moving Loss 0.4016
# 0.24281620979309082 secs
# Iter 14200 Loss 0.4498 Moving Loss 0.4069
# 0.24074935913085938 secs
# Iter 14300 Loss 0.4496 Moving Loss 0.4167
# 0.2506754398345947 secs
# Iter 14400 Loss 0.4495 Moving Loss 0.4369
# 0.23821592330932617 secs
# Iter 14500 Loss 0.4492 Moving Loss 0.4066
# 0.25541019439697266 secs
# Iter 14600 Loss 0.4488 Moving Loss 0.3880
# 0.241715669631958 secs
# Iter 14700 Loss 0.4482 Moving Loss 0.3659
# 0.23978710174560547 secs
# Iter 14800 Loss 0.4478 Moving Loss 0.3922
# 0.23807263374328613 secs
# Iter 14900 Loss 0.4474 Moving Loss 0.3816
# 0.23626232147216797 secs
# Iter 15000 Loss 0.4470 Moving Loss 0.3906
# 0.23955368995666504 secs
# Iter 15100 Loss 0.4467 Moving Loss 0.4020
# 0.2360670566558838 secs
# Iter 15200 Loss 0.4464 Moving Loss 0.3999
# 0.2600979804992676 secs
# Iter 15300 Loss 0.4463 Moving Loss 0.4231
# 0.2596590518951416 secs
# Iter 15400 Loss 0.4460 Moving Loss 0.4037
# 0.23834657669067383 secs
# Iter 15500 Loss 0.4457 Moving Loss 0.4016
# 0.23780035972595215 secs
# Iter 15600 Loss 0.4454 Moving Loss 0.3996
# 0.23775005340576172 secs
# Iter 15700 Loss 0.4452 Moving Loss 0.4072
# 0.24704742431640625 secs
# Iter 15800 Loss 0.4449 Moving Loss 0.4067
# 0.2377033233642578 secs
# Iter 15900 Loss 0.4446 Moving Loss 0.3870
# 0.2399888038635254 secs
# Iter 16000 Loss 0.4442 Moving Loss 0.3941
# 0.2391796112060547 secs
# Iter 16100 Loss 0.4440 Moving Loss 0.4067
# 0.2372276782989502 secs
# Iter 16200 Loss 0.4438 Moving Loss 0.4112
# 0.2360243797302246 secs
# Iter 16300 Loss 0.4435 Moving Loss 0.3967
# 0.23606157302856445 secs
# Iter 16400 Loss 0.4433 Moving Loss 0.4017
# 0.25105762481689453 secs
# Iter 16500 Loss 0.4430 Moving Loss 0.3985
# 0.24683809280395508 secs
# Iter 16600 Loss 0.4428 Moving Loss 0.4072
# 0.24567818641662598 secs
# Iter 16700 Loss 0.4425 Moving Loss 0.3929
# 0.24187421798706055 secs
# Iter 16800 Loss 0.4422 Moving Loss 0.3908
# 0.2369382381439209 secs
# Iter 16900 Loss 0.4420 Moving Loss 0.4154
# 0.2393648624420166 secs
# Iter 17000 Loss 0.4417 Moving Loss 0.3948
# 0.2375955581665039 secs
# Iter 17100 Loss 0.4415 Moving Loss 0.3958
# 0.23686790466308594 secs
# Iter 17200 Loss 0.4412 Moving Loss 0.3992
# 0.24761724472045898 secs
# Iter 17300 Loss 0.4410 Moving Loss 0.3975
# 0.25222229957580566 secs
# Iter 17400 Loss 0.4406 Moving Loss 0.3865
# 0.26691675186157227 secs
# Iter 17500 Loss 0.4404 Moving Loss 0.3981
# 0.2413322925567627 secs
# Iter 17600 Loss 0.4402 Moving Loss 0.3997
# 0.2367241382598877 secs
# Iter 17700 Loss 0.4400 Moving Loss 0.4082
# 0.23894238471984863 secs
# Iter 17800 Loss 0.4398 Moving Loss 0.3979
# 0.23848462104797363 secs
# Iter 17900 Loss 0.4395 Moving Loss 0.3970
# 0.24719023704528809 secs
# Iter 18000 Loss 0.4392 Moving Loss 0.3874
# 0.24028563499450684 secs
# Iter 18100 Loss 0.4390 Moving Loss 0.3963
# 0.23775887489318848 secs
# Iter 18200 Loss 0.4388 Moving Loss 0.3979
# 0.2368481159210205 secs
# Iter 18300 Loss 0.4385 Moving Loss 0.3826
# 0.2376856803894043 secs
# Iter 18400 Loss 0.4382 Moving Loss 0.3994
# 0.24173617362976074 secs
# Iter 18500 Loss 0.4380 Moving Loss 0.3937
# 0.24992680549621582 secs
# Iter 18600 Loss 0.4378 Moving Loss 0.4079
# 0.2492828369140625 secs
# Iter 18700 Loss 0.4376 Moving Loss 0.3945
# 0.24890589714050293 secs
# Iter 18800 Loss 0.4374 Moving Loss 0.3920
# 0.23795342445373535 secs
# Iter 18900 Loss 0.4371 Moving Loss 0.3953
# 0.23981451988220215 secs
# Iter 19000 Loss 0.4370 Moving Loss 0.4064
# 0.23908734321594238 secs
# Iter 19100 Loss 0.4367 Moving Loss 0.3888
# 0.23739862442016602 secs
# Iter 19200 Loss 0.4365 Moving Loss 0.3900
# 0.23819231986999512 secs
# Iter 19300 Loss 0.4363 Moving Loss 0.3961
# 0.2550053596496582 secs
# Iter 19400 Loss 0.4361 Moving Loss 0.4020
# 0.25900769233703613 secs
# Iter 19500 Loss 0.4359 Moving Loss 0.4053
# 0.2400989532470703 secs
# Iter 19600 Loss 0.4357 Moving Loss 0.3878
# 0.23529982566833496 secs
# Iter 19700 Loss 0.4355 Moving Loss 0.3894
# 0.23653149604797363 secs
# Iter 19800 Loss 0.4353 Moving Loss 0.4017
# 0.24152231216430664 secs
# Iter 19900 Loss 0.4351 Moving Loss 0.3996
# 0.25347256660461426 secs
# Iter 20000 Loss 0.4349 Moving Loss 0.3938
# 0.24078726768493652 secs
# Iter 20100 Loss 0.4348 Moving Loss 0.4096
# 0.23937439918518066 secs
# Iter 20200 Loss 0.4346 Moving Loss 0.3895
# 0.23605751991271973 secs
# Iter 20300 Loss 0.4344 Moving Loss 0.3937
# 0.23722100257873535 secs
# Iter 20400 Loss 0.4342 Moving Loss 0.4073
# 0.2391645908355713 secs
# Iter 20500 Loss 0.4341 Moving Loss 0.3992
# 0.23769783973693848 secs
# Iter 20600 Loss 0.4339 Moving Loss 0.3947
# 0.2527439594268799 secs
# Iter 20700 Loss 0.4337 Moving Loss 0.3985
# 0.24951791763305664 secs
# Iter 20800 Loss 0.4334 Moving Loss 0.3669
# 0.23909497261047363 secs
# Iter 20900 Loss 0.4331 Moving Loss 0.3808
# 0.24086284637451172 secs
# Iter 21000 Loss 0.4330 Moving Loss 0.4073
# 0.2371218204498291 secs
# Iter 21100 Loss 0.4328 Moving Loss 0.3942
# 0.23769497871398926 secs
# Iter 21200 Loss 0.4327 Moving Loss 0.4008
# 0.23518633842468262 secs
# Iter 21300 Loss 0.4325 Moving Loss 0.3943
# 0.23761606216430664 secs
# Iter 21400 Loss 0.4322 Moving Loss 0.3795
# 0.2657124996185303 secs
# Iter 21500 Loss 0.4320 Moving Loss 0.3836
# 0.25347137451171875 secs
# Iter 21600 Loss 0.4319 Moving Loss 0.4063
# 0.24227452278137207 secs
# Iter 21700 Loss 0.4318 Moving Loss 0.4075
# 0.2382960319519043 secs
# Iter 21800 Loss 0.4316 Moving Loss 0.3947
# 0.24016070365905762 secs
# Iter 21900 Loss 0.4315 Moving Loss 0.4054
# 0.24312186241149902 secs
# Iter 22000 Loss 0.4313 Moving Loss 0.3899
# 0.23639154434204102 secs
# Iter 22100 Loss 0.4312 Moving Loss 0.4051
# 0.2384626865386963 secs
# Iter 22200 Loss 0.4310 Moving Loss 0.3971
# 0.2398066520690918 secs
# Iter 22300 Loss 0.4309 Moving Loss 0.4110
# 0.24611783027648926 secs
# Iter 22400 Loss 0.4308 Moving Loss 0.3913
# 0.25631284713745117 secs
# Iter 22500 Loss 0.4306 Moving Loss 0.3952
# 0.25830769538879395 secs
# Iter 22600 Loss 0.4305 Moving Loss 0.4001
# 0.2383577823638916 secs
# Iter 22700 Loss 0.4303 Moving Loss 0.3964
# 0.27129435539245605 secs
# Iter 22800 Loss 0.4302 Moving Loss 0.4016
# 0.28130507469177246 secs
# Iter 22900 Loss 0.4300 Moving Loss 0.3973
# 0.28165197372436523 secs
# Iter 23000 Loss 0.4299 Moving Loss 0.3997
# 0.25140929222106934 secs
# Iter 23100 Loss 0.4298 Moving Loss 0.3981
# 0.25722289085388184 secs
# Iter 23200 Loss 0.4296 Moving Loss 0.3876
# 0.23948907852172852 secs
# Iter 23300 Loss 0.4295 Moving Loss 0.3975
# 0.236863374710083 secs
# Iter 23400 Loss 0.4293 Moving Loss 0.3913
# 0.2604806423187256 secs
# Iter 23500 Loss 0.4291 Moving Loss 0.3897
# 0.27672410011291504 secs
# Iter 23600 Loss 0.4290 Moving Loss 0.4057
# 0.255185604095459 secs
# Iter 23700 Loss 0.4289 Moving Loss 0.3888
# 0.252086877822876 secs
# Iter 23800 Loss 0.4287 Moving Loss 0.3949
# 0.2521383762359619 secs
# Iter 23900 Loss 0.4286 Moving Loss 0.3986
# 0.2426161766052246 secs
# Iter 24000 Loss 0.4284 Moving Loss 0.3878
# 0.23832106590270996 secs
# Iter 24100 Loss 0.4283 Moving Loss 0.3930
# 0.24095797538757324 secs
# Iter 24200 Loss 0.4281 Moving Loss 0.3948
# 0.23916983604431152 secs
# Iter 24300 Loss 0.4280 Moving Loss 0.3940
# 0.23606061935424805 secs
# Iter 24400 Loss 0.4279 Moving Loss 0.3983
# 0.23505783081054688 secs
# Iter 24500 Loss 0.4277 Moving Loss 0.3900
# 0.23496747016906738 secs
# Iter 24600 Loss 0.4276 Moving Loss 0.4045
# 0.24255871772766113 secs
# Iter 24700 Loss 0.4275 Moving Loss 0.3890
# 0.2667722702026367 secs
# Iter 24800 Loss 0.4273 Moving Loss 0.3928
# 0.24061226844787598 secs
# Iter 24900 Loss 0.4272 Moving Loss 0.4012
# 0.2372303009033203 secs
# Iter 25000 Loss 0.4272 Moving Loss 0.4115
# 0.2379300594329834 secs
# Iter 25100 Loss 0.4270 Moving Loss 0.3982
# 0.23898744583129883 secs
# Iter 25200 Loss 0.4269 Moving Loss 0.3904
# 0.23662805557250977 secs
# Iter 25300 Loss 0.4267 Moving Loss 0.3824
# 0.23457074165344238 secs
# Iter 25400 Loss 0.4266 Moving Loss 0.3937
# 0.26883578300476074 secs
# Iter 25500 Loss 0.4265 Moving Loss 0.4077
# 0.28954410552978516 secs
# Iter 25600 Loss 0.4264 Moving Loss 0.3918
# 0.2545459270477295 secs
# Iter 25700 Loss 0.4262 Moving Loss 0.3899
# 0.2466754913330078 secs
# Iter 25800 Loss 0.4262 Moving Loss 0.4060
# 0.23536396026611328 secs
# Iter 25900 Loss 0.4261 Moving Loss 0.4142
# 0.23653340339660645 secs
# Iter 26000 Loss 0.4261 Moving Loss 0.4153
# 0.23814082145690918 secs
# Iter 26100 Loss 0.4259 Moving Loss 0.3806
# 0.2379910945892334 secs
# Iter 26200 Loss 0.4258 Moving Loss 0.3992
# 0.23683500289916992 secs
# Iter 26300 Loss 0.4256 Moving Loss 0.3824
# 0.23768973350524902 secs
# Iter 26400 Loss 0.4255 Moving Loss 0.4012
# 0.236297607421875 secs
# Iter 26500 Loss 0.4254 Moving Loss 0.3924
# 0.25187087059020996 secs
# Iter 26600 Loss 0.4253 Moving Loss 0.3973
# 0.2502741813659668 secs
# Iter 26700 Loss 0.4252 Moving Loss 0.3898
# 0.24649691581726074 secs
# Iter 26800 Loss 0.4250 Moving Loss 0.3800
# 0.2542850971221924 secs
# Iter 26900 Loss 0.4249 Moving Loss 0.4041
# 0.23890304565429688 secs
# Iter 27000 Loss 0.4248 Moving Loss 0.3899
# 0.23944807052612305 secs
# Iter 27100 Loss 0.4246 Moving Loss 0.3826
# 0.23802661895751953 secs
# Iter 27200 Loss 0.4245 Moving Loss 0.3959
# 0.23712754249572754 secs
# Iter 27300 Loss 0.4245 Moving Loss 0.4065
# 0.23806118965148926 secs
# Iter 27400 Loss 0.4244 Moving Loss 0.4085
# 0.2632637023925781 secs
# Iter 27500 Loss 0.4243 Moving Loss 0.4022
# 0.25897741317749023 secs
# Iter 27600 Loss 0.4242 Moving Loss 0.3753
# 0.28848958015441895 secs
# Iter 27700 Loss 0.4240 Moving Loss 0.3860
# 0.23660850524902344 secs
# Iter 27800 Loss 0.4239 Moving Loss 0.3932
# 0.2371349334716797 secs
# Iter 27900 Loss 0.4238 Moving Loss 0.3992
# 0.2379317283630371 secs
# Iter 28000 Loss 0.4237 Moving Loss 0.3984
# 0.24233007431030273 secs
# Iter 28100 Loss 0.4237 Moving Loss 0.4060
# 0.23613715171813965 secs
# Iter 28200 Loss 0.4236 Moving Loss 0.4060
# 0.2400672435760498 secs
# Iter 28300 Loss 0.4235 Moving Loss 0.3877
# 0.2535102367401123 secs
# Iter 28400 Loss 0.4234 Moving Loss 0.3960
# 0.2511622905731201 secs
# Iter 28500 Loss 0.4233 Moving Loss 0.3938
# 0.23917531967163086 secs
# Iter 28600 Loss 0.4232 Moving Loss 0.3938
# 0.23579931259155273 secs
# Iter 28700 Loss 0.4230 Moving Loss 0.3826
# 0.2362079620361328 secs
# Iter 28800 Loss 0.4229 Moving Loss 0.3744
# 0.2450549602508545 secs
# Iter 28900 Loss 0.4228 Moving Loss 0.3994
# 0.2496929168701172 secs
# Iter 29000 Loss 0.4227 Moving Loss 0.3913
# 0.23849844932556152 secs
# Iter 29100 Loss 0.4226 Moving Loss 0.4013
# 0.24137377738952637 secs
# Iter 29200 Loss 0.4225 Moving Loss 0.3966
# 0.24747943878173828 secs
# Iter 29300 Loss 0.4224 Moving Loss 0.3993
# 0.2517268657684326 secs
# Iter 29400 Loss 0.4223 Moving Loss 0.3916
# 0.24354934692382812 secs
# Iter 29500 Loss 0.4223 Moving Loss 0.4048
# 0.252605676651001 secs
# Iter 29600 Loss 0.4221 Moving Loss 0.3883
# 0.24527740478515625 secs
# Iter 29700 Loss 0.4220 Moving Loss 0.3795
# 0.23807239532470703 secs
# Iter 29800 Loss 0.4219 Moving Loss 0.3909
# 0.23914265632629395 secs
# Iter 29900 Loss 0.4218 Moving Loss 0.3803
# 0.23892712593078613 secs
# Iter 30000 Loss 0.4217 Moving Loss 0.3989
# 0.24542474746704102 secs
# Iter 30100 Loss 0.4216 Moving Loss 0.3932
# 0.25074076652526855 secs
# Iter 30200 Loss 0.4216 Moving Loss 0.4145
# 0.25197386741638184 secs
# Iter 30300 Loss 0.4215 Moving Loss 0.4124
# 0.2456223964691162 secs
# Iter 30400 Loss 0.4215 Moving Loss 0.3994
# 0.24345874786376953 secs
# Iter 30500 Loss 0.4213 Moving Loss 0.3841
# 0.23753857612609863 secs
# Iter 30600 Loss 0.4213 Moving Loss 0.3947
# 0.23859739303588867 secs
# Iter 30700 Loss 0.4212 Moving Loss 0.3963
# 0.23812007904052734 secs
# Iter 30800 Loss 0.4211 Moving Loss 0.3879
# 0.23996758460998535 secs
# Iter 30900 Loss 0.4210 Moving Loss 0.3856
# 0.2400047779083252 secs
# Iter 31000 Loss 0.4209 Moving Loss 0.4027
# 0.2523162364959717 secs
# Iter 31100 Loss 0.4208 Moving Loss 0.3972
# 0.25858426094055176 secs
# Done
# ```

# %% [markdown]
# ### Comparison Logs
#
# ```bash
# The file "Simulated-data/20-order_hidden_markov_chain_1000000.txt" is the same as "output/decom_hmm_1m"
# ```
