# %% [markdown]
# # Compression logs order-30 markov chain
#
# Compression
# ```bash
# bash compress.sh Simulated-data-main/30-order_markov_chain.txt output/30_mc.dzip com MODEL_PATH
# ```
#
# Decompress
# ```bash
# bash decompress.sh output/30_mc.dzip output/decom_mc30 com MODEL_PATH
# ```
#
# Verify successful decompression
# ```bash
# bash compare.sh Simulated-data-main/30-order_markov_chain.txt output/decom_mc30
# ```

# %% [markdown]
# # Compression Logs
#
# ```bash
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# Iter 100 Loss 0.5659 Moving Loss 0.5659
# 0.40853214263916016 secs
# Iter 200 Loss 0.5343 Moving Loss 0.5028
# 0.18056392669677734 secs
# Iter 300 Loss 0.5268 Moving Loss 0.5118
# 0.18127036094665527 secs
# Iter 400 Loss 0.5204 Moving Loss 0.5013
# 0.18002033233642578 secs
# Iter 500 Loss 0.5165 Moving Loss 0.5006
# 0.18095803260803223 secs
# Iter 600 Loss 0.5158 Moving Loss 0.5124
# 0.17986345291137695 secs
# Iter 700 Loss 0.5137 Moving Loss 0.5013
# 0.18015623092651367 secs
# Iter 800 Loss 0.5123 Moving Loss 0.5024
# 0.17983388900756836 secs
# Iter 900 Loss 0.5114 Moving Loss 0.5044
# 0.1801004409790039 secs
# Iter 1000 Loss 0.5104 Moving Loss 0.5013
# 0.18000173568725586 secs
# Iter 1100 Loss 0.5095 Moving Loss 0.4999
# 0.18184304237365723 secs
# Iter 1200 Loss 0.5089 Moving Loss 0.5029
# 0.18278932571411133 secs
# Iter 1300 Loss 0.5083 Moving Loss 0.5010
# 0.1801307201385498 secs
# Iter 1400 Loss 0.5080 Moving Loss 0.5035
# 0.17994117736816406 secs
# Iter 1500 Loss 0.5075 Moving Loss 0.5008
# 0.1800088882446289 secs
# Iter 1600 Loss 0.5071 Moving Loss 0.5016
# 0.18051385879516602 secs
# Iter 1700 Loss 0.5068 Moving Loss 0.5015
# 0.18419456481933594 secs
# Iter 1800 Loss 0.5064 Moving Loss 0.5001
# 0.18059563636779785 secs
# Iter 1900 Loss 0.5061 Moving Loss 0.5001
# 0.17977476119995117 secs
# Iter 2000 Loss 0.5059 Moving Loss 0.5020
# 0.18199539184570312 secs
# Iter 2100 Loss 0.5056 Moving Loss 0.5010
# 0.17995381355285645 secs
# Iter 2200 Loss 0.5055 Moving Loss 0.5016
# 0.18001151084899902 secs
# Iter 2300 Loss 0.5053 Moving Loss 0.5026
# 0.17983722686767578 secs
# Iter 2400 Loss 0.5051 Moving Loss 0.5007
# 0.180023193359375 secs
# Iter 2500 Loss 0.5054 Moving Loss 0.5116
# 0.1898808479309082 secs
# Iter 2600 Loss 0.5057 Moving Loss 0.5136
# 0.18816328048706055 secs
# Iter 2700 Loss 0.5055 Moving Loss 0.5006
# 0.1801772117614746 secs
# Iter 2800 Loss 0.5054 Moving Loss 0.5008
# 0.18040180206298828 secs
# Iter 2900 Loss 0.5052 Moving Loss 0.5002
# 0.1808326244354248 secs
# Iter 3000 Loss 0.5050 Moving Loss 0.5006
# 0.17986822128295898 secs
# Done
# (torch_venv) (base) bash-5.1$ bash compare.sh Simulated-data-main/20-order_markov_chain.txt output/decom_mc20
# The file "Simulated-data-main/20-order_markov_chain.txt" is the same as "output/decom_mc20"
# (torch_venv) (base) bash-5.1$ bash compress.sh Simulated-data-main/20-order_hidden_markov_chain.txt 20_hmm.dzip com MODEL_PATH
# Seq Length 199999
# Using cuda
# Vocab Size 3
# CudNN version 90100
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2623107433319092 secs
# ====> Epoch: 1 Average loss: 0.6197071183.7673
# Loss went from 100000000.0000 to 0.6197
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08753132820129395 secs
# ====> Epoch: 2 Average loss: 0.5022469120.5004
# Loss went from 0.6197 to 0.5022
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09898805618286133 secs
# ====> Epoch: 3 Average loss: 0.5011245790.4912
# Loss went from 0.5022 to 0.5011
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09159040451049805 secs
# ====> Epoch: 4 Average loss: 0.5013875789.4971
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08971786499023438 secs
# ====> Epoch: 5 Average loss: 0.5013506151.4918
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.0927267074584961 secs
# ====> Epoch: 6 Average loss: 0.5005211311.4956
# Loss went from 0.5011 to 0.5005
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09078335762023926 secs
# ====> Epoch: 7 Average loss: 0.5009008379.4868
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09162139892578125 secs
# ====> Epoch: 8 Average loss: 0.5004717425.4879
# Loss went from 0.5005 to 0.5005
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# 0.40949583053588867 secs
# Iter 100 Loss 0.5459 Moving Loss 0.5459 Train Loss 0.9084
# 0.17007017135620117 secs
# Iter 200 Loss 0.5269 Moving Loss 0.5078 Train Loss 0.5612
# 0.1682720184326172 secs
# Iter 300 Loss 0.5201 Moving Loss 0.5066 Train Loss 0.5172
# 0.16900277137756348 secs
# Iter 400 Loss 0.5167 Moving Loss 0.5065 Train Loss 0.5549
# 0.1681363582611084 secs
# Iter 500 Loss 0.5134 Moving Loss 0.5000 Train Loss 0.5046
# 0.167466402053833 secs
# Iter 600 Loss 0.5127 Moving Loss 0.5095 Train Loss 0.5383
# 0.1679086685180664 secs
# Iter 700 Loss 0.5110 Moving Loss 0.5010 Train Loss 0.5095
# 0.16796040534973145 secs
# Iter 800 Loss 0.5097 Moving Loss 0.5002 Train Loss 0.5073
# 0.16780877113342285 secs
# Iter 900 Loss 0.5090 Moving Loss 0.5036 Train Loss 0.5175
# 0.16760516166687012 secs
# Iter 1000 Loss 0.5084 Moving Loss 0.5034 Train Loss 0.5100
# 0.1718587875366211 secs
# Iter 1100 Loss 0.5080 Moving Loss 0.5031 Train Loss 0.5162
# 0.17142701148986816 secs
# Iter 1200 Loss 0.5077 Moving Loss 0.5044 Train Loss 0.5092
# 0.16884922981262207 secs
# Iter 1300 Loss 0.5076 Moving Loss 0.5071 Train Loss 0.5494
# 0.1673898696899414 secs
# Iter 1400 Loss 0.5070 Moving Loss 0.4992 Train Loss 0.4999
# 0.16792917251586914 secs
# Iter 1500 Loss 0.5065 Moving Loss 0.4992 Train Loss 0.5034
# 0.16821908950805664 secs
# Iter 1600 Loss 0.5063 Moving Loss 0.5038 Train Loss 0.5216
# 0.17433834075927734 secs
# Iter 1700 Loss 0.5061 Moving Loss 0.5032 Train Loss 0.5119
# 0.1670539379119873 secs
# Iter 1800 Loss 0.5060 Moving Loss 0.5034 Train Loss 0.5083
# 0.16707611083984375 secs
# Iter 1900 Loss 0.5058 Moving Loss 0.5024 Train Loss 0.5200
# 0.1679823398590088 secs
# Iter 2000 Loss 0.5055 Moving Loss 0.4987 Train Loss 0.4991
# 0.16745352745056152 secs
# Iter 2100 Loss 0.5052 Moving Loss 0.5008 Train Loss 0.5054
# 0.16858267784118652 secs
# Iter 2200 Loss 0.5050 Moving Loss 0.5003 Train Loss 0.5065
# 0.17613887786865234 secs
# Iter 2300 Loss 0.5047 Moving Loss 0.4987 Train Loss 0.5054
# 0.1681993007659912 secs
# Iter 2400 Loss 0.5074 Moving Loss 0.5681 Train Loss 0.7103
# 0.167921781539917 secs
# Iter 2500 Loss 0.5070 Moving Loss 0.4986 Train Loss 0.5021
# 0.16753172874450684 secs
# Iter 2600 Loss 0.5066 Moving Loss 0.4963 Train Loss 0.4935
# 0.16739749908447266 secs
# Iter 2700 Loss 0.5063 Moving Loss 0.4990 Train Loss 0.5087
# 0.16738629341125488 secs
# Iter 2800 Loss 0.5060 Moving Loss 0.4971 Train Loss 0.4970
# 0.17870402336120605 secs
# Iter 2900 Loss 0.5059 Moving Loss 0.5027 Train Loss 0.5148
# 0.16822171211242676 secs
# Iter 3000 Loss 0.5057 Moving Loss 0.4991 Train Loss 0.5011
# Done
# (torch_venv) (base) bash-5.1$ bash decompress.sh 20_hmm.dzip decom_hmm20 com MODEL_PATH
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# Iter 100 Loss 0.5459 Moving Loss 0.5459
# 0.45862412452697754 secs
# Iter 200 Loss 0.5269 Moving Loss 0.5078
# 0.17841553688049316 secs
# Iter 300 Loss 0.5201 Moving Loss 0.5066
# 0.17786836624145508 secs
# Iter 400 Loss 0.5167 Moving Loss 0.5065
# 0.1779170036315918 secs
# Iter 500 Loss 0.5134 Moving Loss 0.5000
# 0.1778860092163086 secs
# Iter 600 Loss 0.5127 Moving Loss 0.5095
# 0.17784333229064941 secs
# Iter 700 Loss 0.5110 Moving Loss 0.5010
# 0.17737650871276855 secs
# Iter 800 Loss 0.5097 Moving Loss 0.5002
# 0.1770613193511963 secs
# Iter 900 Loss 0.5090 Moving Loss 0.5036
# 0.17728590965270996 secs
# Iter 1000 Loss 0.5084 Moving Loss 0.5034
# 0.1774444580078125 secs
# Iter 1100 Loss 0.5080 Moving Loss 0.5031
# 0.17810344696044922 secs
# Iter 1200 Loss 0.5077 Moving Loss 0.5044
# 0.18599152565002441 secs
# Iter 1300 Loss 0.5076 Moving Loss 0.5071
# 0.17797231674194336 secs
# Iter 1400 Loss 0.5070 Moving Loss 0.4992
# 0.17655229568481445 secs
# Iter 1500 Loss 0.5065 Moving Loss 0.4992
# 0.17628860473632812 secs
# Iter 1600 Loss 0.5063 Moving Loss 0.5038
# 0.17691993713378906 secs
# Iter 1700 Loss 0.5061 Moving Loss 0.5032
# 0.17817926406860352 secs
# Iter 1800 Loss 0.5060 Moving Loss 0.5034
# 0.17878293991088867 secs
# Iter 1900 Loss 0.5058 Moving Loss 0.5024
# 0.1777639389038086 secs
# Iter 2000 Loss 0.5055 Moving Loss 0.4987
# 0.17715764045715332 secs
# Iter 2100 Loss 0.5052 Moving Loss 0.5008
# 0.1778888702392578 secs
# Iter 2200 Loss 0.5050 Moving Loss 0.5003
# 0.17757654190063477 secs
# Iter 2300 Loss 0.5047 Moving Loss 0.4987
# 0.1815028190612793 secs
# Iter 2400 Loss 0.5074 Moving Loss 0.5681
# 0.18184328079223633 secs
# Iter 2500 Loss 0.5070 Moving Loss 0.4986
# 0.18490362167358398 secs
# Iter 2600 Loss 0.5066 Moving Loss 0.4963
# 0.17806553840637207 secs
# Iter 2700 Loss 0.5063 Moving Loss 0.4990
# 0.19864988327026367 secs
# Iter 2800 Loss 0.5060 Moving Loss 0.4971
# 0.18337464332580566 secs
# Iter 2900 Loss 0.5059 Moving Loss 0.5027
# 0.17706990242004395 secs
# Iter 3000 Loss 0.5057 Moving Loss 0.4991
# 0.1782674789428711 secs
# Done
# (torch_venv) (base) bash-5.1$ bash compare.sh Simulated-data-main/20-order_hidden_markov_chain.txt decom_hmm20
# The file "Simulated-data-main/20-order_hidden_markov_chain.txt" is the same as "decom_hmm20"
# (torch_venv) (base) bash-5.1$ code compression_logs_30.ipynb
# (torch_venv) (base) bash-5.1$ bash compress.sh Simulated-data-main/30-order_markov_chain.txt output/30_mc.dzip com MODEL_PATH
# Seq Length 199999
# Using cuda
# Vocab Size 3
# CudNN version 90100
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.2636113166809082 secs
# ====> Epoch: 1 Average loss: 0.6185349761.7871
# Loss went from 100000000.0000 to 0.6185
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08395552635192871 secs
# ====> Epoch: 2 Average loss: 0.5020421762.5006
# Loss went from 0.6185 to 0.5020
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08828020095825195 secs
# ====> Epoch: 3 Average loss: 0.5019702109.4903
# Loss went from 0.5020 to 0.5020
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08862066268920898 secs
# ====> Epoch: 4 Average loss: 0.5007665308.4971
# Loss went from 0.5020 to 0.5008
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.0918571949005127 secs
# ====> Epoch: 5 Average loss: 0.5006946304.4942
# Loss went from 0.5008 to 0.5007
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.08846831321716309 secs
# ====> Epoch: 6 Average loss: 0.5003536869.4958
# Loss went from 0.5007 to 0.5004
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09145021438598633 secs
# ====> Epoch: 7 Average loss: 0.5006535462.4889
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:203.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# 0.09034085273742676 secs
# ====> Epoch: 8 Average loss: 0.5013145095.4864
# Done
# Using MODEL_PATH for encoding
# array type int64
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# 0.4184691905975342 secs
# Iter 100 Loss 0.6146 Moving Loss 0.6146 Train Loss 1.0557
# 0.17176270484924316 secs
# Iter 200 Loss 0.5657 Moving Loss 0.5168 Train Loss 0.5869
# 0.1712496280670166 secs
# Iter 300 Loss 0.5441 Moving Loss 0.5009 Train Loss 0.5217
# 0.17006945610046387 secs
# Iter 400 Loss 0.5384 Moving Loss 0.5212 Train Loss 0.5806
# 0.16994929313659668 secs
# Iter 500 Loss 0.5310 Moving Loss 0.5013 Train Loss 0.5126
# 0.17205095291137695 secs
# Iter 600 Loss 0.5268 Moving Loss 0.5058 Train Loss 0.5173
# 0.16985464096069336 secs
# Iter 700 Loss 0.5239 Moving Loss 0.5067 Train Loss 0.5276
# 0.16993045806884766 secs
# Iter 800 Loss 0.5210 Moving Loss 0.5010 Train Loss 0.5074
# 0.16964483261108398 secs
# Iter 900 Loss 0.5195 Moving Loss 0.5070 Train Loss 0.5207
# 0.17002201080322266 secs
# Iter 1000 Loss 0.5178 Moving Loss 0.5023 Train Loss 0.5127
# 0.17101430892944336 secs
# Iter 1100 Loss 0.5164 Moving Loss 0.5029 Train Loss 0.5041
# 0.17027044296264648 secs
# Iter 1200 Loss 0.5152 Moving Loss 0.5018 Train Loss 0.5112
# 0.17050552368164062 secs
# Iter 1300 Loss 0.5144 Moving Loss 0.5045 Train Loss 0.5135
# 0.17047715187072754 secs
# Iter 1400 Loss 0.5134 Moving Loss 0.5007 Train Loss 0.5042
# 0.16987299919128418 secs
# Iter 1500 Loss 0.5125 Moving Loss 0.5004 Train Loss 0.5022
# 0.1706094741821289 secs
# Iter 1600 Loss 0.5119 Moving Loss 0.5029 Train Loss 0.5123
# 0.1693418025970459 secs
# Iter 1700 Loss 0.5112 Moving Loss 0.5003 Train Loss 0.5011
# 0.16903352737426758 secs
# Iter 1800 Loss 0.5109 Moving Loss 0.5048 Train Loss 0.5083
# 0.1699085235595703 secs
# Iter 1900 Loss 0.5104 Moving Loss 0.5012 Train Loss 0.5106
# 0.1700451374053955 secs
# Iter 2000 Loss 0.5099 Moving Loss 0.5004 Train Loss 0.5016
# 0.1750950813293457 secs
# Iter 2100 Loss 0.5095 Moving Loss 0.5019 Train Loss 0.5046
# 0.17590546607971191 secs
# Iter 2200 Loss 0.5091 Moving Loss 0.5003 Train Loss 0.5015
# 0.17506957054138184 secs
# Iter 2300 Loss 0.5087 Moving Loss 0.5004 Train Loss 0.5008
# 0.16995882987976074 secs
# Iter 2400 Loss 0.5083 Moving Loss 0.4999 Train Loss 0.5002
# 0.1700444221496582 secs
# Iter 2500 Loss 0.5081 Moving Loss 0.5013 Train Loss 0.5038
# 0.16997361183166504 secs
# Iter 2600 Loss 0.5077 Moving Loss 0.5001 Train Loss 0.5007
# 0.17753148078918457 secs
# Iter 2700 Loss 0.5075 Moving Loss 0.5019 Train Loss 0.5065
# 0.1707460880279541 secs
# Iter 2800 Loss 0.5073 Moving Loss 0.5007 Train Loss 0.5019
# 0.18102669715881348 secs
# Iter 2900 Loss 0.5071 Moving Loss 0.5011 Train Loss 0.5014
# 0.19387173652648926 secs
# Iter 3000 Loss 0.5069 Moving Loss 0.5015 Train Loss 0.5067
# Done
# ```

# %% [markdown]
# # Decompression Logs
#
# ```bash
# Using MODEL_PATH for decoding
# Using device cuda
# /home/jx1421/Dzip-torch/torch_venv/lib64/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# 3124
# Iter 100 Loss 0.6146 Moving Loss 0.6146
# 0.4833822250366211 secs
# Iter 200 Loss 0.5657 Moving Loss 0.5168
# 0.2067267894744873 secs
# Iter 300 Loss 0.5441 Moving Loss 0.5009
# 0.19398260116577148 secs
# Iter 400 Loss 0.5384 Moving Loss 0.5212
# 0.17946815490722656 secs
# Iter 500 Loss 0.5310 Moving Loss 0.5013
# 0.1852414608001709 secs
# Iter 600 Loss 0.5268 Moving Loss 0.5058
# 0.19684743881225586 secs
# Iter 700 Loss 0.5239 Moving Loss 0.5067
# 0.20014166831970215 secs
# Iter 800 Loss 0.5210 Moving Loss 0.5010
# 0.1793959140777588 secs
# Iter 900 Loss 0.5195 Moving Loss 0.5070
# 0.18896055221557617 secs
# Iter 1000 Loss 0.5178 Moving Loss 0.5023
# 0.19511866569519043 secs
# Iter 1100 Loss 0.5164 Moving Loss 0.5029
# 0.20740699768066406 secs
# Iter 1200 Loss 0.5152 Moving Loss 0.5018
# 0.2054004669189453 secs
# Iter 1300 Loss 0.5144 Moving Loss 0.5045
# 0.20594286918640137 secs
# Iter 1400 Loss 0.5134 Moving Loss 0.5007
# 0.20594239234924316 secs
# Iter 1500 Loss 0.5125 Moving Loss 0.5004
# 0.20484209060668945 secs
# Iter 1600 Loss 0.5119 Moving Loss 0.5029
# 0.20519614219665527 secs
# Iter 1700 Loss 0.5112 Moving Loss 0.5003
# 0.2058851718902588 secs
# Iter 1800 Loss 0.5109 Moving Loss 0.5048
# 0.205979585647583 secs
# Iter 1900 Loss 0.5104 Moving Loss 0.5012
# 0.20531249046325684 secs
# Iter 2000 Loss 0.5099 Moving Loss 0.5004
# 0.20261454582214355 secs
# Iter 2100 Loss 0.5095 Moving Loss 0.5019
# 0.19537878036499023 secs
# Iter 2200 Loss 0.5091 Moving Loss 0.5003
# 0.19102072715759277 secs
# Iter 2300 Loss 0.5087 Moving Loss 0.5004
# 0.17956018447875977 secs
# Iter 2400 Loss 0.5083 Moving Loss 0.4999
# 0.18554043769836426 secs
# Iter 2500 Loss 0.5081 Moving Loss 0.5013
# 0.17802000045776367 secs
# Iter 2600 Loss 0.5077 Moving Loss 0.5001
# 0.18175053596496582 secs
# Iter 2700 Loss 0.5075 Moving Loss 0.5019
# 0.17754316329956055 secs
# Iter 2800 Loss 0.5073 Moving Loss 0.5007
# 0.17618417739868164 secs
# Iter 2900 Loss 0.5071 Moving Loss 0.5011
# 0.17801928520202637 secs
# Iter 3000 Loss 0.5069 Moving Loss 0.5015
# 0.17751193046569824 secs
# Done
# ```

# %% [markdown]
# # Comparison
#
# The file "Simulated-data-main/30-order_markov_chain.txt" is the same as "output/decom_mc30"
